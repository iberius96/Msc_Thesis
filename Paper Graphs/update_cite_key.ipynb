# %%
import pandas as pd
import biblib.bib
import re
import graphviz
import os
import sys
import math

# %%
def build_cite_key(authors, year, title):
    invalid = '<>:"/\|?*{}()\''

    authors = re.sub(r'\\. ', '', authors)
    authors = re.sub(r'\\.', '', authors)
    authors = authors.replace('ı', 'i')
    authors = authors.replace('.', '')
    authors = authors.replace('-', ' ')
    for char in invalid: authors = authors.replace(char, '')

    title_invalid = '!.,$&#`+;’‐–‘^'
    title_proc = title.lower().replace(' ', '_')
    title_proc = title_proc.replace('~','_')
    title_proc = title_proc.replace('ı', 'i')
    title_proc = title_proc.replace('ó', 'o')
    for char in invalid: title_proc = title_proc.replace(char, '')
    for char in title_invalid: title_proc = title_proc.replace(char, '')
    title_proc = title_proc.replace('&amp;', '')
    title_proc = title_proc.replace('amp;', '')

    def_authors_regex = re.compile(r'^[a-z]+( [a-z]+)*,')
    def_authors_match = re.match(def_authors_regex, authors.lower())

    if(('and' not in authors) and (',' not in authors)): # SINGLE AUTHOR
        author_proc = authors.split().pop(-1).lower()
        cite_key = f"{author_proc}_{year}_{title_proc}"
    elif(bool(def_authors_match)): # SURNAME(S), NAME(S)
        author_proc = def_authors_match[0].replace(',','').replace(' ', '_')
        cite_key = f"{author_proc}_{year}_{title_proc}"
    else: # NAME(S) SURNAME(S) AND ...
        ns_authors_regex = re.compile(r'[a-z]+ \band\b')
        author_proc = ns_authors_regex.search(authors.lower()).group().replace(' and', '')
        cite_key = f"{author_proc}_{year}_{title_proc}"
    
    cite_key = cite_key.replace('-', '_')
    for char in invalid: cite_key = cite_key.replace(char, '')
    
    return cite_key

# %%
def get_glossary():
    with open('Glossary.bib', 'r') as glossary:
        db = biblib.bib.Parser().parse(glossary, log_fp=sys.stderr).get_entries()
        return db

# %%
def standardise_keys(bs_fs, venues):
    for key in venues:
        for venue in venues[key]:
            print(f'---------{venue}---------')

            with os.scandir(f'../References/Snowballing/{bs_fs}/{key}/{venue}') as it:
                for entry in it:
                    if entry.name.endswith(".bib") and entry.is_file():
                        with open(entry, 'r') as fp:
                            db = biblib.bib.Parser().parse(fp, log_fp=sys.stderr).get_entries()

                        for ent in db.values():
                            print(ent.key)
                            cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])

                            with open(entry) as r:
                                text = r.read().replace(f'{{{ent.key}', f'{{{cite_key}')
                            with open(entry, "w") as w:
                                w.write(text)

# %%
venues = {
    'Conferences': ['ACL','CIKM','COLING','EACL','ECIR','ECML PKDD','EMNLP','KDD','NAACL','SIGIR'],
    'Journals': ['Decision Support Systems', 'Expert Systems with Applications', 'Information Sciences', 'Journal of Infometrics', 'Knowledge-Based Systems', 'Pattern Recognition']
}

# %%
standardise_keys('Backward snowballing (Outgoing references)', venues)
standardise_keys('Forward snowballing (Incoming citations)', venues)
# Out:
# ---------ACL---------
# boyd_graber_2017_applications_of_topic_models
# srivastava_2017_autoencoding_variational_inference_for_topic_models
# lau_2017_topically_driven_neural_language_model
# he_2017_efficient_correlated_topic_modeling_with_topic_embedding
# benton_2018_deep_dirichlet_multinomial_regression
# zhou_2016_nonparametric_bayesian_negative_binomial_factor_analysis
# srivastava_2017_autoencoding_variational_inference_for_topic_models
# zhao_2019_variational_autoencoders_for_sparse_and_overdispersed_discrete_data
# nan_2019_topic_modeling_with_wasserstein_autoencoders
# naesseth_2017_reparameterization_gradients_through_acceptance_rejection_sampling_algorithms
# miao_2017_discovering_discrete_latent_topics_with_neural_variational_inference
# gupta_2019_document_informed_neural_autoregressive_topic_models_with_distributional_prior
# choi_2018_topicontiles_tile_based_spatio_temporal_event_analytics_via_exclusive_topic_modeling_on_social_media
# giorgi_2018_the_remarkable_benefit_of_user_level_aggregation_for_lexical_based_population_level_predictions
# nugroho_2016_using_time_sensitive_interactions_to_improve_topic_derivation_in_twitter
# shin_2017_stexnmf_spatio_temporally_exclusive_topic_discovery_for_anomalous_event_detection
# steinskog_2017_twitter_topic_modeling_by_tweet_aggregation
# shang_2018_automated_phrase_mining_from_massive_text_corpora
# huang_2017_category_level_transfer_learning_from_knowledge_base_to_microblog_stream_for_accurate_event_detection
# he_2017_efficient_correlated_topic_modeling_with_topic_embedding
# ---------CIKM---------
# yamada_2017_learning_distributed_representations_of_texts_and_entities_from_knowledge_base
# wang_2017_combining_knowledge_with_deep_convolutional_neural_networks_for_short_text_classification
# venkatesh_2018_on_evaluating_and_comparing_open_domain_dialog_systems
# ram_2018_conversational_ai_the_science_behind_the_alexa_prize
# krause_2017_edina_building_an_open_domain_socialbot_with_self_dialogues
# khatri_2018_contextual_topic_modeling_for_dialog_systems
# joty_2018_coherence_modeling_of_asynchronous_conversations_a_neural_entity_grid_approach
# guo_2018_topic_based_evaluation_for_conversational_bots
# conneau_2016_very_deep_convolutional_networks_for_text_classification
# cer_2018_universal_sentence_encoder
# bojanowski_2016_enriching_word_vectors_with_subword_information
# underwood_2019_distant_horizons_digital_evidence_and_literary_change
# vaccaro_2019_contestability_in_algorithmic_systems
# wang_2019_balanced_datasets_are_not_enough_estimating_and_mitigating_gender_bias_in_deep_image_representations
# tapal_2017_the_sense_of_agency_scale_a_measure_of_consciously_perceived_control_over_onetextquotesingles_mind_body_and_the_immediate_environment
# wang_2019_implicit_gender_biases_in_professional_software_development_an_empirical_study
# woodruff_2018_a_qualitative_exploration_of_perceptions_of_algorithmic_fairness
# yang_2018_investigating_how_experienced_ux_designers_effectively_work_with_machine_learning
# zafar_2016_fairness_beyond_disparate_treatment_amp_disparate_impact_learning_classification_without_disparate_mistreatment
# smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels
# schwemmer_2020_diagnosing_gender_bias_in_image_recognition_systems
# scheuerman_2019_how_computers_see_gender_an_evaluation_of_gender_classification_in_commercial_facial_analysis_services
# robertson_2018_auditing_the_personalization_and_composition_of_politically_related_search_engine_results_pages
# robertson_2018_auditing_partisan_audience_bias_within_google_search
# nelson_2017_computational_grounded_theory_a_methodological_framework
# moreira_2018_image_provenance_analysis_at_scale
# mantyla_2018_measuring_lda_topic_stability_from_clusters_of_replicated_runs
# lau_2017_topically_driven_neural_language_model
# kulshrestha_2017_quantifying_search_bias_investigating_sources_of_bias_for_political_searches_in_social_media
# kleinberg_2017_human_decisions_and_machine_predictions
# john_2019_the_case_of_computer_science_education_employment_gender_and_raceethnicity_in_silicon_valley_1980textendash2015
# jiang_2021_supporting_serendipity_opportunities_and_challenges_for_human_ai_collaboration_in_qualitative_analysis
# hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence
# hoffman_2017_evaluating_a_computational_approach_to_labeling_politeness_challenges_for_the_application_of_machine_classification_to_social_computing_data
# hirsch_2017_designing_contestability
# fiebrink_2018_introduction_to_the_special_issue_on_human_centered_machine_learning
# dove_2017_ux_design_innovation_challenges_for_working_with_machine_learning_as_a_design_material
# cui_2018_learning_to_evaluate_image_captioning
# corbett_davies_2018_the_measure_and_mismeasure_of_fairness_a_critical_review_of_fair_machine_learning
# clementson_2017_truth_bias_and_partisan_bias_in_political_deception_detection
# buolamwini_2018_gender_shades_intersectional_accuracy_disparities_in_commercial_gender_classification
# baumer_2020_topicalizer_reframing_core_concepts_in_machine_learning_visualization_by_co_designing_for_interpretivist_scholarship
# ---------COLING---------
# berg_2018_digital_labour_platforms_and_the_future_of_work_towards_decent_work_in_the_online_world
# edlund_2017_participant_crosstalk_issues_when_using_the_mechanical_turk
# xia_2017_our_privacy_needs_to_be_protected_at_all_costs_crowd_workers_privacy_experiences_on_amazon_mechanical_turk
# lippe_2018_organizational_worktextendashlife_policies_and_the_gender_wage_gap_in_european_workplaces
# shu_2021_privacy_preserving_task_recommendation_services_for_crowdsourcing
# schwartz_2018_embedded_in_the_crowd_creative_freelancers_crowdsourced_work_and_occupational_community
# sannon_2019_privacy_power_and_invisible_labor_on_amazon_mechanical_turk
# guth_2017_finding_the_diamond_in_the_rough_exploring_communication_and_platform_in_crowdsourcing_performance
# gadiraju_2017_clarity_is_a_worthwhile_quality_on_the_role_of_task_clarity_in_microtask_crowdsourcing
# ma_2019_learning_representations_for_time_series_clustering
# zhao_2021_a_relation_oriented_clustering_method_for_open_relation_extraction
# zhang_2018_whai_weibull_hybrid_autoencoding_inference_for_deep_topic_modeling
# zhang_2021_supporting_clustering_with_contrastive_learning
# zeng_2018_topic_memory_networks_for_short_text_classification
# yang_2020_adversarial_learning_for_robust_deep_clustering
# yang_2019_deep_clustering_by_gaussian_mixture_variational_autoencoders_with_graph_embedding
# xu_2017_self_taught_convolutional_neural_networks_for_short_text_clustering
# wu_2018_tracing_fake_news_footprints_characterizing_social_media_messages_by_how_they_propagate
# wu_2019_deep_comprehensive_correlation_mining_for_image_clustering
# wang_2020_friendly_topic_assistant_for_transformer_based_abstractive_summarization
# wang_2020_neural_topic_model_with_attention_for_supervised_learning
# wang_2019_topic_guided_variational_autoencoders_for_text_generation
# van_gansbeke_2020_scan_learning_to_classify_images_without_labels
# tsai_2021_mice_mixture_of_contrastive_experts_for_unsupervised_image_clustering
# tang_2019_a_topic_augmented_text_generation_model_joint_learning_of_semantics_and_structural_features
# srivastava_2017_autoencoding_variational_inference_for_topic_models
# see_2017_get_to_the_point_summarization_with_pointer_generator_networks
# reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks
# rakib_2020_enhancement_of_short_text_clustering_by_iterative_classification
# madiraju_2018_deep_temporal_clustering__fully_unsupervised_learning_of_time_domain_features
# liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach
# li_2020_contrastive_clustering
# kobayashi_2018_contextual_augmentation_data_augmentation_by_words_with_paradigmatic_relations
# guo_2017_improved_deep_embedded_clustering_with_local_structure_preservation
# ghasedi_2019_balanced_self_paced_learning_for_generative_adversarial_clustering_network
# dieng_2019_topic_modeling_in_embedding_spaces
# devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding
# cong_2017_deep_latent_dirichlet_allocation_with_topic_layer_adaptive_stochastic_gradient_riemannian_mcmc
# chen_2020_a_simple_framework_for_contrastive_learning_of_visual_representations
# caron_2018_deep_clustering_for_unsupervised_learning_of_visual_features
# brahma_2018_unsupervised_learning_of_sentence_representations_using_sequence_consistency
# asano_2019_self_labelling_via_simultaneous_clustering_and_representation_learning
# aljalbout_2018_clustering_with_deep_learning_taxonomy_and_new_methods
# ailem_2019_topic_augmented_generator_for_abstractive_summarization
# shi_2017_jointly_learning_word_embeddings_and_latent_topics
# salant_2018_contextualized_word_representations_for_reading_comprehension
# peters_2018_deep_contextualized_word_representations
# zhao_2017_topic_aware_deep_compositional_models_for_sentence_classification
# burkhardt_2019_decoupling_sparsity_and_smoothness_in_the_dirichlet_variational_autoencoder_topic_model
# zhao_2017_metalda_a_topic_model_that_efficiently_incorporates_meta_information
# traag_2018_from_louvain_to_leiden_guaranteeing_well_connected_communities
# srivastava_2017_autoencoding_variational_inference_for_topic_models
# sakr_2020_the_future_is_big_graphs_a_community_view_on_graph_processing_systems
# rao_2021_vec2gc____a_graph_based_clustering_method_for_text_representations
# newman_2018_networks
# nan_2019_topic_modeling_with_wasserstein_autoencoders
# nalisnick_2016_stick_breaking_variational_autoencoders
# mcinnes_2018_umap_uniform_manifold_approximation_and_projection_for_dimension_reduction
# mantyla_2018_measuring_lda_topic_stability_from_clusters_of_replicated_runs
# krasnashchok_2018_improving_topic_quality_by_promoting_named_entities_in_topic_modeling
# kingma_2019_an_introduction_to_variational_autoencoders
# isoaho_2019_topic_modeling_and_text_analysis_for_qualitative_policy_research
# hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence
# dziri_2018_augmenting_neural_response_generation_with_context_aware_topical_attention
# doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures
# dieng_2020_topic_modeling_in_embedding_spaces
# angelov_2020_top2vec_distributed_representations_of_topics
# ---------EACL---------
# aletras_2017_labeling_topics_with_images_using_a_neural_network
# aletras_2017_evaluating_topic_representations_for_exploring_document_collections
# masada_2018_adversarial_learning_for_topic_models
# silva_2017_content_based_social_recommendation_with_poisson_matrix_factorization
# wang_2018_atmadversarial_neural_topic_model
# wang_2020_neural_topic_modeling_with_bidirectional_adversarial_training
# vafa_2020_text_based_ideal_points
# su_2019_personalized_point_of_interest_recommendation_on_ranking_with_poisson_factorization
# srivastava_2017_autoencoding_variational_inference_for_topic_models
# nan_2019_topic_modeling_with_wasserstein_autoencoders
# kuo_2021_the_framework_of_personalized_ranking_on_poisson_factorization
# kang_2019_decoupling_representation_and_classifier_for_long_tailed_recognition
# joo_2020_generalized_gumbel_softmax_gradient_estimator_for_various_discrete_random_variables
# john_2018_disentangled_representation_learning_for_non_parallel_text_style_transfer
# jiang_2017_a_topic_model_based_on_poisson_decomposition
# jang_2016_categorical_reparameterization_with_gumbel_softmax
# huang_2018_siamese_network_based_supervised_topic_modeling
# hu_2020_neural_topic_modeling_with_cycle_consistent_adversarial_training
# he_2018_effective_attention_modeling_for_aspect_level_sentiment_classification
# he_2017_an_unsupervised_neural_attention_model_for_aspect_extraction
# guo_2017_understanding_users_budgets_for_recommendation_with_hierarchical_poisson_factorization
# gui_2022_multi_task_mutual_learning_for_joint_sentiment_classification_and_topic_detection
# gao_2017_collaborative_dynamic_sparse_topic_regression_with_user_profile_evolution_for_item_recommendation
# chaidaroon_2017_variational_deep_semantic_hashing_for_text_documents
# card_2017_neural_models_for_documents_with_metadata
# bouchacourt_2017_multi_level_variational_autoencoder_learning_disentangled_representations_from_grouped_observations
# blei_2017_variational_inference_a_review_for_statisticians
# barry_2018_alcohol_advertising_on_twittertextemdasha_topic_model
# zhang_2019_bertscore_evaluating_text_generation_with_bert
# vaswani_2017_attention_is_all_you_need
# sorodoc_2017_multimodal_topic_labelling
# radford_2019_language_models_are_unsupervised_multitask_learners
# liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach
# lewis_2019_bart_denoising_sequence_to_sequence_pre_training_for_natural_language_generation_translation_and_comprehension
# keskar_2019_ctrl_a_conditional_transformer_language_model_for_controllable_generation
# gourru_2018_united_we_stand_using_multiple_strategies_for_topic_labeling
# devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding
# alokaili_2020_automatic_generation_of_topic_labels
# ---------ECIR---------
# zhang_2019_bertscore_evaluating_text_generation_with_bert
# vaswani_2017_attention_is_all_you_need
# reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks
# popa_2021_bart_tl_weakly_supervised_topic_label_generation
# mueller_2018_reading_between_the_lines_prediction_of_political_violence_using_newspaper_text
# maurya_2021_zmbart_an_unsupervised_cross_lingual_transfer_framework_for_language_generation
# marjanen_2020_topic_modelling_discourse_dynamics_in_historical_newspapers
# liu_2020_multilingual_denoising_pre_training_for_neural_machine_translation
# li_2020_global_surveillance_of_covid_19_by_mining_news_media_using_a_multi_source_dynamic_embedded_topic_model
# lewis_2019_bart_denoising_sequence_to_sequence_pre_training_for_natural_language_generation_translation_and_comprehension
# kim_2019_an_ontology_based_labeling_of_influential_topics_using_topic_network_analysis
# kanerva_2018_turku_neural_parser_pipeline_an_end_to_end_system_for_the_conll_2018_shared_task
# alokaili_2020_automatic_generation_of_topic_labels
# ---------ECML PKDD---------
# ---------EMNLP---------
# arjovsky_2017_wasserstein_generative_adversarial_networks
# card_2018_neural_models_for_documents_with_metadata
# gulrajani_2017_improved_training_of_wasserstein_gans
# kim_2017_learning_to_discover_cross_domain_relations_with_generative_adversarial_networks
# lee_2018_scalable_sentiment_for_sequence_to_sequence_chatbot_response_with_performance_analysis
# miao_2017_discovering_discrete_latent_topics_with_neural_variational_inference
# srivastava_2017_autoencoding_variational_inference_for_topic_models
# wang_2020_neural_topic_modeling_with_bidirectional_adversarial_training
# wang_2019_atm_adversarial_neural_topic_model
# wang_2019_open_event_extraction_from_online_text_using_a_generative_adversarial_network
# zhou_2017_event_extraction_from_twitter_using_non_parametric_bayesian_mixture_model_with_word_embeddings
# zhu_2017_unpaired_image_to_image_translation_using_cycle_consistent_adversarial_networks
# he_2017_efficient_correlated_topic_modeling_with_topic_embedding
# montani_2022_explosionspacy_v343_extended_typer_support_and_bug_fixes
# zhou_2017_learning_phrase_embeddings_from_paraphrases_with_grus
# zhang_2019_paws_paraphrase_adversaries_from_word_scrambling
# yu_2020_assessing_phrasal_representation_and_composition_in_transformers
# wolf_2019_transfertransfo_a_transfer_learning_approach_for_neural_network_based_conversational_agents
# wieting_2018_paranmt_50m_pushing_the_limits_of_paraphrastic_sentence_embeddings_with_millions_of_machine_translations
# vijayakumar_2018_diverse_beam_search_for_improved_description_of_complex_scenes
# toshniwal_2020_a_cross_task_analysis_of_text_span_representations
# seo_2018_phrase_indexed_question_answering_a_new_challenge_for_scalable_document_comprehension
# reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks
# radford_2019_language_models_are_unsupervised_multitask_learners
# merullo_2019_investigating_sports_commentator_bias_within_a_large_corpus_of_american_football_broadcasts
# merity_2016_pointer_sentinel_mixture_models
# liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach
# li_2020_on_the_sentence_embeddings_from_pre_trained_language_models
# lee_2020_learning_dense_representations_of_phrases_at_scale
# krishna_2020_reformulating_unsupervised_style_transfer_as_paraphrase_generation
# joshi_2019_spanbert_improving_pre_training_by_representing_and_predicting_spans
# holtzman_2019_the_curious_case_of_neural_text_degeneration
# gao_2021_the_pile_an_800gb_dataset_of_diverse_text_for_language_modeling
# gala_2020_analyzing_gender_bias_within_narrative_tropes
# dieng_2019_topic_modeling_in_embedding_spaces
# devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding
# conneau_2018_what_you_can_cram_into_a_single__vector_probing_sentence_embeddings_for_linguistic_properties
# bommasani_2020_interpreting_pretrained_contextualized_representations_via_reductions_to_static_embeddings
# asaadi_2019_big_bird_a_large_fine_grained_bigram_relatedness_dataset_for_examining_semantic_composition
# akoury_2020_storium_a_dataset_and_evaluation_platform_for_machine_in_the_loop_story_generation
# choudhury_2017_the_language_of_social_support_in_social_media_and_its_effect_on_suicidal_ideation_risk
# j_william_worden_2008_grief_counseling_and_grief_therapy_fourth_edition_a_handbook_for_the_mental_health_practitioner
# wolf_2020_transformers_state_of_the_art_natural_language_processing
# wang_2018_its_going_to_be_okay_measuring_access_to_support_in_online_communities
# rashid_2017_dimensions_of_interpersonal_relationships_corpus_and_experiments
# orvell_2019_you_and_i_in_a_foreign_land_the_persuasive_force_of_generic_you
# orvell_2017_how_textquotedblleftyoutextquotedblright_makes_meaning
# nienhuis_2016_therapeutic_alliance_empathy_and_genuineness_in_individual_adult_psychotherapy_a_meta_analytic_review
# liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach
# khanpour_2017_identifying_empathetic_messages_in_online_health_communities
# fiesler_2018_participant_perceptions_of_twitter_research_ethics
# doveling_2017_online_emotion_regulation_in_digitally_mediated_bereavement_why_age_and_kind_of_loss_matter_in_grieving_online
# devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding
# cameron_2019_empathy_is_hard_work_people_choose_to_avoid_empathy_because_of_its_cognitive_costs
# buechel_2018_modeling_empathy_and_distress_in_reaction_to_news_stories
# breitfeller_2019_finding_microaggressions_in_the_wild_a_case_for_locating_elusive_phenomena_in_social_media_posts
# mageed_2017_recognizing_pathogenic_empathy_in_social_media
# ---------KDD---------
# jiang_2017_metapad_meta_pattern_discovery_from_massive_text_corpora
# zhang_2018_taxogen_unsupervised_topic_taxonomy_construction_by_adaptive_term_embedding_and_clustering
# yang_2017_efficiently_answering_technical_questions_textemdash_a_knowledge_graph_approach
# soares_2019_matching_the_blanks_distributional_similarity_for_relation_learning
# shen_2019_hiexpan_task_guided_taxonomy_construction_by_hierarchical_tree_expansion
# shen_2019_setexpan_corpus_based_set_expansion_via_context_feature_selection_and_rank_ensemble
# shang_2017_automated_phrase_mining_from_massive_text_corpora
# qu_2017_weakly_supervised_relation_extraction_by_pattern_enhanced_embedding_learning
# nickel_2017_poincare_embeddings_for_learning_hierarchical_representations
# meng_2020_hierarchical_topic_mining_via_joint_spherical_tree_and_text_embedding
# meng_2019_spherical_text_embedding
# meng_2019_discriminative_topic_mining_via_category_name_guided_text_embedding
# le_2019_inferring_concept_hierarchies_from_text_corpora_via_hyperbolic_embeddings
# huang_2020_guiding_corpus_based_set_expansion_by_auxiliary_sets_generation_and_co_expansion
# han_2018_fewrel_a_large_scale_supervised_few_shot_relation_classification_dataset_with_state_of_the_art_evaluation
# gao_2019_hybrid_attention_based_prototypical_networks_for_noisy_few_shot_relation_classification
# devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding
# dash_2019_hypernym_detection_using_strict_partial_order_networks
# chang_2018_distributional_inclusion_vector_embedding_for_unsupervised_hypernymy_detection
# zhang_2019_higitclass_keyword_driven_hierarchical_classification_of_github_repositories
# tifrea_2018_poincare_glove_hyperbolic_word_embeddings
# shang_2017_automated_phrase_mining_from_massive_text_corpora
# nickel_2018_learning_continuous_hierarchies_in_the_lorentz_model_of_hyperbolic_geometry
# nickel_2017_poincare_embeddings_for_learning_hierarchical_representations
# meng_2018_weakly_supervised_hierarchical_text_classification
# meng_2018_weakly_supervised_neural_text_classification
# meng_2019_spherical_text_embedding
# meng_2019_discriminative_topic_mining_via_category_name_guided_text_embedding
# meng_2020_unsupervised_word_embedding_learning_by_incorporating_local_and_global_contexts
# kumar_2018_von_mises_fisher_loss_for_training_sequence_to_sequence_models_with_continuous_outputs
# huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring
# huang_2020_guiding_corpus_based_set_expansion_by_auxiliary_sets_generation_and_co_expansion
# ganea_2018_hyperbolic_entailment_cones_for_learning_hierarchical_embeddings
# gallagher_2016_anchored_correlation_explanation_topic_modeling_with_minimal_domain_knowledge
# dieng_2019_topic_modeling_in_embedding_spaces
# ahuja_2021_mixehr_guided_a_guided_multi_modal_topic_modeling_approach_for_large_scale_automatic_phenotyping_using_the_electronic_health_record
# silva_2017_content_based_social_recommendation_with_poisson_matrix_factorization
# wang_2020_unsupervised_machine_learning_for_the_discovery_of_latent_disease_clusters_and_patient_subgroups_using_electronic_health_records
# song_2021_supervised_multi_specialist_topic_model_with_applications_on_large_scale_electronic_health_record_data
# li_2020_inferring_multimodal_latent_topics_from_electronic_health_records
# dieng_2019_the_dynamic_embedded_topic_model
# ahuja_2020_surelda_a_multidisease_automated_phenotyping_method_for_the_electronic_health_record
# ---------NAACL---------
# masada_2018_adversarial_learning_for_topic_models
# yang_2017_improved_variational_autoencoders_for_text_modeling_using_dilated_convolutions
# xu_2016_variational_autoencoders_for_semi_supervised_text_classification
# wang_2018_atmadversarial_neural_topic_model
# wan_2019_fine_grained_spoiler_detection_from_large_scale_review_corpora
# thomas_2018_disentangling_the_independently_controllable_factors_of_variation_by_interacting_with_the_world
# srivastava_2017_autoencoding_variational_inference_for_topic_models
# reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks
# pergola_2019_topical_phrase_extraction_from_clinical_reports_by_incorporating_both_local_and_global_context
# pergola_2019_tdam_a_topic_dependent_attention_model_for_sentiment_analysis
# peng_2019_domain_agnostic_learning_with_disentangled_representations
# nan_2019_topic_modeling_with_wasserstein_autoencoders
# miao_2017_discovering_discrete_latent_topics_with_neural_variational_inference
# kumar_2017_variational_inference_of_disentangled_latent_concepts_from_unlabeled_observations
# kar_2018_mpst_a_corpus_of_movie_plot_synopses_with_tags
# john_2019_disentangled_representation_learning_for_non_parallel_text_style_transfer
# hoang_2019_towards_autoencoding_variational_inference_for_aspect_based_opinion_summary
# higgins_2018_towards_a_definition_of_disentangled_representations
# higgins_2017_beta_vae_learning_basic_visual_concepts_with_a_constrained_variational_framework
# gui_2019_neural_topic_model_with_reinforcement_learning
# gao_2019_auto_encoding_total_correlation_explanation
# esmaeili_2018_structured_disentangled_representations
# ding_2018_coherence_aware_neural_topic_modeling
# dieng_2016_topicrnn_a_recurrent_neural_network_with_long_range_semantic_dependency
# devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding
# cooijmans_2016_recurrent_batch_normalization
# card_2017_neural_models_for_documents_with_metadata
# bengio_2017_independently_controllable_features
# achille_2017_emergence_of_invariance_and_disentanglement_in_deep_representations
# ramrakhiyani_2017_measuring_topic_coherence_through_optimal_word_buckets
# morstatter_2017_in_search_of_coherence_and_consensus_measuring_the_interpretability_of_statistical_topics
# zhao_2017_metalda_a_topic_model_that_efficiently_incorporates_meta_information
# zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey
# zhang_2020_topic_modeling_on_document_networks_with_adjacent_encoder
# xue_2020_public_discourse_and_sentiment_during_the_covid_19_pandemic_using_latent_dirichlet_allocation_for_topic_modeling_on_twitter
# wang_2018_astm_an_attentional_segmentation_based_topic_model_for_short_texts
# symeonidis_2018_a_comparative_evaluation_of_pre_processing_techniques_and_their_interactions_for_twitter_sentiment_analysis
# sinnenberg_2017_twitter_as_a_tool_for_health_research_a_systematic_review
# nerghes_2019_narratives_of_the_refugee_crisis_a_comparative_study_of_mainstream_media_and_twitter
# morstatter_2018_from_alt_right_to_alt_rechts_twitter_analysis_of_the_2017_german_federal_election
# maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology
# lyu_2021_understanding_the_public_discussion_about_the_centers_for_disease_control_and_prevention_during_the_covid_19_pandemic_using_twitter_data_text_mining_analysis_study
# lund_2019_automatic_evaluation_of_local_topic_quality
# lipton_2016_the_mythos_of_model_interpretability
# li_2018_short_text_topic_modeling_by_exploring_original_documents
# korencic_2018_document_based_topic_coherence_measures_for_news_media_text
# kirilenko_2021_automated_topic_modeling_of_tourist_reviews_does_the_anna_karenina_principle_apply
# karami_2020_twitter_and_research_a_systematic_literature_review_through_text_mining
# karami_2018_characterizing_diabetes_diet_exercise_and_obesity_comments_on_twitter
# kagashe_2017_enhancing_seasonal_influenza_surveillance_topic_analysis_of_widely_used_medicinal_drugs_using_twitter_data
# hecking_2019_can_topic_models_be_used_in_research_evaluations_reproducibility_validity_and_reliability_when_compared_with_semantic_maps
# doogan_2020_public_perceptions_and_attitudes_toward_covid_19_nonpharmaceutical_interventions_across_six_countries_a_topic_modeling_analysis_of_twitter_data
# brown_2018_methodological_cyborg_as_black_feminist_technology_constructing_the_social_self_using_computational_digital_autoethnography_and_social_media
# blair_2020_aggregated_topic_models_for_increasing_social_media_topic_coherence
# bhatia_2018_topic_intrusion_for_automatic_topic_model_evaluation
# bhatia_2017_an_automatic_approach_for_document_level_topic_model_evaluation
# baumer_2017_comparing_grounded_theory_and_topic_modeling_extreme_divergence_or_unlikely_convergence
# andreotta_2019_analyzing_social_media_data_a_mixed_methods_framework_combining_computational_and_qualitative_text_analysis
# alokaili_2019_re_ranking_words_to_improve_interpretability_of_automatically_generated_topics
# aletras_2017_evaluating_topic_representations_for_exploring_document_collections
# agrawal_2018_what_is_wrong_with_topic_modeling_and_how_to_fix_it_using_search_based_software_engineering
# ---------SIGIR---------
# zhao_2019_weakly_supervised_opinion_summarization_by_leveraging_external_information
# xu_2018_double_embeddings_and_cnn_based_sequence_labeling_for_aspect_extraction
# tian_2020_aspect_and_opinion_aware_abstractive_review_summarization_with_reinforced_hard_typed_decoder
# rudra_2018_identifying_sub_events_and_summarizing_disaster_related_information_from_microblogs
# rossiello_2017_centroid_based_text_summarization_through_compositionality_of_word_embeddings
# reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks
# he_2017_an_unsupervised_neural_attention_model_for_aspect_extraction
# fan_2017_controllable_abstractive_summarization
# dash_2018_summarizing_user_generated_textual_content_motivation_and_methods_for_fairness_in_algorithmic_summaries
# condori_2017_opinion_summarization_methods_comparing_and_extending_extractive_and_abstractive_approaches
# chu_2018_meansum_a_neural_model_for_unsupervised_multi_document_abstractive_summarization
# brazinskas_2019_unsupervised_opinion_summarization_as_copycat_review_generation
# angelidis_2018_summarizing_opinions_aspect_extraction_meets_sentiment_prediction_and_they_are_both_weakly_supervised
# amplayo_2019_informative_and_controllable_opinion_summarization
# schofield_2017_pulling_out_the_stops_rethinking_stopword_removal_for_topic_models
# zhang_2019_bertscore_evaluating_text_generation_with_bert
# smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels
# alokaili_2019_re_ranking_words_to_improve_interpretability_of_automatically_generated_topics
# aletras_2016_labeling_topics_with_images_using_neural_networks
# aletras_2015_evaluating_topic_representations_for_exploring_document_collections
# ---------Decision Support Systems---------
# yang_2019_in_airbnb_we_trust_understanding_consumers_trust_attachment_building_mechanisms_in_the_sharing_economy
# xu_2017_the_influence_of_e_services_on_customer_online_purchasing_behavior_toward_remanufactured_products
# xu_2018_does_traveler_satisfaction_differ_in_various_travel_group_compositions
# xu_2020_examining_an_asymmetric_effect_between_online_customer_reviews_emphasis_and_overall_satisfaction_determinants
# williams_2018_a_comparison_of_lsa_and_lda_for_the_analysis_of_railroad_accident_text
# sutherland_2018_the_sharing_economy_and_digital_platforms_a_review_and_research_agenda
# so_2018_motivations_and_constraints_of_airbnb_consumers_findings_from_a_mixed_methods_approach
# siering_2018_disentangling_consumer_recommendations_explaining_and_predicting_airline_recommendations_based_on_online_reviews
# roma_2019_sharing_economy_and_incumbents_pricing_strategy_the_impact_of_airbnb_on_the_hospitality_industry
# priporas_2017_unraveling_the_diverse_nature_of_service_quality_in_a_sharing_economy
# pappas_2019_the_complexity_of_consumer_experience_formulation_in_the_sharing_economy
# novais_2018_destination_competitiveness_a_phenomenographic_study
# netter_2019_sharing_economy_revisited_towards_a_new_framework_for_understanding_sharing_models
# moon_2019_peer_to_peer_interactions_perspectives_of_airbnb_guests_and_hosts
# masiero_2018_modeling_reference_experience_in_destination_choice
# mao_2017_why_travelers_use_airbnb_again
# lutz_2018_consumer_segmentation_within_the_sharing_economy_the_case_of_airbnb
# liu_2017_airbnb_online_targeted_advertising_sense_of_power_and_consumer_decisions
# liang_2017_be_a_superhost_the_importance_of_badge_systems_for_peer_to_peer_rental_accommodations
# leung_2019_framing_the_sharing_economy_toward_a_sustainable_ecosystem
# letheren_2017_effects_of_personification_and_anthropomorphic_tendency_on_destination_attitude_and_travel_intentions
# hu_2019_when_is_enough_enough_investigating_product_reviews_and_information_overload_from_a_consumer_empowerment_perspective
# hawlitschek_2018_consumer_motives_for_peer_to_peer_sharing
# han_2019_exploring_halal_friendly_destination_attributes_in_south_korea_perceptions_and_behaviors_of_muslim_travelers_toward_a_non_muslim_destination
# guttentag_2017_assessing_airbnb_as_a_disruptive_innovation_relative_to_hotels_substitution_and_comparative_performance_expectations
# gupta_2019_the_effects_of_national_cultural_values_on_individuals_intention_to_participate_in_peer_to_peer_sharing_economy
# davras_2019_analysis_of_hotel_services_by_their_symmetric_and_asymmetric_effects_on_overall_customer_satisfaction_a_comparison_of_market_segments
# davidson_2018_materialism_and_the_sharing_economy_a_cross_cultural_study_of_american_and_indian_consumers
# choi_2019_values_of_food_leftover_sharing_platforms_in_the_sharing_economy
# cheng_2019_an_investigation_on_online_reviews_in_sharing_economy_driven_hospitality_platforms_a_viewpoint_of_trust
# cardoso_2019_a_destination_imagery_processing_model_structural_differences_between_dream_and_favourite_destinations
# camilleri_2017_value_co_creation_and_co_destruction_in_the_airbnb_sharing_economy
# akbar_2018_the_sharing_economy_and_the_future_of_the_hotel_industry_transaction_cost_theory_and_platform_economics
# bapna_2017_nurturing_online_communities_an_empirical_investigation
# bellos_2017_the_car_sharing_economy_interaction_of_business_model_choice_and_product_line_design
# benjaafar_2019_peer_to_peer_product_sharing_implications_for_ownership_usage_and_social_welfare_in_the_sharing_economy
# cachon_2017_the_role_of_surge_pricing_on_a_service_platform_with_self_scheduling_capacity
# chen_2019_measuring_and_managing_the_externality_of_managerial_responses_to_online_customer_reviews
# guttentag_2017_why_tourists_choose_airbnb_a_motivation_based_segmentation_study
# jiang_2018_collaborative_consumption_strategic_and_economic_implications_of_product_sharing
# li_2018_competitive_dynamics_in_the_sharing_economy_an_analysis_in_the_context_of_airbnb_and_hotels
# liang_2017_understanding_repurchase_intention_of_airbnb_consumers_perceived_authenticity_electronic_word_of_mouth_and_price_sensitivity
# xu_2018_examining_the_relevance_of_online_customer_textual_reviews_on_hotels_product_and_service_attributes
# xu_2017_the_impact_of_e_service_offerings_on_the_demand_of_online_customers
# zervas_2017_the_rise_of_the_sharing_economy_estimating_the_impact_of_airbnb_on_the_hotel_industry
# matthias_2017_making_sense_of_big_data___can_it_transform_operations_management
# ramanathan_2017_role_of_social_media_in_retail_network_operations_and_marketing_to_enhance_customer_satisfaction
# xu_2017_business_intelligence_in_online_customer_textual_reviews_understanding_consumer_perceptions_and_influential_factors
# wiener_2018_omnichannel_businesses_in_the_publishing_and_retailing_industries_synergies_and_tensions_between_coexisting_online_and_offline_business_models
# thakur_2018_customer_engagement_and_online_reviews
# sheng_2017_a_multidisciplinary_perspective_of_big_data_in_management_research
# pepin_2017_visual_analytics_for_exploring_topic_long_term_evolution_and_detecting_weak_signals_in_company_targeted_tweets
# liu_2017_an_investigation_of_brand_related_user_generated_content_on_twitter
# ibrahim_2017_exploring_the_effect_of_user_engagement_in_online_brand_communities_evidence_from_twitter
# ghiassi_2016_targeted_twitter_sentiment_analysis_for_brands_using_supervised_feature_engineering_and_the_dynamic_architecture_for_artificial_neural_networks
# daniel_2017_company_event_popularity_for_financial_markets_using_twitter_and_sentiment_analysis
# bradlow_2017_the_role_of_big_data_and_predictive_analytics_in_retailing
# li_2017_catching_fire_and_spreading_it_a_glimpse_into_displayed_entrepreneurial_passion_in_crowdfunding_campaigns
# kim_2020_transparency_and_accountability_in_ai_decision_support_explaining_and_visualizing_convolutional_neural_networks_for_text_information
# guo_2017_mining_meaning_from_online_ratings_and_reviews_tourist_satisfaction_analysis_using_latent_dirichlet_allocation
# goldberg_2020_text_mining_approaches_for_postmarket_food_safety_surveillance_using_online_media
# goldberg_2018_a_tabu_search_heuristic_for_smoke_term_curation_in_safety_defect_discovery
# amplayo_2018_incorporating_product_description_to_sentiment_topic_models_for_improved_aspect_based_sentiment_analysis
# law_2017_automated_defect_discovery_for_dishwasher_appliances_from_online_consumer_reviews
# mummalaneni_2018_social_media_analytics_for_quality_surveillance_and_safety_hazard_detection_in_baby_cribs
# pessach_2020_employees_recruitment_a_prescriptive_analytics_approach_via_machine_learning_and_mathematical_programming
# qiao_2018_the_impact_of_customer_reviews_on_product_innovation_empirical_evidence_in_mobile_apps
# sachan_2020_an_explainable_ai_decision_support_system_to_automate_loan_underwriting
# siering_2018_disentangling_consumer_recommendations_explaining_and_predicting_airline_recommendations_based_on_online_reviews
# srinivas_2019_topic_based_knowledge_mining_of_online_student_reviews_for_strategic_planning_in_universities
# xiang_2017_a_comparative_analysis_of_major_online_review_platforms_implications_for_social_media_analytics_in_hospitality_and_tourism
# zaman_2020_facebook_hospital_reviews_automated_service_quality_detection_and_relationships_with_patient_satisfaction
# zaman_2021_cross_category_defect_discovery_from_online_reviews_supplementing_sentiment_with_category_specific_semantics
# zhang_2018_product_innovation_based_on_online_review_data_mining_a_case_study_of_huawei_phones
# zhang_2021_mining_product_innovation_ideas_from_online_reviews
# huang_2018_analyst_information_discovery_and_interpretation_roles_a_topic_modeling_approach
# pucihar_2021_34th_bled_econference_digital_support_from_crisis_to_progressive_change_conference_proceedings
# wei_2019_discovering_bank_risk_factors_from_financial_statements_based_on_a_new_semi_supervised_text_mining_algorithm
# yang_2020_news_sentiment_credit_spreads_and_information_asymmetry
# grover_2018_creating_strategic_business_value_from_big_data_analytics_a_research_framework
# yang_2020_finbert_a_pretrained_language_model_for_financial_communications
# cambria_2017_sentiment_analysis_is_a_big_suitcase
# devlin_2019_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding
# palmer_2021_induction_of_a_sentiment_dictionary_for_financial_analyst_communication_a_data_driven_approach_balancing_machine_learning_and_human_intuition
# kiesel_2017_cds_spreads_as_an_independent_measure_of_credit_risk
# donovan_pucihar_2021_34th_bled_econference_digital_support_from_crisis_to_progressive_change_conference_proceedings_measuring_credit_risk_using_qualitative_disclosure
# lee_2016_investor_sentiment_and_credit_default_swap_spreads_during_the_global_financial_crisis
# ---------Expert Systems with Applications---------
# ozyurt_2021_a_new_topic_modeling_based_approach_for_aspect_extraction_in_aspect_based_sentiment_analysis_ss_lda
# girgin_2021_ranking_influencers_of_social_networks_by_semantic_kernels_and_sentiment_information
# altinel_2018_semantic_text_classification_a_survey_of_past_and_recent_advances
# altinel_2017_instance_labeling_in_semi_supervised_learning_with_meaning_values_of_words
# aktas_2022_turkish_sentiment_analysis_using_machine_learning_methods_application_on_online_food_order_site_reviews
# bae_2020_label_propagation_based_parallel_graph_partitioning_for_large_scale_graph_data
# bilgin_2017_sentiment_analysis_on_twitter_data_with_semi_supervised_doc2vec
# kemaloglu_2021_turkish_sentiment_analysis_on_social_media
# sahin_2017_turkish_document_classification_based_on_word2vec_and_svm_classifier
# wang_2022_investigation_of_pre_service_teachersconceptions_of_the_nature_of_science_based_on_the_lda_model
# kukreja_2022_machine_learning_models_for_mathematical_symbol_recognition_a_stem_to_stern_literature_analysis
# shan_2020_robust_encoder_decoder_learning_framework_for_offline_handwritten_mathematical_expression_recognition_based_on_a_multi_scale_deep_neural_network
# savin_2021_free_associations_of_citizens_and_scientists_with_economic_and_green_growth_a_computational_linguistics_analysis
# sakshi_2021_a_retrospective_study_on_handwritten_mathematical_symbols_and_expressions_classification_and_recognition
# rani_2021_an_extractive_text_summarization_approach_using_tagged_lda_based_topic_modeling
# abbaspour_onari_2021_a_medical_decision_support_system_for_predicting_the_severity_level_of_covid_19
# leong_2021_a_meta_analysis_of_consumer_innovation_resistance_is_there_a_cultural_invariance
# huang_2021_lda_topic_mining_of_light_food_customer_reviews_on_the_meituan_platform
# wu_2020_handwritten_mathematical_expression_recognition_via_paired_adversarial_learning
# nguyen_2020_cnn_based_spatial_classification_features_for_clustering_offline_handwritten_mathematical_expressions
# julca_aguilar_2020_a_general_framework_for_the_recognition_of_online_handwritten_graphics
# firdaus_2020_handwritten_mathematical_symbol_recognition_using_machine_learning_techniques_review
# le_2019_pattern_generation_strategies_for_improving_recognition_of_handwritten_mathematical_expressions
# kim_2019_research_paper_classification_systems_based_on_tf_idf_and_lda_schemes
# hidayatullah_2019_topic_modeling_of_weather_and_climate_condition_on_twitter_using_latent_dirichlet_allocation_lda
# zhang_2020_a_tree_blstm_based_recognition_system_for_online_handwritten_mathematical_expressions
# phan_2018_augmented_incremental_recognition_of_online_handwritten_mathematical_expressions
# sehra_2017_research_patterns_and_trends_in_software_effort_estimation
# onan_2017_hybrid_supervised_clustering_based_ensemble_scheme_for_text_classification
# breiner_2019_automatic_keyboard_layout_design_for_low_resource_latin_script_languages
# onan_2016_a_feature_selection_model_based_on_genetic_rank_aggregation_for_text_sentiment_classification
# phong_2017_a_new_method_for_displayed_mathematical_expression_detection_based_on_fft_and_svm
# guo_2018_research_on_mathematical_formula_knowledge_base_for_formula_recognition
# maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology
# hew_2019_computer_science_in_asean_a_ten_year_bibliometric_analysis_2009textendash2018
# tran_minh_khuong_2019_interactive_user_interface_for_recognizing_online_handwritten_mathematical_expressions_and_correcting_misrecognition
# lods_2019_fuzzy_visibility_graph_for_structural_analysis_of_online_handwritten_mathematical_expressions
# mahdavi_2019_icdar_2019_crohme__tfd_competition_on_recognition_of_handwritten_mathematical_expressions_and_typeset_formula_detection
# nguyen_2019_hybrid_cnn_gru_model_for_high_efficient_handwritten_digit_recognition
# onan_2019_mining_opinions_from_instructor_evaluation_reviews_a_deep_learning_approach
# tamburri_2021_success_and_failure_in_software_engineering_a_followup_systematic_literature_review
# wang_2020_icfhr_2020_competition_on_offline_recognition_and_spotting_of_handwritten_mathematical_expressions___offrashme
# wang_2020_recognizing_handwritten_mathematical_expressions_as_latex_sequences_using_a_multiscale_robust_neural_network
# chiyangwa_2021_natural_language_processing_techniques_to_reveal_human_computer_interaction_for_development_research_topics
# grimmer_2021_machine_learning_for_social_science_an_agnostic_approach
# onan_2020_sentiment_analysis_on_product_reviews_based_on_weighted_word_embeddings_and_deep_neural_networks
# page_2021_updating_guidance_for_reporting_systematic_reviews_development_of_the_prisma_2020_statement
# wang_2021_bayesian_text_classification_and_summarization_via_a_class_specified_topic_model
# wu_2021_graph_to_graph_towards_accurate_and_interpretable_online_handwritten_mathematical_expression_recognition
# yang_2021_understanding_service_providers_competency_in_knowledge_intensive_crowdsourcing_platforms_an_lda_approach
# zhao_2021_joint_optimisation_of_regular_and_demand_responsive_transit_services
# zhelezniakov_2021_online_handwritten_mathematical_expression_recognition_and_applications_a_survey
# zhou_2021_a_feature_selection_algorithm_of_decision_tree_based_on_feature_weight
# sadiq_2021_discrepancy_detection_between_actual_user_reviews_and_numeric_ratings_of_google_app_store_using_deep_learning
# kirilenko_2021_automated_topic_modeling_of_tourist_reviews_does_the_anna_karenina_principle_apply
# zhao_2020_a_weighted_hybrid_ensemble_method_for_classifying_imbalanced_data
# yan_2020_a_hybrid_scheme_based_one_vs_all_decision_trees_for_multi_class_classification_tasks
# shan_2020_learn_a_novel_incremental_learning_method_for_text_classification
# sann_2020_online_complaining_behavior_does_cultural_background_and_hotel_class_matter
# manosuthi_2020_impact_of_distance_on_the_arrivals_behaviours_and_attitudes_of_international_tourists_in_hong_kong_a_longitudinal_approach
# lundberg_2020_from_local_explanations_to_global_understanding_with_explainable_ai_for_trees
# gridach_2020_hybrid_deep_neural_networks_for_recommender_systems
# gregoriades_2020_electronic_word_of_mouth_analysis_for_new_product_positioning_evaluation
# gilboa_2020_the_role_of_culture_and_purchasing_power_parity_in_shaping_mall_shoppers_profiles
# dwivedi_2021_setting_the_future_of_digital_and_social_media_marketing_research_perspectives_and_research_propositions
# christodoulou_2020_combination_of_topic_modelling_and_decision_tree_classification_for_tourist_destination_marketing
# chang_2020_using_deep_learning_and_visual_analytics_to_explore_hotel_reviews_and_responses
# arrieta_2020_explainable_artificial_intelligence_xai_concepts_taxonomies_opportunities_and_challenges_toward_responsible_ai
# yen_2019_the_effects_of_hotel_attribute_performance_on_electronic_word_of_mouth_ewom_behaviors
# huang_2019_relationships_between_hofstedes_cultural_dimensions_and_tourist_satisfaction_a_cross_country_cross_sample_examination
# liu_2019_market_segmentation_a_multiple_criteria_approach_combining_preference_analysis_and_segmentation_decision
# korfiatis_2019_measuring_service_quality_from_unstructured_data_a_topic_modeling_application_on_airline_passengers_online_reviews
# laguna_2018_tabu_search
# chopard_2018_simulated_annealing
# blut_2018_testing_retail_marketing_mix_effects_on_patronage_a_meta_analysis
# gambhir_2017_recent_automatic_text_summarization_techniques_a_survey
# guo_2017_mining_meaning_from_online_ratings_and_reviews_tourist_satisfaction_analysis_using_latent_dirichlet_allocation
# mantovani_2016_hyper_parameter_tuning_of_a_decision_tree_induction_algorithm
# valdivia_2017_sentiment_analysis_in_tripadvisor
# kim_2018_the_effects_of_culture_on_consumerstextquotesingle_consumption_and_generation_of_online_reviews
# kotler_2010_principles_of_marketing
# li_2017_feature_selection_a_data_perspective
# liu_2018_a_unified_framework_for_detecting_author_spamicity_by_modeling_review_deviation
# radojevic_2018_the_effects_of_traveling_for_business_on_customer_satisfaction_with_hotel_services
# alami_2019_enhancing_unsupervised_neural_networks_based_text_summarization_with_word_embedding_and_ensemble_learning
# du_2019_techniques_for_interpretable_machine_learning
# gomez_2019_exploratory_study_on_class_imbalance_and_solutions_for_network_traffic_classification
# hollebeek_2019_digital_content_marketingtextquotesingles_role_in_fostering_consumer_engagement_trust_and_value_framework_fundamental_propositions_and_implications
# roberts_2019_lessbgreaterstmlessbgreater_an_lessigreaterrlessigreater_package_for_structural_topic_models
# epaminonda_2021_a_review_of_the_sociocultural_profile_of_cyprus_historical_background_current_features_change_and_diversity
# sharma_2020_photoacoustic_imaging_of_live_chicken_embryo_at_multiple_developmental_stages
# winter_2021_the_effects_of_trait_based_personalization_in_social_media_advertising
# araque_2017_enhancing_deep_learning_sentiment_analysis_with_ensemble_techniques_in_social_applications
# chen_2017_improving_sentiment_analysis_via_sentence_type_classification_using_bilstm_crf_and_cnn
# giatsoglou_2017_sentiment_analysis_leveraging_emotions_and_word_embeddings
# symitsi_2018_employees_online_reviews_and_equity_prices
# ye_2017_predicting_the_helpfulness_of_online_reviews_using_a_scripts_enriched_text_regression_model
# li_2018_big_data_in_tourism_research_a_literature_review
# law_2017_automated_defect_discovery_for_dishwasher_appliances_from_online_consumer_reviews
# lee_2018_assessment_of_airport_service_quality_a_complementary_approach_to_measure_perceived_service_quality_based_on_google_reviews
# kuhn_2018_using_structural_topic_modeling_to_identify_latent_topics_and_trends_in_aviation_incident_reports
# kim_2017_what_makes_tourists_feel_negatively_about_tourism_destinations_application_of_hybrid_text_mining_methodology_to_smart_destination_management
# hu_2017_the_effect_of_user_controllable_filters_on_the_prediction_of_online_hotel_reviews
# guo_2017_mining_meaning_from_online_ratings_and_reviews_tourist_satisfaction_analysis_using_latent_dirichlet_allocation
# geetha_2017_relationship_between_customer_sentiment_and_online_customer_ratings_for_hotels___an_empirical_analysis
# calheiros_2017_sentiment_classification_of_consumer_generated_online_reviews_using_topic_modeling
# ...
# miano_2022_mapping_a_pricing_process_through_a_fuzzy_inference_system_decision_support_for_a_small_business_entrepreneur
# vicedo_2020_a_bibliometric_overview_of_how_critical_success_factors_influence_on_enterprise_resource_planning_implementations
# aznar_sanchez_2018_forest_ecosystem_services_an_analysis_of_worldwide_research
# feng_2022_the_performance_of_topic_evolution_based_on_a_feature_maximization_measurement_for_the_linguistics_domain
# levin_2020_composite_technology_challenge_system_for_optimization_in_5g_communications
# pileggi_2021_knowledge_interoperability_and_re_use_in_empathy_mapping_an_ontological_approach
# velasco_munoz_2019_sustainable_irrigation_in_agriculture_an_analysis_of_global_research
# zhang_2021_topic_evolution_disruption_and_resilience_in_early_covid_19_research
# chen_2019_an_automatic_literature_knowledge_graph_and_reasoning_network_modeling_framework_based_on_ontology_and_natural_language_processing
# alfaro_garca_2020_a_citation_analysis_of_fuzzy_research_by_universities_and_countries
# mele_2021_a_new_method_for_the_design_of_knowledge_based_engineering_systems_for_manufacturing
# ma_2021_combining_topic_modeling_and_sao_semantic_analysis_to_identify_technological_opportunities_of_emerging_technologies
# liu_2019_predicting_the_evolution_of_physics_research_from_a_complex_network_perspective
# lu_2022_topic_change_point_detection_using_a_mixed_bayesian_model
# desta_2021_local_perceptions_of_ecosystem_services_and_human_induced_degradation_of_lake_ziway_in_the_rift_valley_region_of_ethiopia
# fan_2020_an_online_bayesian_approach_to_change_point_detection_for_categorical_data
# sharma_2022_journal_of_computer_information_systems_intellectual_and_conceptual_structure
# moosavi_2022_supply_chain_disruption_during_the_covid_19_pandemic_recognizing_potential_disruption_management_strategies
# aznar_sanchez_2019_the_worldwide_research_trends_on_water_ecosystem_services
# pineda_ospina_2019_tendencias_en_la_generacion_de_conocimiento_en_innovacion_en_el_campo_de_las_ciencias_administrativas
# liang_2022_mapping_the_knowledge_frontiers_and_evolution_of_decision_making_based_on_agent_based_modeling
# elgendi_2019_characteristics_of_a_highly_cited_article_a_machine_learning_perspective
# aznar_sanchez_2019_worldwide_research_trends_on_sustainable_land_use_in_agriculture
# peng_2021_effective_electricity_load_forecasting_using_enhanced_double_reservoir_echo_state_network
# chen_2020_a_topic_sensitive_trust_evaluation_approach_for_users_in_online_communities
# arencibia_jorge_2022_evolutionary_stages_and_multidisciplinary_nature_of_artificial_intelligence_research
# huang_2019_community_based_influence_maximization_for_viral_marketing
# hadzibeganovic_2019_nonconformity_of_cooperators_promotes_the_emergence_of_pure_altruism_in_tag_based_multi_agent_networked_systems
# trevisani_2018_chronological_corpora_curve_clustering_from_scientific_corpora_construction_to_knowledge_dynamics_discovery_through_word_life_cycles_clustering
# brahnam_2020_extraction_of_key_concept_relevance_graphs_from_fourteen_decades_of_psychoanalytic_journal_publications
# loglisci_2018_mining_microscopic_and_macroscopic_changes_in_network_data_streams
# yu_2019_bibliometric_analysis_on_the_evolution_of_applied_intelligence
# aznar_sanchez_2019_innovation_and_technology_for_sustainable_mining_activity_a_worldwide_research_assessment
# aznar_sanchez_2018_mining_waste_and_its_sustainable_management_advances_in_worldwide_research
# yu_2019_a_bibliometric_analysis_of_fuzzy_optimization_and_decision_making_2002__2017
# rincon_patino_2018_exploring_machine_learning_a_bibliometric_general_approach_using_citespace
# faust_2018_documenting_and_predicting_topic_changes_in_computers_in_biology_and_medicine_a_bibliometric_keyword_analysis_from_1990_to_2017
# trevisani_2018_learning_the_evolution_of_disciplines_from_scientific_literature_a_functional_clustering_approach_to_normalized_keyword_count_trajectories
# tuzzi_2018_introduction_tracing_the_history_of_a_discipline_through_quantitative_and_qualitative_analyses_of_scientific_literature
# zhang_2020_framework_of_computational_intelligence_enhanced_knowledge_base_construction_methodology_and_a_case_of_gene_related_cardiovascular_disease
# jebari_2021_the_use_of_citation_context_to_detect_the_evolution_of_research_topics_a_large_scale_analysis
# trevisani_2018_functional_data_analysis_and_knowledge_based_systems
# park_2019_using_text_network_analysis_for_analyzing_academic_papers_in_nursing
# he_2018_an_evidential_dynamical_model_to_predict_the_interference_effect_of_categorization_on_decision_making_results
# trujillo_2018_expanding_and_shifting_trends_in_recent_alternative_fuels_literature
# lei_2018_uncovering_design_topics_by_visualizing_and_interpreting_keyword_data
# kim_2019_multi_co_training_for_document_classification_using_various_document_representations_tf_idf_lda_and_doc2vec
# novotna_2020_topic_modelling_of_the_czech_supreme_court_decisions
# sengupta_2021_ljst_a_semi_supervised_joint_sentiment_topic_model_for_short_texts
# yldrm_2020_microblog_topic_identification_using_linked_open_data
# park_2021_dynamic_emotions_of_supporters_and_opponents_of_anti_racism_movement_from_george_floyd_protests
# shadrova_2022_it_may_be_in_the_structure_not_the_combinations_graph_metrics_as_an_alternative_to_statistical_measures_in_corpus_linguistic_research
# pattnaik_2022_perspectives_of_non_expert_users_on_cyber_security_and_privacy_an_analysis_of_online_discussions_on_twitter
# truica_2021_a_deep_learning_architecture_for_audience_interest_prediction_of_news_topic_on_social_media
# chai_2022_comparison_of_text_preprocessing_methods
# torregrosa_2022_a_survey_on_extremism_analysis_using_natural_language_processing_definitions_literature_review_trends_and_challenges
# salvatore_2022_corporate_social_responsibility_activities_through_twitter_from_topic_model_analysis_to_indexes_measuring_communication_characteristics
# wang_2022_linguistic_understandability_signal_observability_funding_opportunities_and_crowdfunding_campaigns
# kars_unluoglu_2022_migrants_as_dissonant_harmony_seekers_and_migrant_life_in_foam
# clissa_2022_analyzing_wlcg_file_transfer_errors_through_machine_learning_an_automatic_pipeline_to_support_post_mortem_distributed_data_management
# phan_2021_an_approach_for_a_decision_making_support_system_based_on_measuring_the_user_satisfaction_level_on_twitter
# narhari_2021_automated_diagnosis_of_diabetic_retinopathy_enabled_by_optimized_thresholding_based_blood_vessel_segmentation_and_hybrid_classifier
# chang_2021_what_are_people_concerned_about_during_the_pandemic_detecting_evolving_topics_about_covid_19_from_twitter
# pathan_2022_cross_domain_aspect_detection_and_categorization_using_machine_learning_for_aspect_based_opinion_mining
# fraguas_sanchez_2022_actively_targeted_nanomedicines_in_breast_cancer_from_pre_clinal_investigation_to_clinic
# yavari_2022_event_prediction_in_social_network_through_twitter_messages_analysis
# mohotti_2020_discovering_communities_with_sgns_modelling_based_network_connections_and_text_communications_clustering
# guo_2022_two_dimensional_bhattacharyya_bound_linear_discriminant_analysis_with_its_applications
# olaya_2022_non_negative_matrix_factorization_for_dimensionality_reduction
# lokku_2022_optimized_scale_invariant_feature_transform_with_local_tri_directional_patterns_for_facial_expression_recognition_with_deep_learning_model
# khalili_2022_the_ineffectiveness_of_domain_specific_word_embedding_models_for_gui_test_reuse
# egger_2021_identifying_hidden_semantic_structures_in_instagram_data_a_topic_modelling_comparison
# si_2022_federated_non_negative_matrix_factorization_for_short_texts_topic_modeling_with_mutual_information
# cheng_2022_a_simple_interpretable_method_to_identify_surprising_topic_shifts_in_scientific_fields
# pipanmekaporn_2019_learning_short_text_representation_using_non_negative_matrix_factorization_and_word_semantic_correlations
# egger_2022_a_topic_modeling_comparison_between_lda_nmf_top2vec_and_bertopic_to_demystify_twitter_posts
# saura_2021_using_data_mining_techniques_to_explore_security_issues_in_smart_living_environments_in_twitter
# parlina_2021_exposing_emerging_trends_in_smart_sustainable_city_research_using_deep_autoencoders_based_fuzzy_c_means
# murshed_2022_short_text_topic_modelling_approaches_in_the_context_of_big_data_taxonomy_survey_and_analysis
# rivas_2021_my_trac_system_for_recommendation_of_points_of_interest_on_the_basis_of_twitter_profiles
# wangwatcharakul_2020_dynamic_collaborative_filtering_based_on_user_preference_drift_and_topic_evolution
# rudiger_2021_the_explanatory_power_of_citations_a_new_approach_to_unpacking_impact_in_science
# cheng_2020_tracking_disaster_footprints_with_social_streaming_data
# li_2020_a_semi_explicit_short_text_retrieval_method_combining_wikipedia_features
# luber_2021_identifying_topical_shifts_in_twitter_streams_an_integration_of_non_negative_matrix_factorisation_sentiment_analysis_and_structural_break_models_for_large_scale_data
# habbat_2021_topic_modeling_and_sentiment_analysis_with_lda_and_nmf_on_moroccan_tweets
# hu_2020_incremental_rapidly_grouping_aggregation_method_for_similar_web_news_headline
# wang_2021_technology_hotspot_tracking_topic_discovery_and_evolution_of_chinas_blockchain_patents_based_on_a_dynamic_lda_model
# wei_2020_short_text_embedding_autoencoders_with_attention_based_neighborhood_preservation
# truica_2021_tlatr_automatic_topic_labeling_using_automatic_domain_specific_term_recognition
# billington_2020_thats_classified_inventing_a_new_patent_taxonomy
# albalawi_2020_using_topic_modeling_methods_for_short_text_data_a_comparative_analysis
# gadelrab_2020_novel_semantic_tagging_detection_algorithms_based_non_negative_matrix_factorization
# kang_2022_resilience_in_web_based_mental_health_communities_building_a_resilience_dictionary_with_semiautomatic_text_analysis
# luo_2022_exploring_energy_saving_refrigerators_through_online_e_commerce_reviews_an_augmented_mining_model_based_on_machine_learning_methods
# truica_2021_topic_based_document_level_sentiment_analysis_using_contextual_cues
# peikert_2021_objective_functions_to_determine_the_number_of_topics_for_topic_modeling
# chen_2021_tmhol_topic_memory_model_for_detection_of_hate_speech_and_offensive_language
# universidade_estadual_do_maranhao_uema_and_sousa_2020_analise_do_setor_de_telecomunicac_c_ao_brasileiro_uma_vis_ao_sobre_reclamac_c_oes
# guven_2019_comparison_of_topic_modeling_methods_for_type_detection_of_turkish_news
# mirhadi_2022_a_solution_approach_for_cardinality_minimization_problem_based_on_fractional_programming
# baraibar_diez_2020_mapping_social_impact_a_bibliometric_analysis
# luo_2021_identification_of_research_priorities_during_the_covid_19_pandemic_implications_for_its_management
# erfanian_2022_an_evolutionary_event_detection_model_using_the_matrix_decomposition_oriented_dirichlet_process
# guven_2019_comparison_method_for_emotion_detection_of_twitter_users
# vasquez_henriquez_2020_tweets_on_the_go_gender_differences_in_transport_perception_and_its_discussion_on_social_media
# luo_2021_exploring_destination_image_through_online_reviews_an_augmented_mining_model_using_latent_dirichlet_allocation_combined_with_probabilistic_hesitant_fuzzy_algorithm
# liu_2021_answer_keyword_generation_for_community_question_answering_by_multiaspect_gamma__poisson_matrix_completion
# shams_2020_lisa_language_independent_method_for_aspect_based_sentiment_analysis
# monselise_2021_topics_and_sentiments_of_public_concerns_regarding_covid_19_vaccines_social_media_trend_analysis
# lee_2021_construction_disputes_and_associated_contractual_knowledge_discovery_using_unstructured_text_heavy_data_legal_cases_in_the_united_kingdom
# ye_2021_cdcn_a_new_nmf_based_community_detection_method_with_community_structures_and_node_attributes
# valero_2022_topic_modeling_on_podcast_short_text_metadata
# oliveira_moraes_2021_clustering_introductory_computer_science_exercises_using_topic_modeling_methods
# chen_2019_research_on_key_technology_of_web_hierarchical_topic_detection_and_evolution_based_on_behaviour_tracking_analysis
# luo_2021_exploring_chinas_5a_global_geoparks_through_online_tourism_reviews_a_mining_model_based_on_machine_learning_approach
# shadrova_2021_topic_models_do_not_model_topics_epistemological_remarks_and_steps_towards_best_practices
# monselise_2021_topics_and_sentiments_of_public_concerns_regarding_covid_19_vaccines_social_media_trend_analysis_preprint
# wang_2019_where_does_lda_sit_for_github
# rela_2021_optimized_segmentation_and_classification_for_liver_tumor_segmentation_and_classification_using_oppositionbased_spotted_hyena_optimization
# salcedo_sanz_2020_machine_learning_information_fusion_in_earth_observation_a_comprehensive_review_of_methods_applications_and_data_sources
# douglas_smith_2020_certain_trends_in_uncertainty_and_sensitivity_analysis_an_overview_of_software_tools_and_techniques
# petrusevich_2019_analysis_of_students_final_qualification_theses_using_text_loans_detection_systems
# yang_2020_leveraging_global_and_local_topic_popularities_for_lda_based_document_clustering
# massanori_2020_death_of_a_software_ecosystem_a_developer_relations_devrel_perspective
# yildirim_2020_microblog_topic_identification_using_linked_open_data
# agnihotri_2019_soft_voting_technique_to_improve_the_performance_of_global_filter_based_feature_selection_in_text_corpus
# hagerer_2021_an_analysis_of_programming_course_evaluations_before_and_after_the_introduction_of_an_autograder
# jing_2022_a_hierarchical_spatial_unit_partitioning_approach_for_finegrained_urban_functional_region_identification
# likhitha_2019_a_detailed_survey_on_topic_modeling_for_document_and_short_text_data
# junior_2020_an_extensive_analysis_of_online_restaurant_reviews_a_case_study_of_the_amazonian_culinary_tourism
# liu_2020_nadsr_a_network_anomaly_detection_scheme_based_on_representation
# wan_2020_a_novel_sentence_embedding_based_topic_detection_method_for_microblogs
# safaryan_2021_semantic_recommendation_system_for_bilingual_corpus_of_academic_papers
# fu_2021_output_based_transfer_learning_in_genetic_programming_for_document_classification
# zhou_2020_a_discriminative_convolutional_neural_network_with_context_aware_attention
# zhou_2022_increasing_naturalness_of_human__machine_dialogue_the_users_choices_inference_of_options_in_machine_raised_questions
# yan_2019_application_of_a_parallel_particle_swarm_optimization_long_short_term_memory_model_to_improve_water_quality_data
# trinh_2021_nested_variational_autoencoder_for_topic_modelling_on_microtexts_with_word_vectors
# diallo_2021_deep_embedding_clustering_based_on_contractive_autoencoder
# wei_2020_bilstm_with_multi_polarity_orthogonal_attention_for_implicit_sentiment_analysis
# ijirana_2020_patterns_of_metacognitive_skills_and_external_representation_of_students_in_chemistry_problem_solving
# cholissodin_2021_social_computing_to_create_government_public_policy_document_blueprint_draft_based_on_social_media_data_about_covid_19_using_lstm_and_mmr_hybrid_algorithms
# pathik_2021_an_efficient_sentiment_analysis_using_topic_model_based_optimized_recurrent_neural_network
# yu_2021_additive_densenet_dense_connections_based_on_simple_addition_operations
# woo_2020_content_noise_detection_model_using_deep_learning_in_web_forums
# ma_2021_an_image_enhanced_topic_modeling_method_for_neuroimaging_literature
# ganji_2020_kernel_compositional_embedding_and_its_application_in_linguistic_structured_data_classification
# oyedotun_2021_deep_network_compression_with_teacher_latent_subspace_learning_and_lasso
# van_houdt_2020_a_review_on_the_long_short_term_memory_model
# suarez_cansino_2022_automatic_generation_of_learning_outcomes_based_on_long_short__term_memory_artificial_neural_network1
# sheng_2020_a_topic_learning_pipeline_for_curating_brain_cognitive_researches
# li_2021_an_improved_term_weighting_method_based_on_relevance_frequency_for_text_classification
# yavary_2021_document_embedding_using_piped_elm_gan_model
# geng_2022_webpage_retrieval_based_on_query_by_example_for_think_tank_construction
# rezaeenour_2022_systematic_review_of_content_analysis_algorithms_based_on_deep_neural_networks
# ---------Pattern Recognition---------

# %%
bs_selection = [
    'xiang_2017_a_comparative_analysis_of_major_online_review_platforms_implications_for_social_media_analytics_in_hospitality_and_tourism',
    'liu_2017_an_investigation_of_brand_related_user_generated_content_on_twitter',
    'kim_2019_an_ontology_based_labeling_of_influential_topics_using_topic_network_analysis',
    'huang_2018_analyst_information_discovery_and_interpretation_roles_a_topic_modeling_approach',
    'maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology',
    'karami_2018_characterizing_diabetes_diet_exercise_and_obesity_comments_on_twitter',
    'aletras_2017_evaluating_topic_representations_for_exploring_document_collections',
    'smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels',
    'savin_2021_free_associations_of_citizens_and_scientists_with_economic_and_green_growth_a_computational_linguistics_analysis',
    'syed_2017_full_text_or_abstract_examining_topic_coherence_scores_using_latent_dirichlet_allocation',
    'li_2020_global_surveillance_of_covid_19_by_mining_news_media_using_a_multi_source_dynamic_embedded_topic_model',
    'alp_2018_identifying_topical_influencers_on_twitter_based_on_user_behavior_and_network_topology',
    'morstatter_2017_in_search_of_coherence_and_consensus_measuring_the_interpretability_of_statistical_topics',
    'light_2017_managing_the_boundaries_of_taste_culture_valuation_and_computational_social_science',
    'clare_2019_modelling_research_topic_trends_in_community_forestry',
    'nerghes_2019_narratives_of_the_refugee_crisis_a_comparative_study_of_mainstream_media_and_twitter',
    'campos_2020_recommendation_system_for_knowledge_acquisition_in_moocs_ecosystems',
    'zhang_2017_scientific_evolutionary_pathways_identifying_and_visualizing_relationships_for_scientific_topics',
    'bagozzi_2018_the_politics_of_scrutiny_in_human_rights_monitoring_evidence_from_structural_topic_models_of_us_state_department_human_rights_reports',
    'dahal_2019_topic_modeling_and_sentiment_analysis_of_global_climate_change_tweets',
    'grajzl_2019_toward_understanding_17th_century_english_culture_a_structural_topic_model_of_francis_bacontextquotesingles_ideas',
    'hoang_2019_towards_autoencoding_variational_inference_for_aspect_based_opinion_summary',
    'herzog_2018_transfer_topic_labeling_with_domain_specific_knowledge_base_an_analysis_of_uk_house_of_commons_speeches_1935_2014',
    'karami_2019_twitter_speaks_a_case_of_national_disaster_situational_awareness',
    'gourru_2018_united_we_stand_using_multiple_strategies_for_topic_labeling',
    'kuhn_2018_using_structural_topic_modeling_to_identify_latent_topics_and_trends_in_aviation_incident_reports',
    'chen_2020_what_are_moocs_learners_concerns_text_analysis_of_reviews_for_computer_science_courses'
]

fs_selection = [
    'stamolampros_2019_job_satisfaction_and_employee_turnover_determinants_in_high_contact_services_insights_from_employeesonline_reviews',
    'chen_2020_detecting_latent_topics_and_trends_in_educational_technologies_over_four_decades_using_structural_topic_modeling_a_retrospective_of_all_volumes_of_computers__education',
    'stamolampros_2020_harnessing_the_wisdom_of_employees_from_online_reviews',
    'amat_lefort_2022_quality_40_big_data_analytics_to_explore_service_quality_attributes_and_their_relation_to_user_sentiment_in_airbnb_reviews',
    'ding_2020_employing_structural_topic_modelling_to_explore_perceived_service_quality_attributes_in_airbnb_accommodation',
    'yang_2021_revealing_industry_challenge_and_business_response_to_covid_19_a_text_mining_approach',
    'hagen_2019_open_data_visualizations_and_analytics_as_tools_for_policy_making',
    'monselise_2021_topics_and_sentiments_of_public_concerns_regarding_covid_19_vaccines_social_media_trend_analysis',
    'aman_2021_listen_to_e_scooter_riders_mining_rider_satisfaction_factors_from_app_store_reviews',
    'luo_2020_topic_modelling_for_theme_park_online_reviews_analysis_of_disneyland',
    'meena_2022_online_food_delivery_companies_performance_and_consumers_expectations_during_covid_19_an_investigation_using_machine_learning_approach',
    'singh_2022_modeling_the_public_attitude_towards_organic_foods_a_big_data_and_text_mining_approach',
    'wang_2020_a_topic_based_patent_analytics_approach_for_exploring_technological_trends_in_smart_manufacturing',
    'he_2021_automatic_topic_labeling_using_graph_based_pre_trained_neural_embedding',
    'chen_2020_a_structural_topic_modeling_based_bibliometric_study_of_sentiment_analysis_literature',
    'chen_2022_a_decade_of_sentic_computing_topic_modeling_and_bibliometric_analysis',
    'yoo_2023_exploring_the_nexus_between_food_and_vegn_lifestyle_via_text_mining_based_online_community_analytics',
    'chung_2022_understanding_music_streaming_services_via_text_mining_of_online_customer_reviews',
    'jebari_2021_the_use_of_citation_context_to_detect_the_evolution_of_research_topics_a_large_scale_analysis',
    'huang_2022_identification_of_topic_evolution_network_analytics_with_piecewise_linear_representation_and_word_embedding',
    'zhang_2021_topic_evolution_disruption_and_resilience_in_early_covid_19_research',
    'ebadi_2021_understanding_the_temporal_evolution_of_covid_19_research_through_machine_learning_and_natural_language_processing',
    'barrera_barrera_2022_selecting_the_appropriate_leading_journal_in_hospitality_and_tourism_research_a_guide_based_on_the_topic_journal_fit_and_the_jcr_impact_factor',
    'truica_2021_tlatr_automatic_topic_labeling_using_automatic_domain_specific_term_recognition',
    'he_2019_automatic_labeling_of_topic_models_using_graph_based_ranking',
    'rosati_2022_moving_beyond_word_lists_towards_abstractive_topic_labels_for_human_like_topics_of_scientific_documents',
    'he_2021_automatic_topic_labeling_model_with_paired_attention_based_on_pre_trained_deep_neural_network',
    'ojo_2021_what_matters_most_to_patients_on_the_core_determinants_of_patient_experience_from_free_text_feedback',
    'scelsi_2021_principled_analysis_of_energy_discourse_across_domains_with_thesaurus_based_automatic_topic_labeling',
    'symitsi_2020_the_informational_value_of_employee_online_reviews',
    'chin_2019_ondemand_recent_personal_tweets_summarization_on_mobile_devices'
]

cite_key_trim_regex = re.compile('(^([a-z]+_)+[0-9]+)')

# %%
# Initial selection + all BS papers after query
# Papers from initial selection are colored skyblue
# Selected papers from BS are colored mistyrose
# Node size increases based on nr of incoming edges
def build_bs_graph(path, venues, snowb_selection, print_rank = False, min_incoming_edges = 1, selection_only = False):
    snowb_style = []
    incoming_edges = {}
    year_groups = {}

    # Count incoming edges for referenced papers
    for key in venues:
        for venue in venues[key]:
            with os.scandir(f'{path}/{key}/{venue}') as it:
                for entry in it:
                    if entry.name.endswith(".bib") and entry.is_file():
                        source = entry.name.replace('.bib','')
                        if(source not in incoming_edges): 
                            incoming_edges[source] = 0
                            year = cite_key_trim_regex.search(source).group()[-4:]
                            if(year not in year_groups): year_groups[year] = [source]
                            else: year_groups[year].append(source)
                        with open(entry, 'r') as fp:
                            db = biblib.bib.Parser().parse(fp, log_fp=sys.stderr).get_entries()
                        
                        for ent in db.values():
                            cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])

                            if(selection_only == False or cite_key in snowb_selection):
                                if(cite_key in incoming_edges): incoming_edges[cite_key] += 1
                                else: incoming_edges[cite_key] = 1

                                year = cite_key_trim_regex.search(cite_key).group()[-4:]
                                if(year not in year_groups): year_groups[year] = [cite_key]
                                else: year_groups[year].append(cite_key)

    print('digraph G {')
    for key in venues:
        for venue in venues[key]:
            with os.scandir(f'{path}/{key}/{venue}') as it:
                for entry in it:
                    if entry.name.endswith(".bib") and entry.is_file():
                        source = entry.name.replace('.bib','')
                        with open(entry, 'r') as fp:
                            db = biblib.bib.Parser().parse(fp, log_fp=sys.stderr).get_entries()

                        out_count = 0 # Avoid generating initial selection nodes with no outgoing edges
                        print_list = []
                        for ent in db.values():
                            cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])

                            if(selection_only == False or cite_key in snowb_selection):
                                if(incoming_edges[cite_key] >= min_incoming_edges):
                                    if(out_count == 0):
                                        print_list.append(f'\t{source} [label={cite_key_trim_regex.search(source).group()} color=skyblue style=filled fixedsize=true width={2} height={2}]\n')
                                        print_list.append(f'\t{source} -> {{')
                                    out_count += 1

                                    size_increase = 1 if incoming_edges[cite_key] == 0 else math.log(incoming_edges[cite_key]) + 1
                                    if cite_key in snowb_selection: 
                                        snowb_style.append(f'\t{cite_key} [label={cite_key_trim_regex.search(cite_key).group()} color=mistyrose style=filled fixedsize=true width={2 * size_increase} height={2 * size_increase}]')
                                    else:
                                        snowb_style.append(f'\t{cite_key} [label={cite_key_trim_regex.search(cite_key).group()} fixedsize=true width={2 * size_increase} height={2 * size_increase}]')
                        
                                    print_list.append(f'{cite_key}; ')
                        for print_str in print_list: print(print_str, end='') 
                        if(len(print_list) > 0): print(f'}}')

    # Color FS papers
    for snowb_paper_style in snowb_style: print(snowb_paper_style)

    # Sort by publication year
    year_keys = list(year_groups.keys())
    year_keys.sort()
    year_groups = {i: year_groups[i] for i in year_keys}

    if(print_rank):
        for year in year_groups:
            print(f'\t{{ rank = same; ', end='')
            for paper in year_groups[year]:
                print(f'{paper}; ', end='')
            print('}')

    print('}')

# %%
# Initial selection + all FS papers after query
# Papers from initial selection are colored skyblue
# Selected papers from FS are colored lightgoldenrodyellow
# Node size increases based on nr of incoming edges
def build_fs_graph(path, venues, snowb_selection, print_rank = False, min_outgoing_edges = 1, selection_only = False):
    snowb_style = []
    incoming_edges = {}
    outgoing_edges = {}
    year_groups = {}

    # Count incoming edges for initial selection
    for key in venues:
        for venue in venues[key]:
            with os.scandir(f'{path}/{key}/{venue}') as it:
                for entry in it:
                    if entry.name.endswith(".bib") and entry.is_file():
                        source = entry.name.replace('.bib','')
                        if(source not in incoming_edges): 
                            incoming_edges[source] = 0
                            year = cite_key_trim_regex.search(source).group()[-4:]
                            if(year not in year_groups): year_groups[year] = [source]
                            else: year_groups[year].append(source)
                        with open(entry, 'r') as fp:
                            db = biblib.bib.Parser().parse(fp, log_fp=sys.stderr).get_entries()
                        
                        for ent in db.values():
                            cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])

                            if(selection_only == False or cite_key in snowb_selection):
                                incoming_edges[source] += 1
                                if(cite_key in outgoing_edges): outgoing_edges[cite_key] += 1
                                else: outgoing_edges[cite_key] = 1

                                year = cite_key_trim_regex.search(cite_key).group()[-4:]
                                if(year not in year_groups): year_groups[year] = [cite_key]
                                else: year_groups[year].append(cite_key)

    print('digraph G {')
    for key in venues:
        for venue in venues[key]:
            with os.scandir(f'{path}/{key}/{venue}') as it:
                for entry in it:
                    if entry.name.endswith(".bib") and entry.is_file():
                        source = entry.name.replace('.bib','')

                        if(incoming_edges[source] != 0): # Avoid generating initial selection nodes with no incoming edges
                            size_increase = math.log(incoming_edges[source]) + 1
                            print(f'\t{source} [label={cite_key_trim_regex.search(source).group()} color=skyblue style=filled fixedsize=true width={2 * size_increase} height={2 * size_increase}]')
                            with open(entry, 'r') as fp:
                                db = biblib.bib.Parser().parse(fp, log_fp=sys.stderr).get_entries()

                            print(f'\t{{', end='')
                            for ent in db.values():
                                cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])
                                if(selection_only == False or cite_key in snowb_selection):
                                    if(outgoing_edges[cite_key] >= min_outgoing_edges):
                                        if cite_key in snowb_selection: 
                                            snowb_style.append(f'\t{cite_key} [label={cite_key_trim_regex.search(cite_key).group()} color=lightgoldenrodyellow style=filled fixedsize=true width={2} height={2}]')
                                        else:
                                            snowb_style.append(f'\t{cite_key} [label={cite_key_trim_regex.search(cite_key).group()} fixedsize=true width={2} height={2}]')
                            
                                        print(f'{cite_key}; ', end='')
                            print(f'}} -> {source}')

    # Color FS papers
    for snowb_paper_style in snowb_style: print(snowb_paper_style)

    # Sort by publication year
    year_keys = list(year_groups.keys())
    year_keys.sort()
    year_groups = {i: year_groups[i] for i in year_keys}

    if(print_rank):
        for year in year_groups:
            print(f'\t{{ rank = same; ', end='')
            for paper in year_groups[year]:
                print(f'{paper}; ', end='')
            print('}')

    print('}')

# %%
build_bs_graph('../References/Snowballing/Backward snowballing (Outgoing references)', venues, bs_selection, min_incoming_edges=1, selection_only=False)
# Out:
# digraph G {
# 	card_2018_neural_models_for_documents_with_metadata [label=card_2018 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	card_2018_neural_models_for_documents_with_metadata -> {boyd_graber_2017_applications_of_topic_models; srivastava_2017_autoencoding_variational_inference_for_topic_models; lau_2017_topically_driven_neural_language_model; he_2017_efficient_correlated_topic_modeling_with_topic_embedding; benton_2018_deep_dirichlet_multinomial_regression; }
# 	wu_2020_neural_mixed_counting_models_for_dispersed_topic_discovery [label=wu_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	wu_2020_neural_mixed_counting_models_for_dispersed_topic_discovery -> {zhou_2016_nonparametric_bayesian_negative_binomial_factor_analysis; srivastava_2017_autoencoding_variational_inference_for_topic_models; zhao_2019_variational_autoencoders_for_sparse_and_overdispersed_discrete_data; nan_2019_topic_modeling_with_wasserstein_autoencoders; naesseth_2017_reparameterization_gradients_through_acceptance_rejection_sampling_algorithms; miao_2017_discovering_discrete_latent_topics_with_neural_variational_inference; gupta_2019_document_informed_neural_autoregressive_topic_models_with_distributional_prior; }
# 	maiti_2019_spatial_aggregation_facilitates_discovery_of_spatial_topics [label=maiti_2019 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	maiti_2019_spatial_aggregation_facilitates_discovery_of_spatial_topics -> {choi_2018_topicontiles_tile_based_spatio_temporal_event_analytics_via_exclusive_topic_modeling_on_social_media; giorgi_2018_the_remarkable_benefit_of_user_level_aggregation_for_lexical_based_population_level_predictions; nugroho_2016_using_time_sensitive_interactions_to_improve_topic_derivation_in_twitter; shin_2017_stexnmf_spatio_temporally_exclusive_topic_discovery_for_anomalous_event_detection; steinskog_2017_twitter_topic_modeling_by_tweet_aggregation; }
# 	huang_2018_phrasectm_correlated_topic_modeling_on_phrases_within_markov_random_fields [label=huang_2018 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	huang_2018_phrasectm_correlated_topic_modeling_on_phrases_within_markov_random_fields -> {shang_2018_automated_phrase_mining_from_massive_text_corpora; huang_2017_category_level_transfer_learning_from_knowledge_base_to_microblog_stream_for_accurate_event_detection; he_2017_efficient_correlated_topic_modeling_with_topic_embedding; }
# 	ahmadvand_2019_concet_entity_aware_topic_classification_for_open_domain_conversational_agents [label=ahmadvand_2019 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	ahmadvand_2019_concet_entity_aware_topic_classification_for_open_domain_conversational_agents -> {yamada_2017_learning_distributed_representations_of_texts_and_entities_from_knowledge_base; wang_2017_combining_knowledge_with_deep_convolutional_neural_networks_for_short_text_classification; venkatesh_2018_on_evaluating_and_comparing_open_domain_dialog_systems; ram_2018_conversational_ai_the_science_behind_the_alexa_prize; krause_2017_edina_building_an_open_domain_socialbot_with_self_dialogues; khatri_2018_contextual_topic_modeling_for_dialog_systems; joty_2018_coherence_modeling_of_asynchronous_conversations_a_neural_entity_grid_approach; guo_2018_topic_based_evaluation_for_conversational_bots; conneau_2016_very_deep_convolutional_networks_for_text_classification; cer_2018_universal_sentence_encoder; bojanowski_2016_enriching_word_vectors_with_subword_information; }
# 	hosseiny_marani_2022_one_rating_to_rule_them_all_evidence_of_multidimensionality_in_human_assessment_of_topic_labeling_quality [label=hosseiny_marani_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	hosseiny_marani_2022_one_rating_to_rule_them_all_evidence_of_multidimensionality_in_human_assessment_of_topic_labeling_quality -> {underwood_2019_distant_horizons_digital_evidence_and_literary_change; vaccaro_2019_contestability_in_algorithmic_systems; wang_2019_balanced_datasets_are_not_enough_estimating_and_mitigating_gender_bias_in_deep_image_representations; tapal_2017_the_sense_of_agency_scale_a_measure_of_consciously_perceived_control_over_onetextquotesingles_mind_body_and_the_immediate_environment; wang_2019_implicit_gender_biases_in_professional_software_development_an_empirical_study; woodruff_2018_a_qualitative_exploration_of_perceptions_of_algorithmic_fairness; yang_2018_investigating_how_experienced_ux_designers_effectively_work_with_machine_learning; zafar_2016_fairness_beyond_disparate_treatment_amp_disparate_impact_learning_classification_without_disparate_mistreatment; smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels; schwemmer_2020_diagnosing_gender_bias_in_image_recognition_systems; scheuerman_2019_how_computers_see_gender_an_evaluation_of_gender_classification_in_commercial_facial_analysis_services; robertson_2018_auditing_the_personalization_and_composition_of_politically_related_search_engine_results_pages; robertson_2018_auditing_partisan_audience_bias_within_google_search; nelson_2017_computational_grounded_theory_a_methodological_framework; moreira_2018_image_provenance_analysis_at_scale; mantyla_2018_measuring_lda_topic_stability_from_clusters_of_replicated_runs; lau_2017_topically_driven_neural_language_model; kulshrestha_2017_quantifying_search_bias_investigating_sources_of_bias_for_political_searches_in_social_media; kleinberg_2017_human_decisions_and_machine_predictions; john_2019_the_case_of_computer_science_education_employment_gender_and_raceethnicity_in_silicon_valley_1980textendash2015; jiang_2021_supporting_serendipity_opportunities_and_challenges_for_human_ai_collaboration_in_qualitative_analysis; hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence; hoffman_2017_evaluating_a_computational_approach_to_labeling_politeness_challenges_for_the_application_of_machine_classification_to_social_computing_data; hirsch_2017_designing_contestability; fiebrink_2018_introduction_to_the_special_issue_on_human_centered_machine_learning; dove_2017_ux_design_innovation_challenges_for_working_with_machine_learning_as_a_design_material; cui_2018_learning_to_evaluate_image_captioning; corbett_davies_2018_the_measure_and_mismeasure_of_fairness_a_critical_review_of_fair_machine_learning; clementson_2017_truth_bias_and_partisan_bias_in_political_deception_detection; buolamwini_2018_gender_shades_intersectional_accuracy_disparities_in_commercial_gender_classification; baumer_2020_topicalizer_reframing_core_concepts_in_machine_learning_visualization_by_co_designing_for_interpretivist_scholarship; }
# 	nouri_2020_mining_crowdsourcing_problems_from_discussion_forums_of_workers [label=nouri_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	nouri_2020_mining_crowdsourcing_problems_from_discussion_forums_of_workers -> {berg_2018_digital_labour_platforms_and_the_future_of_work_towards_decent_work_in_the_online_world; edlund_2017_participant_crosstalk_issues_when_using_the_mechanical_turk; xia_2017_our_privacy_needs_to_be_protected_at_all_costs_crowd_workers_privacy_experiences_on_amazon_mechanical_turk; lippe_2018_organizational_worktextendashlife_policies_and_the_gender_wage_gap_in_european_workplaces; shu_2021_privacy_preserving_task_recommendation_services_for_crowdsourcing; schwartz_2018_embedded_in_the_crowd_creative_freelancers_crowdsourced_work_and_occupational_community; sannon_2019_privacy_power_and_invisible_labor_on_amazon_mechanical_turk; guth_2017_finding_the_diamond_in_the_rough_exploring_communication_and_platform_in_crowdsourcing_performance; gadiraju_2017_clarity_is_a_worthwhile_quality_on_the_role_of_task_clarity_in_microtask_crowdsourcing; }
# 	yin_2022_improving_deep_embedded_clustering_via_learning_cluster_level_representations [label=yin_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	yin_2022_improving_deep_embedded_clustering_via_learning_cluster_level_representations -> {ma_2019_learning_representations_for_time_series_clustering; zhao_2021_a_relation_oriented_clustering_method_for_open_relation_extraction; zhang_2018_whai_weibull_hybrid_autoencoding_inference_for_deep_topic_modeling; zhang_2021_supporting_clustering_with_contrastive_learning; zeng_2018_topic_memory_networks_for_short_text_classification; yang_2020_adversarial_learning_for_robust_deep_clustering; yang_2019_deep_clustering_by_gaussian_mixture_variational_autoencoders_with_graph_embedding; xu_2017_self_taught_convolutional_neural_networks_for_short_text_clustering; wu_2018_tracing_fake_news_footprints_characterizing_social_media_messages_by_how_they_propagate; wu_2019_deep_comprehensive_correlation_mining_for_image_clustering; wang_2020_friendly_topic_assistant_for_transformer_based_abstractive_summarization; wang_2020_neural_topic_model_with_attention_for_supervised_learning; wang_2019_topic_guided_variational_autoencoders_for_text_generation; van_gansbeke_2020_scan_learning_to_classify_images_without_labels; tsai_2021_mice_mixture_of_contrastive_experts_for_unsupervised_image_clustering; tang_2019_a_topic_augmented_text_generation_model_joint_learning_of_semantics_and_structural_features; srivastava_2017_autoencoding_variational_inference_for_topic_models; see_2017_get_to_the_point_summarization_with_pointer_generator_networks; reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks; rakib_2020_enhancement_of_short_text_clustering_by_iterative_classification; madiraju_2018_deep_temporal_clustering__fully_unsupervised_learning_of_time_domain_features; liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach; li_2020_contrastive_clustering; kobayashi_2018_contextual_augmentation_data_augmentation_by_words_with_paradigmatic_relations; guo_2017_improved_deep_embedded_clustering_with_local_structure_preservation; ghasedi_2019_balanced_self_paced_learning_for_generative_adversarial_clustering_network; dieng_2019_topic_modeling_in_embedding_spaces; devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding; cong_2017_deep_latent_dirichlet_allocation_with_topic_layer_adaptive_stochastic_gradient_riemannian_mcmc; chen_2020_a_simple_framework_for_contrastive_learning_of_visual_representations; caron_2018_deep_clustering_for_unsupervised_learning_of_visual_features; brahma_2018_unsupervised_learning_of_sentence_representations_using_sequence_consistency; asano_2019_self_labelling_via_simultaneous_clustering_and_representation_learning; aljalbout_2018_clustering_with_deep_learning_taxonomy_and_new_methods; ailem_2019_topic_augmented_generator_for_abstractive_summarization; }
# 	an_2018_model_free_context_aware_word_composition [label=an_2018 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	an_2018_model_free_context_aware_word_composition -> {shi_2017_jointly_learning_word_embeddings_and_latent_topics; salant_2018_contextualized_word_representations_for_reading_comprehension; peters_2018_deep_contextualized_word_representations; zhao_2017_topic_aware_deep_compositional_models_for_sentence_classification; }
# 	austin_2022_community_topic_topic_model_inference_by_consecutive_word_community_discovery [label=austin_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	austin_2022_community_topic_topic_model_inference_by_consecutive_word_community_discovery -> {burkhardt_2019_decoupling_sparsity_and_smoothness_in_the_dirichlet_variational_autoencoder_topic_model; zhao_2017_metalda_a_topic_model_that_efficiently_incorporates_meta_information; traag_2018_from_louvain_to_leiden_guaranteeing_well_connected_communities; srivastava_2017_autoencoding_variational_inference_for_topic_models; sakr_2020_the_future_is_big_graphs_a_community_view_on_graph_processing_systems; rao_2021_vec2gc____a_graph_based_clustering_method_for_text_representations; newman_2018_networks; nan_2019_topic_modeling_with_wasserstein_autoencoders; nalisnick_2016_stick_breaking_variational_autoencoders; mcinnes_2018_umap_uniform_manifold_approximation_and_projection_for_dimension_reduction; mantyla_2018_measuring_lda_topic_stability_from_clusters_of_replicated_runs; krasnashchok_2018_improving_topic_quality_by_promoting_named_entities_in_topic_modeling; kingma_2019_an_introduction_to_variational_autoencoders; isoaho_2019_topic_modeling_and_text_analysis_for_qualitative_policy_research; hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence; dziri_2018_augmenting_neural_response_generation_with_context_aware_topical_attention; doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures; dieng_2020_topic_modeling_in_embedding_spaces; angelov_2020_top2vec_distributed_representations_of_topics; }
# 	sorodoc_2017_multimodal_topic_labelling [label=sorodoc_2017 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	sorodoc_2017_multimodal_topic_labelling -> {aletras_2017_labeling_topics_with_images_using_a_neural_network; aletras_2017_evaluating_topic_representations_for_exploring_document_collections; }
# 	zhao_2021_adversarial_learning_of_poisson_factorisation_model_for_gauging_brand_sentiment_in_user_reviews [label=zhao_2021 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	zhao_2021_adversarial_learning_of_poisson_factorisation_model_for_gauging_brand_sentiment_in_user_reviews -> {masada_2018_adversarial_learning_for_topic_models; silva_2017_content_based_social_recommendation_with_poisson_matrix_factorization; wang_2018_atmadversarial_neural_topic_model; wang_2020_neural_topic_modeling_with_bidirectional_adversarial_training; vafa_2020_text_based_ideal_points; su_2019_personalized_point_of_interest_recommendation_on_ranking_with_poisson_factorization; srivastava_2017_autoencoding_variational_inference_for_topic_models; nan_2019_topic_modeling_with_wasserstein_autoencoders; kuo_2021_the_framework_of_personalized_ranking_on_poisson_factorization; kang_2019_decoupling_representation_and_classifier_for_long_tailed_recognition; joo_2020_generalized_gumbel_softmax_gradient_estimator_for_various_discrete_random_variables; john_2018_disentangled_representation_learning_for_non_parallel_text_style_transfer; jiang_2017_a_topic_model_based_on_poisson_decomposition; jang_2016_categorical_reparameterization_with_gumbel_softmax; huang_2018_siamese_network_based_supervised_topic_modeling; hu_2020_neural_topic_modeling_with_cycle_consistent_adversarial_training; he_2018_effective_attention_modeling_for_aspect_level_sentiment_classification; he_2017_an_unsupervised_neural_attention_model_for_aspect_extraction; guo_2017_understanding_users_budgets_for_recommendation_with_hierarchical_poisson_factorization; gui_2022_multi_task_mutual_learning_for_joint_sentiment_classification_and_topic_detection; gao_2017_collaborative_dynamic_sparse_topic_regression_with_user_profile_evolution_for_item_recommendation; chaidaroon_2017_variational_deep_semantic_hashing_for_text_documents; card_2017_neural_models_for_documents_with_metadata; bouchacourt_2017_multi_level_variational_autoencoder_learning_disentangled_representations_from_grouped_observations; blei_2017_variational_inference_a_review_for_statisticians; barry_2018_alcohol_advertising_on_twittertextemdasha_topic_model; }
# 	popa_2021_bart_tl_weakly_supervised_topic_label_generation [label=popa_2021 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	popa_2021_bart_tl_weakly_supervised_topic_label_generation -> {zhang_2019_bertscore_evaluating_text_generation_with_bert; vaswani_2017_attention_is_all_you_need; sorodoc_2017_multimodal_topic_labelling; radford_2019_language_models_are_unsupervised_multitask_learners; liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach; lewis_2019_bart_denoising_sequence_to_sequence_pre_training_for_natural_language_generation_translation_and_comprehension; keskar_2019_ctrl_a_conditional_transformer_language_model_for_controllable_generation; gourru_2018_united_we_stand_using_multiple_strategies_for_topic_labeling; devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding; alokaili_2020_automatic_generation_of_topic_labels; }
# 	zosa_2022_multilingual_topic_labelling_of_news_topics_using_ontological_mapping [label=zosa_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	zosa_2022_multilingual_topic_labelling_of_news_topics_using_ontological_mapping -> {zhang_2019_bertscore_evaluating_text_generation_with_bert; vaswani_2017_attention_is_all_you_need; reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks; popa_2021_bart_tl_weakly_supervised_topic_label_generation; mueller_2018_reading_between_the_lines_prediction_of_political_violence_using_newspaper_text; maurya_2021_zmbart_an_unsupervised_cross_lingual_transfer_framework_for_language_generation; marjanen_2020_topic_modelling_discourse_dynamics_in_historical_newspapers; liu_2020_multilingual_denoising_pre_training_for_neural_machine_translation; li_2020_global_surveillance_of_covid_19_by_mining_news_media_using_a_multi_source_dynamic_embedded_topic_model; lewis_2019_bart_denoising_sequence_to_sequence_pre_training_for_natural_language_generation_translation_and_comprehension; kim_2019_an_ontology_based_labeling_of_influential_topics_using_topic_network_analysis; kanerva_2018_turku_neural_parser_pipeline_an_end_to_end_system_for_the_conll_2018_shared_task; alokaili_2020_automatic_generation_of_topic_labels; }
# 	hu_2020_neural_topic_modeling_with_cycle_consistent_adversarial_training [label=hu_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	hu_2020_neural_topic_modeling_with_cycle_consistent_adversarial_training -> {arjovsky_2017_wasserstein_generative_adversarial_networks; card_2018_neural_models_for_documents_with_metadata; gulrajani_2017_improved_training_of_wasserstein_gans; kim_2017_learning_to_discover_cross_domain_relations_with_generative_adversarial_networks; lee_2018_scalable_sentiment_for_sequence_to_sequence_chatbot_response_with_performance_analysis; miao_2017_discovering_discrete_latent_topics_with_neural_variational_inference; srivastava_2017_autoencoding_variational_inference_for_topic_models; wang_2020_neural_topic_modeling_with_bidirectional_adversarial_training; wang_2019_atm_adversarial_neural_topic_model; wang_2019_open_event_extraction_from_online_text_using_a_generative_adversarial_network; zhou_2017_event_extraction_from_twitter_using_non_parametric_bayesian_mixture_model_with_word_embeddings; zhu_2017_unpaired_image_to_image_translation_using_cycle_consistent_adversarial_networks; }
# 	yang_2017_adapting_topic_models_using_lexical_associations_with_tree_priors [label=yang_2017 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	yang_2017_adapting_topic_models_using_lexical_associations_with_tree_priors -> {he_2017_efficient_correlated_topic_modeling_with_topic_embedding; }
# 	wang_2021_phrase_bert_improved_phrase_embeddings_from_bert_with_an_application_to_corpus_exploration [label=wang_2021 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	wang_2021_phrase_bert_improved_phrase_embeddings_from_bert_with_an_application_to_corpus_exploration -> {montani_2022_explosionspacy_v343_extended_typer_support_and_bug_fixes; zhou_2017_learning_phrase_embeddings_from_paraphrases_with_grus; zhang_2019_paws_paraphrase_adversaries_from_word_scrambling; yu_2020_assessing_phrasal_representation_and_composition_in_transformers; wolf_2019_transfertransfo_a_transfer_learning_approach_for_neural_network_based_conversational_agents; wieting_2018_paranmt_50m_pushing_the_limits_of_paraphrastic_sentence_embeddings_with_millions_of_machine_translations; vijayakumar_2018_diverse_beam_search_for_improved_description_of_complex_scenes; toshniwal_2020_a_cross_task_analysis_of_text_span_representations; seo_2018_phrase_indexed_question_answering_a_new_challenge_for_scalable_document_comprehension; reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks; radford_2019_language_models_are_unsupervised_multitask_learners; merullo_2019_investigating_sports_commentator_bias_within_a_large_corpus_of_american_football_broadcasts; merity_2016_pointer_sentinel_mixture_models; liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach; li_2020_on_the_sentence_embeddings_from_pre_trained_language_models; lee_2020_learning_dense_representations_of_phrases_at_scale; krishna_2020_reformulating_unsupervised_style_transfer_as_paraphrase_generation; joshi_2019_spanbert_improving_pre_training_by_representing_and_predicting_spans; holtzman_2019_the_curious_case_of_neural_text_degeneration; gao_2021_the_pile_an_800gb_dataset_of_diverse_text_for_language_modeling; gala_2020_analyzing_gender_bias_within_narrative_tropes; dieng_2019_topic_modeling_in_embedding_spaces; devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding; conneau_2018_what_you_can_cram_into_a_single__vector_probing_sentence_embeddings_for_linguistic_properties; bommasani_2020_interpreting_pretrained_contextualized_representations_via_reductions_to_static_embeddings; asaadi_2019_big_bird_a_large_fine_grained_bigram_relatedness_dataset_for_examining_semantic_composition; akoury_2020_storium_a_dataset_and_evaluation_platform_for_machine_in_the_loop_story_generation; }
# 	zhou_2020_condolence_and_empathy_in_online_communities [label=zhou_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	zhou_2020_condolence_and_empathy_in_online_communities -> {choudhury_2017_the_language_of_social_support_in_social_media_and_its_effect_on_suicidal_ideation_risk; j_william_worden_2008_grief_counseling_and_grief_therapy_fourth_edition_a_handbook_for_the_mental_health_practitioner; wolf_2020_transformers_state_of_the_art_natural_language_processing; wang_2018_its_going_to_be_okay_measuring_access_to_support_in_online_communities; rashid_2017_dimensions_of_interpersonal_relationships_corpus_and_experiments; orvell_2019_you_and_i_in_a_foreign_land_the_persuasive_force_of_generic_you; orvell_2017_how_textquotedblleftyoutextquotedblright_makes_meaning; nienhuis_2016_therapeutic_alliance_empathy_and_genuineness_in_individual_adult_psychotherapy_a_meta_analytic_review; liu_2019_roberta_a_robustly_optimized_bert_pretraining_approach; khanpour_2017_identifying_empathetic_messages_in_online_health_communities; fiesler_2018_participant_perceptions_of_twitter_research_ethics; doveling_2017_online_emotion_regulation_in_digitally_mediated_bereavement_why_age_and_kind_of_loss_matter_in_grieving_online; devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding; cameron_2019_empathy_is_hard_work_people_choose_to_avoid_empathy_because_of_its_cognitive_costs; buechel_2018_modeling_empathy_and_distress_in_reaction_to_news_stories; breitfeller_2019_finding_microaggressions_in_the_wild_a_case_for_locating_elusive_phenomena_in_social_media_posts; mageed_2017_recognizing_pathogenic_empathy_in_social_media; }
# 	zhang_2018_taxogen_unsupervised_topic_taxonomy_construction_by_adaptive_term_embedding_and_clustering [label=zhang_2018 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	zhang_2018_taxogen_unsupervised_topic_taxonomy_construction_by_adaptive_term_embedding_and_clustering -> {jiang_2017_metapad_meta_pattern_discovery_from_massive_text_corpora; }
# 	huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring [label=huang_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring -> {zhang_2018_taxogen_unsupervised_topic_taxonomy_construction_by_adaptive_term_embedding_and_clustering; yang_2017_efficiently_answering_technical_questions_textemdash_a_knowledge_graph_approach; soares_2019_matching_the_blanks_distributional_similarity_for_relation_learning; shen_2019_hiexpan_task_guided_taxonomy_construction_by_hierarchical_tree_expansion; shen_2019_setexpan_corpus_based_set_expansion_via_context_feature_selection_and_rank_ensemble; shang_2017_automated_phrase_mining_from_massive_text_corpora; qu_2017_weakly_supervised_relation_extraction_by_pattern_enhanced_embedding_learning; nickel_2017_poincare_embeddings_for_learning_hierarchical_representations; meng_2020_hierarchical_topic_mining_via_joint_spherical_tree_and_text_embedding; meng_2019_spherical_text_embedding; meng_2019_discriminative_topic_mining_via_category_name_guided_text_embedding; le_2019_inferring_concept_hierarchies_from_text_corpora_via_hyperbolic_embeddings; huang_2020_guiding_corpus_based_set_expansion_by_auxiliary_sets_generation_and_co_expansion; han_2018_fewrel_a_large_scale_supervised_few_shot_relation_classification_dataset_with_state_of_the_art_evaluation; gao_2019_hybrid_attention_based_prototypical_networks_for_noisy_few_shot_relation_classification; devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding; dash_2019_hypernym_detection_using_strict_partial_order_networks; chang_2018_distributional_inclusion_vector_embedding_for_unsupervised_hypernymy_detection; }
# 	meng_2020_hierarchical_topic_mining_via_joint_spherical_tree_and_text_embedding [label=meng_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	meng_2020_hierarchical_topic_mining_via_joint_spherical_tree_and_text_embedding -> {zhang_2019_higitclass_keyword_driven_hierarchical_classification_of_github_repositories; tifrea_2018_poincare_glove_hyperbolic_word_embeddings; shang_2017_automated_phrase_mining_from_massive_text_corpora; nickel_2018_learning_continuous_hierarchies_in_the_lorentz_model_of_hyperbolic_geometry; nickel_2017_poincare_embeddings_for_learning_hierarchical_representations; meng_2018_weakly_supervised_hierarchical_text_classification; meng_2018_weakly_supervised_neural_text_classification; meng_2019_spherical_text_embedding; meng_2019_discriminative_topic_mining_via_category_name_guided_text_embedding; meng_2020_unsupervised_word_embedding_learning_by_incorporating_local_and_global_contexts; kumar_2018_von_mises_fisher_loss_for_training_sequence_to_sequence_models_with_continuous_outputs; huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring; huang_2020_guiding_corpus_based_set_expansion_by_auxiliary_sets_generation_and_co_expansion; ganea_2018_hyperbolic_entailment_cones_for_learning_hierarchical_embeddings; gallagher_2016_anchored_correlation_explanation_topic_modeling_with_minimal_domain_knowledge; dieng_2019_topic_modeling_in_embedding_spaces; }
# 	song_2022_automatic_phenotyping_by_a_seed_guided_topic_model [label=song_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	song_2022_automatic_phenotyping_by_a_seed_guided_topic_model -> {ahuja_2021_mixehr_guided_a_guided_multi_modal_topic_modeling_approach_for_large_scale_automatic_phenotyping_using_the_electronic_health_record; silva_2017_content_based_social_recommendation_with_poisson_matrix_factorization; wang_2020_unsupervised_machine_learning_for_the_discovery_of_latent_disease_clusters_and_patient_subgroups_using_electronic_health_records; song_2021_supervised_multi_specialist_topic_model_with_applications_on_large_scale_electronic_health_record_data; li_2020_inferring_multimodal_latent_topics_from_electronic_health_records; dieng_2019_the_dynamic_embedded_topic_model; ahuja_2020_surelda_a_multidisease_automated_phenotyping_method_for_the_electronic_health_record; }
# 	pergola_2021_a_disentangled_adversarial_neural_topic_model_for_separating_opinions_from_plots_in_user_reviews [label=pergola_2021 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	pergola_2021_a_disentangled_adversarial_neural_topic_model_for_separating_opinions_from_plots_in_user_reviews -> {masada_2018_adversarial_learning_for_topic_models; yang_2017_improved_variational_autoencoders_for_text_modeling_using_dilated_convolutions; xu_2016_variational_autoencoders_for_semi_supervised_text_classification; wang_2018_atmadversarial_neural_topic_model; wan_2019_fine_grained_spoiler_detection_from_large_scale_review_corpora; thomas_2018_disentangling_the_independently_controllable_factors_of_variation_by_interacting_with_the_world; srivastava_2017_autoencoding_variational_inference_for_topic_models; reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks; pergola_2019_topical_phrase_extraction_from_clinical_reports_by_incorporating_both_local_and_global_context; pergola_2019_tdam_a_topic_dependent_attention_model_for_sentiment_analysis; peng_2019_domain_agnostic_learning_with_disentangled_representations; nan_2019_topic_modeling_with_wasserstein_autoencoders; miao_2017_discovering_discrete_latent_topics_with_neural_variational_inference; kumar_2017_variational_inference_of_disentangled_latent_concepts_from_unlabeled_observations; kar_2018_mpst_a_corpus_of_movie_plot_synopses_with_tags; john_2019_disentangled_representation_learning_for_non_parallel_text_style_transfer; hoang_2019_towards_autoencoding_variational_inference_for_aspect_based_opinion_summary; higgins_2018_towards_a_definition_of_disentangled_representations; higgins_2017_beta_vae_learning_basic_visual_concepts_with_a_constrained_variational_framework; gui_2019_neural_topic_model_with_reinforcement_learning; gao_2019_auto_encoding_total_correlation_explanation; esmaeili_2018_structured_disentangled_representations; ding_2018_coherence_aware_neural_topic_modeling; dieng_2016_topicrnn_a_recurrent_neural_network_with_long_range_semantic_dependency; devlin_2018_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding; cooijmans_2016_recurrent_batch_normalization; card_2017_neural_models_for_documents_with_metadata; bengio_2017_independently_controllable_features; achille_2017_emergence_of_invariance_and_disentanglement_in_deep_representations; }
# 	doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures [label=doogan_2021 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures -> {ramrakhiyani_2017_measuring_topic_coherence_through_optimal_word_buckets; morstatter_2017_in_search_of_coherence_and_consensus_measuring_the_interpretability_of_statistical_topics; zhao_2017_metalda_a_topic_model_that_efficiently_incorporates_meta_information; zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey; zhang_2020_topic_modeling_on_document_networks_with_adjacent_encoder; xue_2020_public_discourse_and_sentiment_during_the_covid_19_pandemic_using_latent_dirichlet_allocation_for_topic_modeling_on_twitter; wang_2018_astm_an_attentional_segmentation_based_topic_model_for_short_texts; symeonidis_2018_a_comparative_evaluation_of_pre_processing_techniques_and_their_interactions_for_twitter_sentiment_analysis; sinnenberg_2017_twitter_as_a_tool_for_health_research_a_systematic_review; nerghes_2019_narratives_of_the_refugee_crisis_a_comparative_study_of_mainstream_media_and_twitter; morstatter_2018_from_alt_right_to_alt_rechts_twitter_analysis_of_the_2017_german_federal_election; maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology; lyu_2021_understanding_the_public_discussion_about_the_centers_for_disease_control_and_prevention_during_the_covid_19_pandemic_using_twitter_data_text_mining_analysis_study; lund_2019_automatic_evaluation_of_local_topic_quality; lipton_2016_the_mythos_of_model_interpretability; li_2018_short_text_topic_modeling_by_exploring_original_documents; korencic_2018_document_based_topic_coherence_measures_for_news_media_text; kirilenko_2021_automated_topic_modeling_of_tourist_reviews_does_the_anna_karenina_principle_apply; karami_2020_twitter_and_research_a_systematic_literature_review_through_text_mining; karami_2018_characterizing_diabetes_diet_exercise_and_obesity_comments_on_twitter; kagashe_2017_enhancing_seasonal_influenza_surveillance_topic_analysis_of_widely_used_medicinal_drugs_using_twitter_data; hecking_2019_can_topic_models_be_used_in_research_evaluations_reproducibility_validity_and_reliability_when_compared_with_semantic_maps; doogan_2020_public_perceptions_and_attitudes_toward_covid_19_nonpharmaceutical_interventions_across_six_countries_a_topic_modeling_analysis_of_twitter_data; brown_2018_methodological_cyborg_as_black_feminist_technology_constructing_the_social_self_using_computational_digital_autoethnography_and_social_media; blair_2020_aggregated_topic_models_for_increasing_social_media_topic_coherence; bhatia_2018_topic_intrusion_for_automatic_topic_model_evaluation; bhatia_2017_an_automatic_approach_for_document_level_topic_model_evaluation; baumer_2017_comparing_grounded_theory_and_topic_modeling_extreme_divergence_or_unlikely_convergence; andreotta_2019_analyzing_social_media_data_a_mixed_methods_framework_combining_computational_and_qualitative_text_analysis; alokaili_2019_re_ranking_words_to_improve_interpretability_of_automatically_generated_topics; aletras_2017_evaluating_topic_representations_for_exploring_document_collections; agrawal_2018_what_is_wrong_with_topic_modeling_and_how_to_fix_it_using_search_based_software_engineering; }
# 	mukherjee_2020_read_what_you_need_controllable_aspect_based_opinion_summarization_of_tourist_reviews [label=mukherjee_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	mukherjee_2020_read_what_you_need_controllable_aspect_based_opinion_summarization_of_tourist_reviews -> {zhao_2019_weakly_supervised_opinion_summarization_by_leveraging_external_information; xu_2018_double_embeddings_and_cnn_based_sequence_labeling_for_aspect_extraction; tian_2020_aspect_and_opinion_aware_abstractive_review_summarization_with_reinforced_hard_typed_decoder; rudra_2018_identifying_sub_events_and_summarizing_disaster_related_information_from_microblogs; rossiello_2017_centroid_based_text_summarization_through_compositionality_of_word_embeddings; reimers_2019_sentence_bert_sentence_embeddings_using_siamese_bert_networks; he_2017_an_unsupervised_neural_attention_model_for_aspect_extraction; fan_2017_controllable_abstractive_summarization; dash_2018_summarizing_user_generated_textual_content_motivation_and_methods_for_fairness_in_algorithmic_summaries; condori_2017_opinion_summarization_methods_comparing_and_extending_extractive_and_abstractive_approaches; chu_2018_meansum_a_neural_model_for_unsupervised_multi_document_abstractive_summarization; brazinskas_2019_unsupervised_opinion_summarization_as_copycat_review_generation; angelidis_2018_summarizing_opinions_aspect_extraction_meets_sentiment_prediction_and_they_are_both_weakly_supervised; amplayo_2019_informative_and_controllable_opinion_summarization; }
# 	alokaili_2020_automatic_generation_of_topic_labels [label=alokaili_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	alokaili_2020_automatic_generation_of_topic_labels -> {schofield_2017_pulling_out_the_stops_rethinking_stopword_removal_for_topic_models; zhang_2019_bertscore_evaluating_text_generation_with_bert; smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels; alokaili_2019_re_ranking_words_to_improve_interpretability_of_automatically_generated_topics; aletras_2016_labeling_topics_with_images_using_neural_networks; aletras_2015_evaluating_topic_representations_for_exploring_document_collections; }
# 	xu_2020_how_do_consumers_in_the_sharing_economy_value_sharing_evidence_from_online_reviews [label=xu_2020 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	xu_2020_how_do_consumers_in_the_sharing_economy_value_sharing_evidence_from_online_reviews -> {yang_2019_in_airbnb_we_trust_understanding_consumers_trust_attachment_building_mechanisms_in_the_sharing_economy; xu_2017_the_influence_of_e_services_on_customer_online_purchasing_behavior_toward_remanufactured_products; xu_2018_does_traveler_satisfaction_differ_in_various_travel_group_compositions; xu_2020_examining_an_asymmetric_effect_between_online_customer_reviews_emphasis_and_overall_satisfaction_determinants; williams_2018_a_comparison_of_lsa_and_lda_for_the_analysis_of_railroad_accident_text; sutherland_2018_the_sharing_economy_and_digital_platforms_a_review_and_research_agenda; so_2018_motivations_and_constraints_of_airbnb_consumers_findings_from_a_mixed_methods_approach; siering_2018_disentangling_consumer_recommendations_explaining_and_predicting_airline_recommendations_based_on_online_reviews; roma_2019_sharing_economy_and_incumbents_pricing_strategy_the_impact_of_airbnb_on_the_hospitality_industry; priporas_2017_unraveling_the_diverse_nature_of_service_quality_in_a_sharing_economy; pappas_2019_the_complexity_of_consumer_experience_formulation_in_the_sharing_economy; novais_2018_destination_competitiveness_a_phenomenographic_study; netter_2019_sharing_economy_revisited_towards_a_new_framework_for_understanding_sharing_models; moon_2019_peer_to_peer_interactions_perspectives_of_airbnb_guests_and_hosts; masiero_2018_modeling_reference_experience_in_destination_choice; mao_2017_why_travelers_use_airbnb_again; lutz_2018_consumer_segmentation_within_the_sharing_economy_the_case_of_airbnb; liu_2017_airbnb_online_targeted_advertising_sense_of_power_and_consumer_decisions; liang_2017_be_a_superhost_the_importance_of_badge_systems_for_peer_to_peer_rental_accommodations; leung_2019_framing_the_sharing_economy_toward_a_sustainable_ecosystem; letheren_2017_effects_of_personification_and_anthropomorphic_tendency_on_destination_attitude_and_travel_intentions; hu_2019_when_is_enough_enough_investigating_product_reviews_and_information_overload_from_a_consumer_empowerment_perspective; hawlitschek_2018_consumer_motives_for_peer_to_peer_sharing; han_2019_exploring_halal_friendly_destination_attributes_in_south_korea_perceptions_and_behaviors_of_muslim_travelers_toward_a_non_muslim_destination; guttentag_2017_assessing_airbnb_as_a_disruptive_innovation_relative_to_hotels_substitution_and_comparative_performance_expectations; gupta_2019_the_effects_of_national_cultural_values_on_individuals_intention_to_participate_in_peer_to_peer_sharing_economy; davras_2019_analysis_of_hotel_services_by_their_symmetric_and_asymmetric_effects_on_overall_customer_satisfaction_a_comparison_of_market_segments; davidson_2018_materialism_and_the_sharing_economy_a_cross_cultural_study_of_american_and_indian_consumers; choi_2019_values_of_food_leftover_sharing_platforms_in_the_sharing_economy; cheng_2019_an_investigation_on_online_reviews_in_sharing_economy_driven_hospitality_platforms_a_viewpoint_of_trust; cardoso_2019_a_destination_imagery_processing_model_structural_differences_between_dream_and_favourite_destinations; camilleri_2017_value_co_creation_and_co_destruction_in_the_airbnb_sharing_economy; akbar_2018_the_sharing_economy_and_the_future_of_the_hotel_industry_transaction_cost_theory_and_platform_economics; bapna_2017_nurturing_online_communities_an_empirical_investigation; bellos_2017_the_car_sharing_economy_interaction_of_business_model_choice_and_product_line_design; benjaafar_2019_peer_to_peer_product_sharing_implications_for_ownership_usage_and_social_welfare_in_the_sharing_economy; cachon_2017_the_role_of_surge_pricing_on_a_service_platform_with_self_scheduling_capacity; chen_2019_measuring_and_managing_the_externality_of_managerial_responses_to_online_customer_reviews; guttentag_2017_why_tourists_choose_airbnb_a_motivation_based_segmentation_study; jiang_2018_collaborative_consumption_strategic_and_economic_implications_of_product_sharing; li_201 ...
# 	ibrahim_2019_a_text_analytics_approach_for_online_retailing_service_improvement_evidence_from_twitter [label=ibrahim_2019 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	ibrahim_2019_a_text_analytics_approach_for_online_retailing_service_improvement_evidence_from_twitter -> {matthias_2017_making_sense_of_big_data___can_it_transform_operations_management; ramanathan_2017_role_of_social_media_in_retail_network_operations_and_marketing_to_enhance_customer_satisfaction; xu_2017_business_intelligence_in_online_customer_textual_reviews_understanding_consumer_perceptions_and_influential_factors; wiener_2018_omnichannel_businesses_in_the_publishing_and_retailing_industries_synergies_and_tensions_between_coexisting_online_and_offline_business_models; thakur_2018_customer_engagement_and_online_reviews; sheng_2017_a_multidisciplinary_perspective_of_big_data_in_management_research; pepin_2017_visual_analytics_for_exploring_topic_long_term_evolution_and_detecting_weak_signals_in_company_targeted_tweets; liu_2017_an_investigation_of_brand_related_user_generated_content_on_twitter; ibrahim_2017_exploring_the_effect_of_user_engagement_in_online_brand_communities_evidence_from_twitter; ghiassi_2016_targeted_twitter_sentiment_analysis_for_brands_using_supervised_feature_engineering_and_the_dynamic_architecture_for_artificial_neural_networks; daniel_2017_company_event_popularity_for_financial_markets_using_twitter_and_sentiment_analysis; bradlow_2017_the_role_of_big_data_and_predictive_analytics_in_retailing; }
# 	goldberg_2022_sourcing_product_innovation_intelligence_from_online_reviews [label=goldberg_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	goldberg_2022_sourcing_product_innovation_intelligence_from_online_reviews -> {li_2017_catching_fire_and_spreading_it_a_glimpse_into_displayed_entrepreneurial_passion_in_crowdfunding_campaigns; kim_2020_transparency_and_accountability_in_ai_decision_support_explaining_and_visualizing_convolutional_neural_networks_for_text_information; guo_2017_mining_meaning_from_online_ratings_and_reviews_tourist_satisfaction_analysis_using_latent_dirichlet_allocation; goldberg_2020_text_mining_approaches_for_postmarket_food_safety_surveillance_using_online_media; goldberg_2018_a_tabu_search_heuristic_for_smoke_term_curation_in_safety_defect_discovery; amplayo_2018_incorporating_product_description_to_sentiment_topic_models_for_improved_aspect_based_sentiment_analysis; law_2017_automated_defect_discovery_for_dishwasher_appliances_from_online_consumer_reviews; mummalaneni_2018_social_media_analytics_for_quality_surveillance_and_safety_hazard_detection_in_baby_cribs; pessach_2020_employees_recruitment_a_prescriptive_analytics_approach_via_machine_learning_and_mathematical_programming; qiao_2018_the_impact_of_customer_reviews_on_product_innovation_empirical_evidence_in_mobile_apps; sachan_2020_an_explainable_ai_decision_support_system_to_automate_loan_underwriting; siering_2018_disentangling_consumer_recommendations_explaining_and_predicting_airline_recommendations_based_on_online_reviews; srinivas_2019_topic_based_knowledge_mining_of_online_student_reviews_for_strategic_planning_in_universities; xiang_2017_a_comparative_analysis_of_major_online_review_platforms_implications_for_social_media_analytics_in_hospitality_and_tourism; zaman_2020_facebook_hospital_reviews_automated_service_quality_detection_and_relationships_with_patient_satisfaction; zaman_2021_cross_category_defect_discovery_from_online_reviews_supplementing_sentiment_with_category_specific_semantics; zhang_2018_product_innovation_based_on_online_review_data_mining_a_case_study_of_huawei_phones; zhang_2021_mining_product_innovation_ideas_from_online_reviews; }
# 	roeder_2022_data_driven_decision_making_in_credit_risk_management_the_information_value_of_analyst_reports [label=roeder_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	roeder_2022_data_driven_decision_making_in_credit_risk_management_the_information_value_of_analyst_reports -> {huang_2018_analyst_information_discovery_and_interpretation_roles_a_topic_modeling_approach; pucihar_2021_34th_bled_econference_digital_support_from_crisis_to_progressive_change_conference_proceedings; wei_2019_discovering_bank_risk_factors_from_financial_statements_based_on_a_new_semi_supervised_text_mining_algorithm; yang_2020_news_sentiment_credit_spreads_and_information_asymmetry; grover_2018_creating_strategic_business_value_from_big_data_analytics_a_research_framework; yang_2020_finbert_a_pretrained_language_model_for_financial_communications; cambria_2017_sentiment_analysis_is_a_big_suitcase; devlin_2019_bert_pre_training_of_deep_bidirectional_transformers_for_language_understanding; palmer_2021_induction_of_a_sentiment_dictionary_for_financial_analyst_communication_a_data_driven_approach_balancing_machine_learning_and_human_intuition; kiesel_2017_cds_spreads_as_an_independent_measure_of_credit_risk; donovan_pucihar_2021_34th_bled_econference_digital_support_from_crisis_to_progressive_change_conference_proceedings_measuring_credit_risk_using_qualitative_disclosure; lee_2016_investor_sentiment_and_credit_default_swap_spreads_during_the_global_financial_crisis; }
# 	altinel_2022_social_media_analysis_by_innovative_hybrid_algorithms_with_label_propagation [label=altinel_2022 color=skyblue style=filled fixedsize=true width=2 height=2]
# 	altinel_2022_social_media_analysis_by_innovative_hybrid_algorithms_with_label_propagation -> {ozyurt_2021_a_new_topic_modeling_based_approach_for_aspect_extraction_in_aspect_based_sentiment_analysis_ss_lda; girgin_2021_ranking_influencers_of_social_networks_by_semantic_kernels_and_sentiment_information; altinel_2018_semantic_text_classification_a_survey_of_past_and_recent_advances; altinel_2017_instance_labeling_in_semi_supervised_learning_with_meaning_values_of_words; aktas_2022_turkish_sentiment_analysis_using_machine_learning_methods_application_on_online_food_order_site_reviews; bae_2020_label_propagation_based_parallel_graph_partitioning_for_large_scale_graph_data; bilgin_2017_sentiment_analysis_on_twitter_data_with_semi_supervised_doc2vec; kemaloglu_2021_turkish_sentiment_analysis_on_social_media; sahin_2017_turkish_document_classification_based_on_word2vec_and_svm_classifier; }
# 	sakshi_2023_recent_trends_in_mathematical_expressions_recognition_an_lda_based_analysis [label=sakshi_2023 color=skyblue style=filled fixedsize=true width=2 height=2]
# ...
# 	lin_2017_personality_based_refinement_for_sentiment_classification_in_microblog [label=lin_2017 fixedsize=true width=2.0 height=2.0]
# 	bicalho_2017_a_general_framework_to_expand_short_text_for_topic_modeling [label=bicalho_2017 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	rodrigues_2017_learning_supervised_topic_models_for_classification_and_regression_from_crowds [label=rodrigues_2017 fixedsize=true width=2.0 height=2.0]
# 	wang_2017_numerical_simulation_for_the_solitary_wave_of_zakharovtextendashkuznetsov_equation_based_on_lattice_boltzmann_method [label=wang_2017 fixedsize=true width=2.0 height=2.0]
# 	zabkar_2017_brothers_in_blood_yet_strangers_to_global_brand_purchase_a_four_country_study_of_the_role_of_consumer_personality [label=zabkar_2017 fixedsize=true width=2.0 height=2.0]
# 	zhang_2017_a_comparison_of_the_application_of_block_theory_and_3d_block_cutting_analysis [label=zhang_2017 fixedsize=true width=2.0 height=2.0]
# 	zhang_2017_scientific_evolutionary_pathways_identifying_and_visualizing_relationships_for_scientific_topics [label=zhang_2017 color=mistyrose style=filled fixedsize=true width=2.0 height=2.0]
# 	xuan_2018_doubly_nonparametric_sparse_nonnegative_matrix_factorization_based_on_dependent_indian_buffet_processes [label=xuan_2018 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	waltman_2020_a_principled_methodology_for_comparing_relatedness_measures_for_clustering_publications [label=waltman_2020 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	velden_2017_comparison_of_topic_extraction_approaches_and_their_results [label=velden_2017 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	liu_2018_semantic_structure_based_word_embedding_by_incorporating_concept_convergence_and_word_divergence [label=liu_2018 fixedsize=true width=2.0 height=2.0]
# 	klavans_2016_which_type_of_citation_analysis_generates_the_most_accurate_taxonomy_of_scientific_and_technical_knowledge [label=klavans_2016 fixedsize=true width=2.0 height=2.0]
# 	hou_2018_emerging_trends_and_new_developments_in_information_science_a_document_co_citation_analysis_2009__2016 [label=hou_2018 fixedsize=true width=2.0 height=2.0]
# 	broder_2017_health_literacy_in_childhood_and_youth_a_systematic_review_of_definitions_and_models [label=broder_2017 fixedsize=true width=2.0 height=2.0]
# 	meng_2017_deep_keyphrase_generation [label=meng_2017 fixedsize=true width=2.0 height=2.0]
# 	hu_2018_measuring_the_interdisciplinarity_of_big_data_research_a_longitudinal_study [label=hu_2018 fixedsize=true width=2.0 height=2.0]
# 	leydesdorff_2018_betweenness_and_diversity_in_journal_citation_networks_as_measures_of_interdisciplinarity___a_tribute_to_eugene_garfield [label=leydesdorff_2018 fixedsize=true width=2.0 height=2.0]
# 	rousseau_2018_the_repeat_rate_from_hirschman_to_stirling [label=rousseau_2018 fixedsize=true width=2.0 height=2.0]
# 	alzaidy_2019_bi_lstm_crf_sequence_labeling_for_keyphrase_extraction_from_scholarly_documents [label=alzaidy_2019 fixedsize=true width=2.0 height=2.0]
# 	vallejo_2019_detection_of_communities_within_the_multibody_system_dynamics_network_and_analysis_of_their_relations [label=vallejo_2019 fixedsize=true width=2.0 height=2.0]
# 	leydesdorff_2019_interdisciplinarity_as_diversity_in_citation_patterns_among_journals_rao_stirling_diversity_relative_variety_and_the_gini_coefficient [label=leydesdorff_2019 fixedsize=true width=2.0 height=2.0]
# 	asubiaro_2020_collaboration_clusters_interdisciplinarity_scope_and_subject_classification_of_library_and_information_science_research_from_africa_an_analysis_of_web_of_science_publications_from_1996_to_2015 [label=asubiaro_2020 fixedsize=true width=2.0 height=2.0]
# 	bu_2020_topic_diversity_a_discipline_scheme_free_diversity_measurement_for_journals [label=bu_2020 fixedsize=true width=2.0 height=2.0]
# 	leydesdorff_2020_the_measurement_of_textquotedblleftinterdisciplinaritytextquotedblright_and_textquotedblleftsynergytextquotedblright_in_scientific_and_extra_scientific_collaborations [label=leydesdorff_2020 fixedsize=true width=2.0 height=2.0]
# 	kulczycki_2017_toward_an_excellence_based_research_funding_system_evidence_from_poland [label=kulczycki_2017 fixedsize=true width=2.0 height=2.0]
# 	bagozzi_2018_the_politics_of_scrutiny_in_human_rights_monitoring_evidence_from_structural_topic_models_of_us_state_department_human_rights_reports [label=bagozzi_2018 color=mistyrose style=filled fixedsize=true width=2.0 height=2.0]
# 	besselaar_2017_perverse_effects_of_output_based_research_funding_butlers_australian_case_revisited [label=besselaar_2017 fixedsize=true width=2.0 height=2.0]
# 	sun_2017_discovering_themes_and_trends_in_transportation_research_using_topic_modeling [label=sun_2017 fixedsize=true width=2.0 height=2.0]
# 	chandelier_2018_content_analysis_of_newspaper_coverage_of_wolf_recolonization_in_france_using_structural_topic_modeling [label=chandelier_2018 fixedsize=true width=2.0 height=2.0]
# 	herzog_2018_transfer_topic_labeling_with_domain_specific_knowledge_base_an_analysis_of_uk_house_of_commons_speeches_1935_2014 [label=herzog_2018 color=mistyrose style=filled fixedsize=true width=2.0 height=2.0]
# 	krippendorff_2018_content_analysis_an_introduction_to_its_methodology [label=krippendorff_2018 fixedsize=true width=2.0 height=2.0]
# 	kuhn_2018_using_structural_topic_modeling_to_identify_latent_topics_and_trends_in_aviation_incident_reports [label=kuhn_2018 color=mistyrose style=filled fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	yang_2018_exploring_the_research_trend_of_smart_factory_with_topic_modeling [label=yang_2018 fixedsize=true width=2.0 height=2.0]
# 	clare_2019_modelling_research_topic_trends_in_community_forestry [label=clare_2019 color=mistyrose style=filled fixedsize=true width=2.0 height=2.0]
# 	gal_2019_hot_topics_and_trends_in_cardiovascular_research [label=gal_2019 fixedsize=true width=2.0 height=2.0]
# 	grajzl_2019_toward_understanding_17th_century_english_culture_a_structural_topic_model_of_francis_bacontextquotesingles_ideas [label=grajzl_2019 color=mistyrose style=filled fixedsize=true width=2.0 height=2.0]
# 	zeng_2019_increasing_trend_of_scientists_to_switch_between_topics [label=zeng_2019 fixedsize=true width=2.0 height=2.0]
# 	chen_2019_an_analysis_of_the_evolving_intellectual_structure_of_health_information_systems_research_in_the_information_systems_discipline [label=chen_2019 fixedsize=true width=2.0 height=2.0]
# 	kim_2017_topic_diffusion_analysis_of_a_weighted_citation_network_in_biomedical_literature [label=kim_2017 fixedsize=true width=2.0 height=2.0]
# 	sweeney_2017_healthcare_informatics [label=sweeney_2017 fixedsize=true width=2.0 height=2.0]
# 	park_2017_tracing_technological_development_trajectories_a_genetic_knowledge_persistence_based_main_path_approach [label=park_2017 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	nadri_2017_the_top_100_articles_in_the_medical_informatics_a_bibliometric_analysis [label=nadri_2017 fixedsize=true width=2.0 height=2.0]
# 	lathabai_2018_an_integrated_approach_to_path_analysis_for_weighted_citation_networks [label=lathabai_2018 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	henrique_2019_literature_review_machine_learning_techniques_applied_to_financial_market_prediction [label=henrique_2019 fixedsize=true width=2.0 height=2.0]
# 	liu_2019_a_few_notes_on_main_path_analysis [label=liu_2019 fixedsize=true width=2.0 height=2.0]
# 	blair_2020_aggregated_topic_models_for_increasing_social_media_topic_coherence [label=blair_2020 fixedsize=true width=4.19722457733622 height=4.19722457733622]
# 	chen_2020_accessible_values_for_the_assouad_and_lower_dimensions_of_subsets [label=chen_2020 fixedsize=true width=2.0 height=2.0]
# 	evans_2020_the_longest_path_in_the_price_model [label=evans_2020 fixedsize=true width=2.0 height=2.0]
# 	yu_2020_knowledge_diffusion_paths_of_blockchain_domain_the_main_path_analysis [label=yu_2020 fixedsize=true width=2.0 height=2.0]
# 	leydesdorff_2016_co_word_maps_and_topic_modeling_a_comparison_using_small_and_medium_sized_corpora_lessigreaternlessigreaterhspace0167emltmathsemicolonhspace0167em1000 [label=leydesdorff_2016 fixedsize=true width=2.0 height=2.0]
# 	velden_2017_comparison_of_topic_extraction_approaches_and_their_results [label=velden_2017 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	zhu_2016_a_lda_based_model_for_topic_evolution_evidence_from_information_science_journals [label=zhu_2016 fixedsize=true width=2.0 height=2.0]
# 	xu_2019_a_novel_method_for_topic_linkages_between_scientific_publications_and_patents [label=xu_2019 fixedsize=true width=2.0 height=2.0]
# 	shank_2018_phylotreejs___a_javascript_library_for_application_development_and_interactive_data_visualization_in_phylogenetics [label=shank_2018 fixedsize=true width=2.0 height=2.0]
# 	lathabai_2018_an_integrated_approach_to_path_analysis_for_weighted_citation_networks [label=lathabai_2018 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	xu_2017_multi_source_data_fusion_study_in_scientometrics [label=xu_2017 fixedsize=true width=2.0 height=2.0]
# 	waltman_2020_a_principled_methodology_for_comparing_relatedness_measures_for_clustering_publications [label=waltman_2020 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	park_2017_tracing_technological_development_trajectories_a_genetic_knowledge_persistence_based_main_path_approach [label=park_2017 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	klavans_2017_research_portfolio_analysis_and_topic_prominence [label=klavans_2017 fixedsize=true width=2.0 height=2.0]
# 	glaser_2017_same_data___different_results_towards_a_comparative_approach_to_the_identification_of_thematic_structures_in_science [label=glaser_2017 fixedsize=true width=2.0 height=2.0]
# 	abritis_2017_cash_bonuses_for_peer_reviewed_papers_go_global [label=abritis_2017 fixedsize=true width=2.0 height=2.0]
# 	groll_2019_lasso_type_penalization_in_the_framework_of_generalized_additive_models_for_location_scale_and_shape [label=groll_2019 fixedsize=true width=2.0 height=2.0]
# 	lee_2018_viziometrics_analyzing_visual_information_in_the_scientific_literature [label=lee_2018 fixedsize=true width=2.0 height=2.0]
# 	mubin_2018_an_assessment_into_the_characteristics_of_award_winning_papers_at_chi [label=mubin_2018 fixedsize=true width=2.0 height=2.0]
# 	thomas_2018_gradient_boosting_for_distributional_regression_faster_tuning_and_improved_variable_selection_via_noncyclical_updates [label=thomas_2018 fixedsize=true width=2.0 height=2.0]
# 	umlauf_2018_bamlss_bayesian_additive_models_for_location_scale_and_shape_and_beyond [label=umlauf_2018 fixedsize=true width=2.0 height=2.0]
# 	lu_2019_analyzing_linguistic_complexity_and_scientific_impact [label=lu_2019 fixedsize=true width=2.0 height=2.0]
# 	lu_2018_examining_scientific_writing_styles_from_the_perspective_of_linguistic_complexity [label=lu_2018 fixedsize=true width=2.0 height=2.0]
# 	ghavipour_2018_trust_propagation_algorithm_based_on_learning_automata_for_inferring_local_trust_in_online_social_networks [label=ghavipour_2018 fixedsize=true width=2.0 height=2.0]
# 	khani_2018_context_aware_trustworthy_service_evaluation_in_social_internet_of_things [label=khani_2018 fixedsize=true width=2.0 height=2.0]
# 	lu_2018_a_novel_topsis_evaluation_scheme_for_cloud_service_trustworthiness_combining_objective_and_subjective_aspects [label=lu_2018 fixedsize=true width=2.0 height=2.0]
# 	ghavipour_2018_a_dynamic_algorithm_for_stochastic_trust_propagation_in_online_social_networks_learning_automata_approach [label=ghavipour_2018 fixedsize=true width=2.0 height=2.0]
# 	zhang_2017_detecting_and_predicting_the_topic_change_of_knowledge_based_systems_a_topic_based_bibliometric_analysis_from_1991_to_2016 [label=zhang_2017 fixedsize=true width=2.0 height=2.0]
# 	burel_2017_on_semantics_and_deep_learning_for_event_detection_in_crisis_situations [label=burel_2017 fixedsize=true width=2.0 height=2.0]
# 	nguyen_2017_real_time_event_detection_for_online_behavioral_analysis_of_big_social_data [label=nguyen_2017 fixedsize=true width=2.0 height=2.0]
# 	xiaomei_2018_microblog_sentiment_analysis_with_weak_dependency_connections [label=xiaomei_2018 fixedsize=true width=2.0 height=2.0]
# 	moreno_2018_quantifying_the_emotional_impact_of_events_on_locations_with_social_media [label=moreno_2018 fixedsize=true width=2.0 height=2.0]
# 	rosenthal_2017_semeval_2017_task_4_sentiment_analysis_in_twitter [label=rosenthal_2017 fixedsize=true width=2.0 height=2.0]
# 	cambria_2017_affective_computing_and_sentiment_analysis [label=cambria_2017 fixedsize=true width=2.0 height=2.0]
# 	cavallari_2017_learning_community_embedding_with_community_detection_and_node_embedding_on_graphs [label=cavallari_2017 fixedsize=true width=2.0 height=2.0]
# 	rawashdeh_2017_mining_tag_clouds_to_improve_social_media_recommendation [label=rawashdeh_2017 fixedsize=true width=2.0 height=2.0]
# 	majumder_2017_deep_learning_based_document_modeling_for_personality_detection_from_text [label=majumder_2017 fixedsize=true width=2.0 height=2.0]
# 	jendoubi_2017_two_evidential_data_based_models_for_influence_maximization_in_twitter [label=jendoubi_2017 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	alp_2018_identifying_topical_influencers_on_twitter_based_on_user_behavior_and_network_topology [label=alp_2018 color=mistyrose style=filled fixedsize=true width=2.0 height=2.0]
# 	mei_2017_influence_maximization_on_twitter_a_mechanism_for_effective_marketing_campaign [label=mei_2017 fixedsize=true width=2.0 height=2.0]
# 	lagree_2017_effective_large_scale_online_influence_maximization [label=lagree_2017 fixedsize=true width=2.0 height=2.0]
# 	riquelme_2018_centrality_measure_in_social_networks_based_on_linear_threshold_model [label=riquelme_2018 fixedsize=true width=2.0 height=2.0]
# 	tsugawa_2018_identifying_influencers_from_sampled_social_networks [label=tsugawa_2018 fixedsize=true width=2.0 height=2.0]
# 	jendoubi_2017_two_evidential_data_based_models_for_influence_maximization_in_twitter [label=jendoubi_2017 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	xuan_2018_doubly_nonparametric_sparse_nonnegative_matrix_factorization_based_on_dependent_indian_buffet_processes [label=xuan_2018 fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	zhang_2017_processing_long_queries_against_short_text_top_k_advertisement_matching_in_news_stream_applications [label=zhang_2017 fixedsize=true width=2.0 height=2.0]
# 	xuan_2017_explicitly_and_implicitly_exploiting_the_hierarchical_structure_for_mining_website_interests_on_news_events [label=xuan_2017 fixedsize=true width=2.0 height=2.0]
# 	xu_2017_incorporating_wikipedia_concepts_and_categories_as_prior_knowledge_into_topic_models [label=xu_2017 fixedsize=true width=2.0 height=2.0]
# 	wei_2017_discriminative_locally_document_embedding_learning_a_smooth_affine_map_by_approximation_of_the_probabilistic_generative_structure_of_subspace [label=wei_2017 fixedsize=true width=2.0 height=2.0]
# 	altnel_2017_instance_labeling_in_semi_supervised_learning_with_meaning_values_of_words [label=altnel_2017 fixedsize=true width=2.0 height=2.0]
# 	nie_2017_data_driven_answer_selection_in_community_qa_systems [label=nie_2017 fixedsize=true width=2.0 height=2.0]
# 	xiang_2017_answer_selection_in_community_question_answering_via_attentive_neural_networks [label=xiang_2017 fixedsize=true width=2.0 height=2.0]
# 	liu_2018_learning_structured_text_representations [label=liu_2018 fixedsize=true width=2.0 height=2.0]
# 	zhao_2018_fuzzy_bag_of_words_model_for_document_representation [label=zhao_2018 fixedsize=true width=2.0 height=2.0]
# 	sun_2019_evolving_unsupervised_deep_neural_networks_for_learning_meaningful_representations [label=sun_2019 fixedsize=true width=2.0 height=2.0]
# 	zhao_2019_exploiting_social_and_local_contexts_propagation_for_inducing_chinese_microblog_specific_sentiment_lexicons [label=zhao_2019 fixedsize=true width=2.0 height=2.0]
# }

# %%
build_fs_graph('../References/Snowballing/Forward snowballing (Incoming citations)', venues, fs_selection, min_outgoing_edges=1, selection_only=False)
# Out:
# digraph G {
# 	card_2018_neural_models_for_documents_with_metadata [label=card_2018 color=skyblue style=filled fixedsize=true width=10.0507033814703 height=10.0507033814703]
# 	{hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence; nguyen_2021_contrastive_learning_for_neural_topic_model; hoyle_2022_are_neural_topic_models_broken; zhu_2022_disentangled_learning_of_stance_and_aspect_topics_for_vaccine_attitude_detection_in_social_media; zhao_2021_adversarial_learning_of_poisson_factorisation_model_for_gauging_brand_sentiment_in_user_reviews; tripodi_2020_topic_modelling_games; zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey; zhang_2022_pre_training_and_fine_tuning_neural_topic_model_a_simple_yet_effective_approach_to_incorporating_external_knowledge; panwar_2021_tan_ntm_topic_attention_networks_for_neural_topic_modeling; hoyle_2020_improving_neural_topic_models_using_knowledge_distillation; } -> card_2018_neural_models_for_documents_with_metadata
# 	lau_2017_topically_driven_neural_language_model [label=lau_2017 color=skyblue style=filled fixedsize=true width=9.824046010856293 height=9.824046010856293]
# 	{hoyle_2022_are_neural_topic_models_broken; tripodi_2020_topic_modelling_games; zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey; } -> lau_2017_topically_driven_neural_language_model
# 	wu_2020_neural_mixed_counting_models_for_dispersed_topic_discovery [label=wu_2020 color=skyblue style=filled fixedsize=true width=6.394449154672439 height=6.394449154672439]
# 	{hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence; liu_2022_innovation_hierarchy_based_patent_representation_model; panwar_2021_tan_ntm_topic_attention_networks_for_neural_topic_modeling; zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey; } -> wu_2020_neural_mixed_counting_models_for_dispersed_topic_discovery
# 	maiti_2019_spatial_aggregation_facilitates_discovery_of_spatial_topics [label=maiti_2019 color=skyblue style=filled fixedsize=true width=2.0 height=2.0]
# 	{} -> maiti_2019_spatial_aggregation_facilitates_discovery_of_spatial_topics
# 	huang_2018_phrasectm_correlated_topic_modeling_on_phrases_within_markov_random_fields [label=huang_2018 color=skyblue style=filled fixedsize=true width=4.19722457733622 height=4.19722457733622]
# 	{} -> huang_2018_phrasectm_correlated_topic_modeling_on_phrases_within_markov_random_fields
# 	ahmadvand_2019_concet_entity_aware_topic_classification_for_open_domain_conversational_agents [label=ahmadvand_2019 color=skyblue style=filled fixedsize=true width=6.1588830833596715 height=6.1588830833596715]
# 	{} -> ahmadvand_2019_concet_entity_aware_topic_classification_for_open_domain_conversational_agents
# 	nouri_2020_mining_crowdsourcing_problems_from_discussion_forums_of_workers [label=nouri_2020 color=skyblue style=filled fixedsize=true width=4.19722457733622 height=4.19722457733622]
# 	{} -> nouri_2020_mining_crowdsourcing_problems_from_discussion_forums_of_workers
# 	sorodoc_2017_multimodal_topic_labelling [label=sorodoc_2017 color=skyblue style=filled fixedsize=true width=6.795790545596741 height=6.795790545596741]
# 	{he_2021_automatic_topic_labeling_model_with_paired_attention_based_on_pre_trained_deep_neural_network; kriukova_2018_explicit_semantic_analysis_as_a_means_for_topic_labelling; truica_2021_tlatr_automatic_topic_labeling_using_automatic_domain_specific_term_recognition; he_2021_automatic_topic_labeling_using_graph_based_pre_trained_neural_embedding; he_2019_automatic_labeling_of_topic_models_using_graph_based_ranking; popa_2021_bart_tl_weakly_supervised_topic_label_generation; } -> sorodoc_2017_multimodal_topic_labelling
# 	popa_2021_bart_tl_weakly_supervised_topic_label_generation [label=popa_2021 color=skyblue style=filled fixedsize=true width=5.58351893845611 height=5.58351893845611]
# 	{rosati_2022_moving_beyond_word_lists_towards_abstractive_topic_labels_for_human_like_topics_of_scientific_documents; zosa_2022_multilingual_topic_labelling_of_news_topics_using_ontological_mapping; university_of_helsinki_2021_not_all_comments_are_equal_insights_into_comment_moderation_from_a_topic_aware_model; } -> popa_2021_bart_tl_weakly_supervised_topic_label_generation
# 	aletras_2017_labeling_topics_with_images_using_a_neural_network [label=aletras_2017 color=skyblue style=filled fixedsize=true width=7.1298987149230735 height=7.1298987149230735]
# 	{kriukova_2018_explicit_semantic_analysis_as_a_means_for_topic_labelling; he_2019_automatic_labeling_of_topic_models_using_graph_based_ranking; he_2021_automatic_topic_labeling_using_graph_based_pre_trained_neural_embedding; he_2021_automatic_topic_labeling_model_with_paired_attention_based_on_pre_trained_deep_neural_network; } -> aletras_2017_labeling_topics_with_images_using_a_neural_network
# 	barbieri_2017_survival_factorization_on_diffusion_networks [label=barbieri_2017 color=skyblue style=filled fixedsize=true width=4.772588722239782 height=4.772588722239782]
# 	{} -> barbieri_2017_survival_factorization_on_diffusion_networks
# 	hu_2020_neural_topic_modeling_with_cycle_consistent_adversarial_training [label=hu_2020 color=skyblue style=filled fixedsize=true width=6.969813299576001 height=6.969813299576001]
# 	{nguyen_2021_contrastive_learning_for_neural_topic_model; hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence; zhao_2021_adversarial_learning_of_poisson_factorisation_model_for_gauging_brand_sentiment_in_user_reviews; panwar_2021_tan_ntm_topic_attention_networks_for_neural_topic_modeling; zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey; zhang_2022_pre_training_and_fine_tuning_neural_topic_model_a_simple_yet_effective_approach_to_incorporating_external_knowledge; } -> hu_2020_neural_topic_modeling_with_cycle_consistent_adversarial_training
# 	yang_2017_adapting_topic_models_using_lexical_associations_with_tree_priors [label=yang_2017 color=skyblue style=filled fixedsize=true width=5.891820298110627 height=5.891820298110627]
# 	{hoyle_2020_improving_neural_topic_models_using_knowledge_distillation; } -> yang_2017_adapting_topic_models_using_lexical_associations_with_tree_priors
# 	wang_2021_phrase_bert_improved_phrase_embeddings_from_bert_with_an_application_to_corpus_exploration [label=wang_2021 color=skyblue style=filled fixedsize=true width=7.991464547107982 height=7.991464547107982]
# 	{} -> wang_2021_phrase_bert_improved_phrase_embeddings_from_bert_with_an_application_to_corpus_exploration
# 	zhou_2020_condolence_and_empathy_in_online_communities [label=zhou_2020 color=skyblue style=filled fixedsize=true width=7.991464547107982 height=7.991464547107982]
# 	{} -> zhou_2020_condolence_and_empathy_in_online_communities
# 	zhang_2018_taxogen_unsupervised_topic_taxonomy_construction_by_adaptive_term_embedding_and_clustering [label=zhang_2018 color=skyblue style=filled fixedsize=true width=10.286269452783065 height=10.286269452783065]
# 	{lee_2022_topic_taxonomy_expansion_via_hierarchy_aware_topic_phrase_generation; jiang_2022_taxoenrich_self_supervised_taxonomy_completion_via_structure_semantic_representations; taha_2022_inferring_the_densest_multi_profiled_cross_community_for_a_user; avron_2022_automated_category_tree_construction_in_e_commerce; lee_2022_taxocom_topic_taxonomy_completion_with_hierarchical_discovery_of_novel_topic_clusters; guo_2021_dhcm_dynamic_and_hierarchical_event_categorization_and_discovery_for_social_media_stream; sas_2022_gitranking_a_ranking_of_github_topics_for_software_classification_using_active_sampling; mousavi_2021_stif_semi_supervised_taxonomy_induction_using_term_embeddings_and_clustering; huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring; meng_2020_embedding_driven_multi_dimensional_topic_mining_and_text_analysis; } -> zhang_2018_taxogen_unsupervised_topic_taxonomy_construction_by_adaptive_term_embedding_and_clustering
# 	huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring [label=huang_2020 color=skyblue style=filled fixedsize=true width=7.780743515792329 height=7.780743515792329]
# 	{lee_2022_topic_taxonomy_expansion_via_hierarchy_aware_topic_phrase_generation; lee_2022_taxocom_topic_taxonomy_completion_with_hierarchical_discovery_of_novel_topic_clusters; guo_2021_dhcm_dynamic_and_hierarchical_event_categorization_and_discovery_for_social_media_stream; sas_2022_gitranking_a_ranking_of_github_topics_for_software_classification_using_active_sampling; taha_2022_inferring_the_densest_multi_profiled_cross_community_for_a_user; huang_2020_weakly_supervised_aspect_based_sentiment_analysis_via_joint_aspect_sentiment_topic_embedding; jiang_2022_taxoenrich_self_supervised_taxonomy_completion_via_structure_semantic_representations; avron_2022_automated_category_tree_construction_in_e_commerce; meng_2020_embedding_driven_multi_dimensional_topic_mining_and_text_analysis; meng_2022_topic_discovery_via_latent_space_clustering_of_pretrained_language_model_representations; meng_2022_adapting_pretrained_representations_for_text_mining; meng_2021_on_the_power_of_pre_trained_text_representations_models_and_applications_in_text_mining; mousavi_2021_stif_semi_supervised_taxonomy_induction_using_term_embeddings_and_clustering; } -> huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring
# 	meng_2020_hierarchical_topic_mining_via_joint_spherical_tree_and_text_embedding [label=meng_2020 color=skyblue style=filled fixedsize=true width=8.664409020350408 height=8.664409020350408]
# 	{ge_2021_fine_grained_opinion_summarization_with_minimal_supervision; lee_2022_topic_taxonomy_expansion_via_hierarchy_aware_topic_phrase_generation; lee_2022_taxocom_topic_taxonomy_completion_with_hierarchical_discovery_of_novel_topic_clusters; meng_2022_adapting_pretrained_representations_for_text_mining; guo_2021_dhcm_dynamic_and_hierarchical_event_categorization_and_discovery_for_social_media_stream; meng_2022_topic_discovery_via_latent_space_clustering_of_pretrained_language_model_representations; huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring; meng_2020_embedding_driven_multi_dimensional_topic_mining_and_text_analysis; meng_2021_on_the_power_of_pre_trained_text_representations_models_and_applications_in_text_mining; } -> meng_2020_hierarchical_topic_mining_via_joint_spherical_tree_and_text_embedding
# 	song_2022_automatic_phenotyping_by_a_seed_guided_topic_model [label=song_2022 color=skyblue style=filled fixedsize=true width=2.0 height=2.0]
# 	{} -> song_2022_automatic_phenotyping_by_a_seed_guided_topic_model
# 	pergola_2021_a_disentangled_adversarial_neural_topic_model_for_separating_opinions_from_plots_in_user_reviews [label=pergola_2021 color=skyblue style=filled fixedsize=true width=5.58351893845611 height=5.58351893845611]
# 	{zhu_2022_disentangled_learning_of_stance_and_aspect_topics_for_vaccine_attitude_detection_in_social_media; } -> pergola_2021_a_disentangled_adversarial_neural_topic_model_for_separating_opinions_from_plots_in_user_reviews
# 	doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures [label=doogan_2021 color=skyblue style=filled fixedsize=true width=7.666426688112432 height=7.666426688112432]
# 	{hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence; wood_2022_a_bayesian_topic_model_for_human_evaluated_interpretability; hoyle_2022_are_neural_topic_models_broken; rosati_2022_moving_beyond_word_lists_towards_abstractive_topic_labels_for_human_like_topics_of_scientific_documents; zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey; korencic_2021_a_topic_coverage_approach_to_evaluation_of_topic_models; meaney_2022_non_negative_matrix_factorization_temporal_topic_models_and_clinical_text_data_identify_covid_19_pandemic_effects_on_primary_healthcare_and_community_health_in_toronto_canada; } -> doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures
# 	mukherjee_2020_read_what_you_need_controllable_aspect_based_opinion_summarization_of_tourist_reviews [label=mukherjee_2020 color=skyblue style=filled fixedsize=true width=6.795790545596741 height=6.795790545596741]
# 	{} -> mukherjee_2020_read_what_you_need_controllable_aspect_based_opinion_summarization_of_tourist_reviews
# 	chin_2017_totem_personal_tweets_summarization_on_mobile_devices [label=chin_2017 color=skyblue style=filled fixedsize=true width=5.218875824868201 height=5.218875824868201]
# 	{} -> chin_2017_totem_personal_tweets_summarization_on_mobile_devices
# 	alokaili_2020_automatic_generation_of_topic_labels [label=alokaili_2020 color=skyblue style=filled fixedsize=true width=6.605170185988092 height=6.605170185988092]
# 	{wood_2022_a_bayesian_topic_model_for_human_evaluated_interpretability; rosati_2022_moving_beyond_word_lists_towards_abstractive_topic_labels_for_human_like_topics_of_scientific_documents; meaney_2022_non_negative_matrix_factorization_temporal_topic_models_and_clinical_text_data_identify_covid_19_pandemic_effects_on_primary_healthcare_and_community_health_in_toronto_canada; zosa_2022_multilingual_topic_labelling_of_news_topics_using_ontological_mapping; he_2021_automatic_topic_labeling_using_graph_based_pre_trained_neural_embedding; university_of_helsinki_2021_not_all_comments_are_equal_insights_into_comment_moderation_from_a_topic_aware_model; wahid_2021_topic2features_a_novel_framework_to_classify_noisy_and_sparse_textual_data_using_lda_topic_distributions; popa_2021_bart_tl_weakly_supervised_topic_label_generation; } -> alokaili_2020_automatic_generation_of_topic_labels
# 	xu_2020_how_do_consumers_in_the_sharing_economy_value_sharing_evidence_from_online_reviews [label=xu_2020 color=skyblue style=filled fixedsize=true width=10.254268770090183 height=10.254268770090183]
# 	{chakraborty_2022_are_online_reviews_credible_the_effects_of_online_reviews_for_the_adoption_of_moocs_for_e_learning; wang_2022_research_on_electronic_word_of_mouth_for_product_and_service_quality_improvement_bibliometric_analysis_and_future_directions; ding_2021_exploring_sources_of_satisfaction_and_dissatisfaction_in_airbnb_accommodation_using_unsupervised_and_supervised_topic_modeling; yan_2021_examining_consumer_complaints_from_an_on_demand_service_platform; } -> xu_2020_how_do_consumers_in_the_sharing_economy_value_sharing_evidence_from_online_reviews
# 	ibrahim_2019_a_text_analytics_approach_for_online_retailing_service_improvement_evidence_from_twitter [label=ibrahim_2019 color=skyblue style=filled fixedsize=true width=9.475339236566736 height=9.475339236566736]
# 	{wang_2022_discovery_of_product_features_for_redesign_from_user_implicit_feedback; wang_2022_research_on_electronic_word_of_mouth_for_product_and_service_quality_improvement_bibliometric_analysis_and_future_directions; firdaniza_2021_information_diffusion_model_in_twitter_a_systematic_literature_review; ding_2021_exploring_sources_of_satisfaction_and_dissatisfaction_in_airbnb_accommodation_using_unsupervised_and_supervised_topic_modeling; gozuacik_2021_social_media_based_opinion_retrieval_for_product_analysis_using_multi_task_deep_neural_networks; li_2021_impact_of_the_latent_topics_of_policy_documents_on_the_promotion_of_new_energy_vehicles_empirical_evidence_from_chinese_cities; bansal_2020_aspect_context_aware_sentiment_classification_of_online_consumer_reviews; he_2020_the_voice_of_drug_consumers_online_textual_review_analysis_using_structural_topic_model; yang_2020_service_providers_competence_identification_in_knowledge_intensive_crowdsourcing_context; } -> ibrahim_2019_a_text_analytics_approach_for_online_retailing_service_improvement_evidence_from_twitter
# 	goldberg_2022_sourcing_product_innovation_intelligence_from_online_reviews [label=goldberg_2022 color=skyblue style=filled fixedsize=true width=4.772588722239782 height=4.772588722239782]
# 	{chakraborty_2022_are_online_reviews_credible_the_effects_of_online_reviews_for_the_adoption_of_moocs_for_e_learning; } -> goldberg_2022_sourcing_product_innovation_intelligence_from_online_reviews
# 	gregoriades_2021_supporting_digital_content_marketing_and_messaging_through_topic_modelling_and_decision_trees [label=gregoriades_2021 color=skyblue style=filled fixedsize=true width=5.58351893845611 height=5.58351893845611]
# 	{} -> gregoriades_2021_supporting_digital_content_marketing_and_messaging_through_topic_modelling_and_decision_trees
# 	pablos_2018_w2vlda_almost_unsupervised_system_for_aspect_based_sentiment_analysis [label=pablos_2018 color=skyblue style=filled fixedsize=true width=11.591581091193483 height=11.591581091193483]
# 	{ge_2021_fine_grained_opinion_summarization_with_minimal_supervision; chen_2020_a_structural_topic_modeling_based_bibliometric_study_of_sentiment_analysis_literature; hussain_2022_aspect2labels_a_novelistic_decision_support_system_for_higher_educational_institutions_by_using_multi_layer_topic_modelling_approach; guven_2022_impact_of_n_stage_latent_dirichlet_allocation_on_analysis_of_headline_classification; huang_2020_weakly_supervised_aspect_based_sentiment_analysis_via_joint_aspect_sentiment_topic_embedding; shams_2020_lisa_language_independent_method_for_aspect_based_sentiment_analysis; truica_2021_topic_based_document_level_sentiment_analysis_using_contextual_cues; bansal_2020_aspect_context_aware_sentiment_classification_of_online_consumer_reviews; } -> pablos_2018_w2vlda_almost_unsupervised_system_for_aspect_based_sentiment_analysis
# 	korfiatis_2019_measuring_service_quality_from_unstructured_data_a_topic_modeling_application_on_airline_passengers_online_reviews [label=korfiatis_2019 color=skyblue style=filled fixedsize=true width=10.580918882296782 height=10.580918882296782]
# 	{shou_2022_predictions_on_usefulness_and_popularity_of_online_reviews_evidence_from_mobile_phones_for_older_adults; farzadnia_2022_identification_of_opinion_trends_using_sentiment_analysis_of_airlines_passengers_reviews; ding_2021_exploring_sources_of_satisfaction_and_dissatisfaction_in_airbnb_accommodation_using_unsupervised_and_supervised_topic_modeling; he_2020_the_voice_of_drug_consumers_online_textual_review_analysis_using_structural_topic_model; shadrova_2021_topic_models_do_not_model_topics_epistemological_remarks_and_steps_towards_best_practices; chen_2020_a_structural_topic_modeling_based_bibliometric_study_of_sentiment_analysis_literature; wang_2022_discovery_of_product_features_for_redesign_from_user_implicit_feedback; calli_2022_understanding_airline_passengers_during_covid_19_outbreak_to_improve_service_quality_topic_modeling_approach_to_complaints_with_latent_dirichlet_allocation_algorithm; li_2021_impact_of_the_latent_topics_of_policy_documents_on_the_promotion_of_new_energy_vehicles_empirical_evidence_from_chinese_cities; } -> korfiatis_2019_measuring_service_quality_from_unstructured_data_a_topic_modeling_application_on_airline_passengers_online_reviews
# 	gomez_2022_large_scale_analysis_of_open_mooc_reviews_to_support_learners_course_selection [label=gomez_2022 color=skyblue style=filled fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	{} -> gomez_2022_large_scale_analysis_of_open_mooc_reviews_to_support_learners_course_selection
# 	fang_2021_criteria_determination_of_analytic_hierarchy_process_using_a_topic_model [label=fang_2021 color=skyblue style=filled fixedsize=true width=7.545177444479562 height=7.545177444479562]
# 	{} -> fang_2021_criteria_determination_of_analytic_hierarchy_process_using_a_topic_model
# 	lebena_2022_preliminary_exploration_of_topic_modelling_representations_for_electronic_health_records_coding_according_to_the_international_classification_of_diseases_in_spanish [label=lebena_2022 color=skyblue style=filled fixedsize=true width=3.386294361119891 height=3.386294361119891]
# 	{} -> lebena_2022_preliminary_exploration_of_topic_modelling_representations_for_electronic_health_records_coding_according_to_the_international_classification_of_diseases_in_spanish
# 	effrosynidis_2022_the_climate_change_twitter_dataset [label=effrosynidis_2022 color=skyblue style=filled fixedsize=true width=5.58351893845611 height=5.58351893845611]
# 	{} -> effrosynidis_2022_the_climate_change_twitter_dataset
# 	korencic_2018_document_based_topic_coherence_measures_for_news_media_text [label=korencic_2018 color=skyblue style=filled fixedsize=true width=8.802394763324312 height=8.802394763324312]
# 	{porter_2020_measuring_tech_emergence_a_contest; chowdhury_2021_functional_analysis_of_generalized_linear_models_under_non_linear_constraints_with_applications_to_identifying_highly_cited_papers; korencic_2021_a_topic_coverage_approach_to_evaluation_of_topic_models; } -> korencic_2018_document_based_topic_coherence_measures_for_news_media_text
# 	bastani_2019_latent_dirichlet_allocation_lda_for_topic_modeling_of_the_cfpb_consumer_complaints [label=bastani_2019 color=skyblue style=filled fixedsize=true width=10.713417653379183 height=10.713417653379183]
# 	{shou_2022_predictions_on_usefulness_and_popularity_of_online_reviews_evidence_from_mobile_phones_for_older_adults; guven_2019_comparison_of_topic_modeling_methods_for_type_detection_of_turkish_news; farzadnia_2022_identification_of_opinion_trends_using_sentiment_analysis_of_airlines_passengers_reviews; calli_2022_understanding_airline_passengers_during_covid_19_outbreak_to_improve_service_quality_topic_modeling_approach_to_complaints_with_latent_dirichlet_allocation_algorithm; yan_2021_examining_consumer_complaints_from_an_on_demand_service_platform; wang_2021_technology_hotspot_tracking_topic_discovery_and_evolution_of_chinas_blockchain_patents_based_on_a_dynamic_lda_model; guven_2022_impact_of_n_stage_latent_dirichlet_allocation_on_analysis_of_headline_classification; ahmed_mateen_2021_an_analysis_on_text_mining_techniques_for_smart_literature_review; yang_2020_service_providers_competence_identification_in_knowledge_intensive_crowdsourcing_context; parlina_2021_exposing_emerging_trends_in_smart_sustainable_city_research_using_deep_autoencoders_based_fuzzy_c_means; } -> bastani_2019_latent_dirichlet_allocation_lda_for_topic_modeling_of_the_cfpb_consumer_complaints
# 	wahid_2022_topic2labels_a_framework_to_annotate_and_classify_the_social_media_data_through_lda_topics_and_deep_learning_models_for_crisis_response [label=wahid_2022 color=skyblue style=filled fixedsize=true width=2.0 height=2.0]
# 	{hussain_2022_aspect2labels_a_novelistic_decision_support_system_for_higher_educational_institutions_by_using_multi_layer_topic_modelling_approach; } -> wahid_2022_topic2labels_a_framework_to_annotate_and_classify_the_social_media_data_through_lda_topics_and_deep_learning_models_for_crisis_response
# 	kim_2020_word2vec_based_latent_semantic_analysis_w2v_lsa_for_topic_modeling_a_study_on_blockchain_technology_trend_analysis [label=kim_2020 color=skyblue style=filled fixedsize=true width=10.0507033814703 height=10.0507033814703]
# 	{murshed_2022_short_text_topic_modelling_approaches_in_the_context_of_big_data_taxonomy_survey_and_analysis; wahid_2021_topic2features_a_novel_framework_to_classify_noisy_and_sparse_textual_data_using_lda_topic_distributions; zhu_2022_evolution_analysis_of_online_topics_based_on_word_topic_coupling_network; gozuacik_2021_social_media_based_opinion_retrieval_for_product_analysis_using_multi_task_deep_neural_networks; ahmed_mateen_2021_an_analysis_on_text_mining_techniques_for_smart_literature_review; luo_2021_exploring_chinas_5a_global_geoparks_through_online_tourism_reviews_a_mining_model_based_on_machine_learning_approach; chiarello_2021_value_creation_in_emerging_technologies_through_text_mining_the_case_of_blockchain; } -> kim_2020_word2vec_based_latent_semantic_analysis_w2v_lsa_for_topic_modeling_a_study_on_blockchain_technology_trend_analysis
# 	yang_2021_author_topic_model_for_co_occurring_normal_documents_and_short_texts_to_explore_individual_user_preferences [label=yang_2021 color=skyblue style=filled fixedsize=true width=5.218875824868201 height=5.218875824868201]
# 	{wood_2022_a_bayesian_topic_model_for_human_evaluated_interpretability; murshed_2022_short_text_topic_modelling_approaches_in_the_context_of_big_data_taxonomy_survey_and_analysis; } -> yang_2021_author_topic_model_for_co_occurring_normal_documents_and_short_texts_to_explore_individual_user_preferences
# 	liu_2018_identifying_impact_of_intrinsic_factors_on_topic_preferences_in_online_social_media_a_nonparametric_hierarchical_bayesian_approach [label=liu_2018 color=skyblue style=filled fixedsize=true width=6.795790545596741 height=6.795790545596741]
# 	{} -> liu_2018_identifying_impact_of_intrinsic_factors_on_topic_preferences_in_online_social_media_a_nonparametric_hierarchical_bayesian_approach
# 	zhang_2018_does_deep_learning_help_topic_extraction_a_kernel_k_means_clustering_method_with_word_embedding [label=zhang_2018 color=skyblue style=filled fixedsize=true width=10.254268770090183 height=10.254268770090183]
# 	{porter_2020_measuring_tech_emergence_a_contest; xu_2022_a_methodology_for_identifying_breakthrough_topics_using_structural_entropy; zhang_2021_topic_evolution_disruption_and_resilience_in_early_covid_19_research; wu_2021_unraveling_the_capabilities_that_enable_digital_transformation_a_data_driven_methodology_and_the_case_of_artificial_intelligence; chowdhury_2021_functional_analysis_of_generalized_linear_models_under_non_linear_constraints_with_applications_to_identifying_highly_cited_papers; huang_2022_identification_of_topic_evolution_network_analytics_with_piecewise_linear_representation_and_word_embedding; zhang_2021_ethics_and_privacy_of_artificial_intelligence_understandings_from_bibliometrics; zhang_2020_framework_of_computational_intelligence_enhanced_knowledge_base_construction_methodology_and_a_case_of_gene_related_cardiovascular_disease; } -> zhang_2018_does_deep_learning_help_topic_extraction_a_kernel_k_means_clustering_method_with_word_embedding
# 	ebadi_2020_application_of_machine_learning_techniques_to_assess_the_trends_and_alignment_of_the_funded_research_output [label=ebadi_2020 color=skyblue style=filled fixedsize=true width=6.605170185988092 height=6.605170185988092]
# 	{chiarello_2021_value_creation_in_emerging_technologies_through_text_mining_the_case_of_blockchain; } -> ebadi_2020_application_of_machine_learning_techniques_to_assess_the_trends_and_alignment_of_the_funded_research_output
# 	kim_2022_exploring_scientific_trajectories_of_a_large_scale_dataset_using_topic_integrated_path_extraction [label=kim_2022 color=skyblue style=filled fixedsize=true width=4.19722457733622 height=4.19722457733622]
# 	{} -> kim_2022_exploring_scientific_trajectories_of_a_large_scale_dataset_using_topic_integrated_path_extraction
# 	cassi_2017_improving_fitness_mapping_research_priorities_against_societal_needs_on_obesity [label=cassi_2017 color=skyblue style=filled fixedsize=true width=8.437751649736402 height=8.437751649736402]
# 	{} -> cassi_2017_improving_fitness_mapping_research_priorities_against_societal_needs_on_obesity
# 	xu_2020_topic_linked_innovation_paths_in_science_and_technology [label=xu_2020 color=skyblue style=filled fixedsize=true width=7.8888779583328805 height=7.8888779583328805]
# 	{xu_2022_a_methodology_for_identifying_breakthrough_topics_using_structural_entropy; zhu_2022_evolution_analysis_of_online_topics_based_on_word_topic_coupling_network; huang_2022_identification_of_topic_evolution_network_analytics_with_piecewise_linear_representation_and_word_embedding; liu_2022_innovation_hierarchy_based_patent_representation_model; } -> xu_2020_topic_linked_innovation_paths_in_science_and_technology
# 	chen_2020_a_topic_sensitive_trust_evaluation_approach_for_users_in_online_communities [label=chen_2020 color=skyblue style=filled fixedsize=true width=4.772588722239782 height=4.772588722239782]
# 	{} -> chen_2020_a_topic_sensitive_trust_evaluation_approach_for_users_in_online_communities
# 	alp_2019_influence_factorization_for_identifying_authorities_in_twitter [label=alp_2019 color=skyblue style=filled fixedsize=true width=7.666426688112432 height=7.666426688112432]
# 	{firdaniza_2021_information_diffusion_model_in_twitter_a_systematic_literature_review; ishfaq_2022_finding_influential_users_in_microblogs_state_of_the_art_methods_and_open_research_challenges; liu_2020_gmm_a_generalized_mechanics_model_for_identifying_the_importance_of_nodes_in_complex_networks; al_yazidi_2020_measuring_reputation_and_influence_in_online_social_networks_a_systematic_literature_review; altinel_girgin_2022_from_past_to_present_spam_detection_and_identifying_opinion_leaders_in_social_networks; } -> alp_2019_influence_factorization_for_identifying_authorities_in_twitter
# 	alp_2018_identifying_topical_influencers_on_twitter_based_on_user_behavior_and_network_topology [label=alp_2018 color=skyblue style=filled fixedsize=true width=10.221747728346623 height=10.221747728346623]
# 	{firdaniza_2021_information_diffusion_model_in_twitter_a_systematic_literature_review; ishfaq_2022_finding_influential_users_in_microblogs_state_of_the_art_methods_and_open_research_challenges; altinel_girgin_2022_from_past_to_present_spam_detection_and_identifying_opinion_leaders_in_social_networks; al_yazidi_2020_measuring_reputation_and_influence_in_online_social_networks_a_systematic_literature_review; liu_2020_gmm_a_generalized_mechanics_model_for_identifying_the_importance_of_nodes_in_complex_networks; } -> alp_2018_identifying_topical_influencers_on_twitter_based_on_user_behavior_and_network_topology
# 	zhang_2017_detecting_and_predicting_the_topic_change_of_knowledge_based_systems_a_topic_based_bibliometric_analysis_from_1991_to_2016 [label=zhang_2017 color=skyblue style=filled fixedsize=true width=10.317766166719343 height=10.317766166719343]
# 	{zhang_2021_ethics_and_privacy_of_artificial_intelligence_understandings_from_bibliometrics; wu_2021_unraveling_the_capabilities_that_enable_digital_transformation_a_data_driven_methodology_and_the_case_of_artificial_intelligence; zhang_2021_topic_evolution_disruption_and_resilience_in_early_covid_19_research; zhang_2020_framework_of_computational_intelligence_enhanced_knowledge_base_construction_methodology_and_a_case_of_gene_related_cardiovascular_disease; } -> zhang_2017_detecting_and_predicting_the_topic_change_of_knowledge_based_systems_a_topic_based_bibliometric_analysis_from_1991_to_2016
# 	chen_2019_experimental_explorations_on_short_text_topic_mining_between_lda_and_nmf_based_schemes [label=chen_2019 color=skyblue style=filled fixedsize=true width=10.908694592507015 height=10.908694592507015]
# 	{parlina_2021_exposing_emerging_trends_in_smart_sustainable_city_research_using_deep_autoencoders_based_fuzzy_c_means; murshed_2022_short_text_topic_modelling_approaches_in_the_context_of_big_data_taxonomy_survey_and_analysis; wang_2021_technology_hotspot_tracking_topic_discovery_and_evolution_of_chinas_blockchain_patents_based_on_a_dynamic_lda_model; truica_2021_tlatr_automatic_topic_labeling_using_automatic_domain_specific_term_recognition; truica_2021_topic_based_document_level_sentiment_analysis_using_contextual_cues; guven_2019_comparison_of_topic_modeling_methods_for_type_detection_of_turkish_news; shams_2020_lisa_language_independent_method_for_aspect_based_sentiment_analysis; luo_2021_exploring_chinas_5a_global_geoparks_through_online_tourism_reviews_a_mining_model_based_on_machine_learning_approach; shadrova_2021_topic_models_do_not_model_topics_epistemological_remarks_and_steps_towards_best_practices; } -> chen_2019_experimental_explorations_on_short_text_topic_mining_between_lda_and_nmf_based_schemes
# 	zhang_2019_learning_document_representation_via_topic_enhanced_lstm_model [label=zhang_2019 color=skyblue style=filled fixedsize=true width=8.35610766069589 height=8.35610766069589]
# 	{} -> zhang_2019_learning_document_representation_via_topic_enhanced_lstm_model
# 	hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence [label=hoyle_2021 fixedsize=true width=2 height=2]
# 	nguyen_2021_contrastive_learning_for_neural_topic_model [label=nguyen_2021 fixedsize=true width=2 height=2]
# 	hoyle_2022_are_neural_topic_models_broken [label=hoyle_2022 fixedsize=true width=2 height=2]
# 	zhu_2022_disentangled_learning_of_stance_and_aspect_topics_for_vaccine_attitude_detection_in_social_media [label=zhu_2022 fixedsize=true width=2 height=2]
# 	zhao_2021_adversarial_learning_of_poisson_factorisation_model_for_gauging_brand_sentiment_in_user_reviews [label=zhao_2021 fixedsize=true width=2 height=2]
# 	tripodi_2020_topic_modelling_games [label=tripodi_2020 fixedsize=true width=2 height=2]
# 	zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey [label=zhao_2021 fixedsize=true width=2 height=2]
# 	zhang_2022_pre_training_and_fine_tuning_neural_topic_model_a_simple_yet_effective_approach_to_incorporating_external_knowledge [label=zhang_2022 fixedsize=true width=2 height=2]
# 	panwar_2021_tan_ntm_topic_attention_networks_for_neural_topic_modeling [label=panwar_2021 fixedsize=true width=2 height=2]
# 	hoyle_2020_improving_neural_topic_models_using_knowledge_distillation [label=hoyle_2020 fixedsize=true width=2 height=2]
# 	hoyle_2022_are_neural_topic_models_broken [label=hoyle_2022 fixedsize=true width=2 height=2]
# 	tripodi_2020_topic_modelling_games [label=tripodi_2020 fixedsize=true width=2 height=2]
# 	zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey [label=zhao_2021 fixedsize=true width=2 height=2]
# 	hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence [label=hoyle_2021 fixedsize=true width=2 height=2]
# 	liu_2022_innovation_hierarchy_based_patent_representation_model [label=liu_2022 fixedsize=true width=2 height=2]
# 	panwar_2021_tan_ntm_topic_attention_networks_for_neural_topic_modeling [label=panwar_2021 fixedsize=true width=2 height=2]
# 	zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey [label=zhao_2021 fixedsize=true width=2 height=2]
# 	he_2021_automatic_topic_labeling_model_with_paired_attention_based_on_pre_trained_deep_neural_network [label=he_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	kriukova_2018_explicit_semantic_analysis_as_a_means_for_topic_labelling [label=kriukova_2018 fixedsize=true width=2 height=2]
# 	truica_2021_tlatr_automatic_topic_labeling_using_automatic_domain_specific_term_recognition [label=truica_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	he_2021_automatic_topic_labeling_using_graph_based_pre_trained_neural_embedding [label=he_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	he_2019_automatic_labeling_of_topic_models_using_graph_based_ranking [label=he_2019 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	popa_2021_bart_tl_weakly_supervised_topic_label_generation [label=popa_2021 fixedsize=true width=2 height=2]
# 	rosati_2022_moving_beyond_word_lists_towards_abstractive_topic_labels_for_human_like_topics_of_scientific_documents [label=rosati_2022 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	zosa_2022_multilingual_topic_labelling_of_news_topics_using_ontological_mapping [label=zosa_2022 fixedsize=true width=2 height=2]
# 	university_of_helsinki_2021_not_all_comments_are_equal_insights_into_comment_moderation_from_a_topic_aware_model [label=university_of_helsinki_2021 fixedsize=true width=2 height=2]
# 	kriukova_2018_explicit_semantic_analysis_as_a_means_for_topic_labelling [label=kriukova_2018 fixedsize=true width=2 height=2]
# 	he_2019_automatic_labeling_of_topic_models_using_graph_based_ranking [label=he_2019 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	he_2021_automatic_topic_labeling_using_graph_based_pre_trained_neural_embedding [label=he_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	he_2021_automatic_topic_labeling_model_with_paired_attention_based_on_pre_trained_deep_neural_network [label=he_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	nguyen_2021_contrastive_learning_for_neural_topic_model [label=nguyen_2021 fixedsize=true width=2 height=2]
# 	hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence [label=hoyle_2021 fixedsize=true width=2 height=2]
# 	zhao_2021_adversarial_learning_of_poisson_factorisation_model_for_gauging_brand_sentiment_in_user_reviews [label=zhao_2021 fixedsize=true width=2 height=2]
# 	panwar_2021_tan_ntm_topic_attention_networks_for_neural_topic_modeling [label=panwar_2021 fixedsize=true width=2 height=2]
# 	zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey [label=zhao_2021 fixedsize=true width=2 height=2]
# 	zhang_2022_pre_training_and_fine_tuning_neural_topic_model_a_simple_yet_effective_approach_to_incorporating_external_knowledge [label=zhang_2022 fixedsize=true width=2 height=2]
# 	hoyle_2020_improving_neural_topic_models_using_knowledge_distillation [label=hoyle_2020 fixedsize=true width=2 height=2]
# 	lee_2022_topic_taxonomy_expansion_via_hierarchy_aware_topic_phrase_generation [label=lee_2022 fixedsize=true width=2 height=2]
# 	jiang_2022_taxoenrich_self_supervised_taxonomy_completion_via_structure_semantic_representations [label=jiang_2022 fixedsize=true width=2 height=2]
# 	taha_2022_inferring_the_densest_multi_profiled_cross_community_for_a_user [label=taha_2022 fixedsize=true width=2 height=2]
# 	avron_2022_automated_category_tree_construction_in_e_commerce [label=avron_2022 fixedsize=true width=2 height=2]
# 	lee_2022_taxocom_topic_taxonomy_completion_with_hierarchical_discovery_of_novel_topic_clusters [label=lee_2022 fixedsize=true width=2 height=2]
# 	guo_2021_dhcm_dynamic_and_hierarchical_event_categorization_and_discovery_for_social_media_stream [label=guo_2021 fixedsize=true width=2 height=2]
# 	sas_2022_gitranking_a_ranking_of_github_topics_for_software_classification_using_active_sampling [label=sas_2022 fixedsize=true width=2 height=2]
# 	mousavi_2021_stif_semi_supervised_taxonomy_induction_using_term_embeddings_and_clustering [label=mousavi_2021 fixedsize=true width=2 height=2]
# 	huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring [label=huang_2020 fixedsize=true width=2 height=2]
# 	meng_2020_embedding_driven_multi_dimensional_topic_mining_and_text_analysis [label=meng_2020 fixedsize=true width=2 height=2]
# 	lee_2022_topic_taxonomy_expansion_via_hierarchy_aware_topic_phrase_generation [label=lee_2022 fixedsize=true width=2 height=2]
# 	lee_2022_taxocom_topic_taxonomy_completion_with_hierarchical_discovery_of_novel_topic_clusters [label=lee_2022 fixedsize=true width=2 height=2]
# 	guo_2021_dhcm_dynamic_and_hierarchical_event_categorization_and_discovery_for_social_media_stream [label=guo_2021 fixedsize=true width=2 height=2]
# 	sas_2022_gitranking_a_ranking_of_github_topics_for_software_classification_using_active_sampling [label=sas_2022 fixedsize=true width=2 height=2]
# 	taha_2022_inferring_the_densest_multi_profiled_cross_community_for_a_user [label=taha_2022 fixedsize=true width=2 height=2]
# 	huang_2020_weakly_supervised_aspect_based_sentiment_analysis_via_joint_aspect_sentiment_topic_embedding [label=huang_2020 fixedsize=true width=2 height=2]
# 	jiang_2022_taxoenrich_self_supervised_taxonomy_completion_via_structure_semantic_representations [label=jiang_2022 fixedsize=true width=2 height=2]
# 	avron_2022_automated_category_tree_construction_in_e_commerce [label=avron_2022 fixedsize=true width=2 height=2]
# 	meng_2020_embedding_driven_multi_dimensional_topic_mining_and_text_analysis [label=meng_2020 fixedsize=true width=2 height=2]
# 	meng_2022_topic_discovery_via_latent_space_clustering_of_pretrained_language_model_representations [label=meng_2022 fixedsize=true width=2 height=2]
# 	meng_2022_adapting_pretrained_representations_for_text_mining [label=meng_2022 fixedsize=true width=2 height=2]
# 	meng_2021_on_the_power_of_pre_trained_text_representations_models_and_applications_in_text_mining [label=meng_2021 fixedsize=true width=2 height=2]
# 	mousavi_2021_stif_semi_supervised_taxonomy_induction_using_term_embeddings_and_clustering [label=mousavi_2021 fixedsize=true width=2 height=2]
# 	ge_2021_fine_grained_opinion_summarization_with_minimal_supervision [label=ge_2021 fixedsize=true width=2 height=2]
# 	lee_2022_topic_taxonomy_expansion_via_hierarchy_aware_topic_phrase_generation [label=lee_2022 fixedsize=true width=2 height=2]
# 	lee_2022_taxocom_topic_taxonomy_completion_with_hierarchical_discovery_of_novel_topic_clusters [label=lee_2022 fixedsize=true width=2 height=2]
# 	meng_2022_adapting_pretrained_representations_for_text_mining [label=meng_2022 fixedsize=true width=2 height=2]
# 	guo_2021_dhcm_dynamic_and_hierarchical_event_categorization_and_discovery_for_social_media_stream [label=guo_2021 fixedsize=true width=2 height=2]
# 	meng_2022_topic_discovery_via_latent_space_clustering_of_pretrained_language_model_representations [label=meng_2022 fixedsize=true width=2 height=2]
# 	huang_2020_corel_seed_guided_topical_taxonomy_construction_by_concept_learning_and_relation_transferring [label=huang_2020 fixedsize=true width=2 height=2]
# 	meng_2020_embedding_driven_multi_dimensional_topic_mining_and_text_analysis [label=meng_2020 fixedsize=true width=2 height=2]
# 	meng_2021_on_the_power_of_pre_trained_text_representations_models_and_applications_in_text_mining [label=meng_2021 fixedsize=true width=2 height=2]
# 	zhu_2022_disentangled_learning_of_stance_and_aspect_topics_for_vaccine_attitude_detection_in_social_media [label=zhu_2022 fixedsize=true width=2 height=2]
# 	hoyle_2021_is_automated_topic_model_evaluation_broken_the_incoherence_of_coherence [label=hoyle_2021 fixedsize=true width=2 height=2]
# 	wood_2022_a_bayesian_topic_model_for_human_evaluated_interpretability [label=wood_2022 fixedsize=true width=2 height=2]
# 	hoyle_2022_are_neural_topic_models_broken [label=hoyle_2022 fixedsize=true width=2 height=2]
# 	rosati_2022_moving_beyond_word_lists_towards_abstractive_topic_labels_for_human_like_topics_of_scientific_documents [label=rosati_2022 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	zhao_2021_topic_modelling_meets_deep_neural_networks_a_survey [label=zhao_2021 fixedsize=true width=2 height=2]
# 	korencic_2021_a_topic_coverage_approach_to_evaluation_of_topic_models [label=korencic_2021 fixedsize=true width=2 height=2]
# 	meaney_2022_non_negative_matrix_factorization_temporal_topic_models_and_clinical_text_data_identify_covid_19_pandemic_effects_on_primary_healthcare_and_community_health_in_toronto_canada [label=meaney_2022 fixedsize=true width=2 height=2]
# 	wood_2022_a_bayesian_topic_model_for_human_evaluated_interpretability [label=wood_2022 fixedsize=true width=2 height=2]
# 	rosati_2022_moving_beyond_word_lists_towards_abstractive_topic_labels_for_human_like_topics_of_scientific_documents [label=rosati_2022 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	meaney_2022_non_negative_matrix_factorization_temporal_topic_models_and_clinical_text_data_identify_covid_19_pandemic_effects_on_primary_healthcare_and_community_health_in_toronto_canada [label=meaney_2022 fixedsize=true width=2 height=2]
# 	zosa_2022_multilingual_topic_labelling_of_news_topics_using_ontological_mapping [label=zosa_2022 fixedsize=true width=2 height=2]
# 	he_2021_automatic_topic_labeling_using_graph_based_pre_trained_neural_embedding [label=he_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	university_of_helsinki_2021_not_all_comments_are_equal_insights_into_comment_moderation_from_a_topic_aware_model [label=university_of_helsinki_2021 fixedsize=true width=2 height=2]
# 	wahid_2021_topic2features_a_novel_framework_to_classify_noisy_and_sparse_textual_data_using_lda_topic_distributions [label=wahid_2021 fixedsize=true width=2 height=2]
# 	popa_2021_bart_tl_weakly_supervised_topic_label_generation [label=popa_2021 fixedsize=true width=2 height=2]
# 	chakraborty_2022_are_online_reviews_credible_the_effects_of_online_reviews_for_the_adoption_of_moocs_for_e_learning [label=chakraborty_2022 fixedsize=true width=2 height=2]
# 	wang_2022_research_on_electronic_word_of_mouth_for_product_and_service_quality_improvement_bibliometric_analysis_and_future_directions [label=wang_2022 fixedsize=true width=2 height=2]
# 	ding_2021_exploring_sources_of_satisfaction_and_dissatisfaction_in_airbnb_accommodation_using_unsupervised_and_supervised_topic_modeling [label=ding_2021 fixedsize=true width=2 height=2]
# 	yan_2021_examining_consumer_complaints_from_an_on_demand_service_platform [label=yan_2021 fixedsize=true width=2 height=2]
# 	wang_2022_discovery_of_product_features_for_redesign_from_user_implicit_feedback [label=wang_2022 fixedsize=true width=2 height=2]
# 	wang_2022_research_on_electronic_word_of_mouth_for_product_and_service_quality_improvement_bibliometric_analysis_and_future_directions [label=wang_2022 fixedsize=true width=2 height=2]
# 	firdaniza_2021_information_diffusion_model_in_twitter_a_systematic_literature_review [label=firdaniza_2021 fixedsize=true width=2 height=2]
# 	ding_2021_exploring_sources_of_satisfaction_and_dissatisfaction_in_airbnb_accommodation_using_unsupervised_and_supervised_topic_modeling [label=ding_2021 fixedsize=true width=2 height=2]
# 	gozuacik_2021_social_media_based_opinion_retrieval_for_product_analysis_using_multi_task_deep_neural_networks [label=gozuacik_2021 fixedsize=true width=2 height=2]
# 	li_2021_impact_of_the_latent_topics_of_policy_documents_on_the_promotion_of_new_energy_vehicles_empirical_evidence_from_chinese_cities [label=li_2021 fixedsize=true width=2 height=2]
# 	bansal_2020_aspect_context_aware_sentiment_classification_of_online_consumer_reviews [label=bansal_2020 fixedsize=true width=2 height=2]
# 	he_2020_the_voice_of_drug_consumers_online_textual_review_analysis_using_structural_topic_model [label=he_2020 fixedsize=true width=2 height=2]
# 	yang_2020_service_providers_competence_identification_in_knowledge_intensive_crowdsourcing_context [label=yang_2020 fixedsize=true width=2 height=2]
# 	chakraborty_2022_are_online_reviews_credible_the_effects_of_online_reviews_for_the_adoption_of_moocs_for_e_learning [label=chakraborty_2022 fixedsize=true width=2 height=2]
# 	ge_2021_fine_grained_opinion_summarization_with_minimal_supervision [label=ge_2021 fixedsize=true width=2 height=2]
# 	chen_2020_a_structural_topic_modeling_based_bibliometric_study_of_sentiment_analysis_literature [label=chen_2020 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	hussain_2022_aspect2labels_a_novelistic_decision_support_system_for_higher_educational_institutions_by_using_multi_layer_topic_modelling_approach [label=hussain_2022 fixedsize=true width=2 height=2]
# 	guven_2022_impact_of_n_stage_latent_dirichlet_allocation_on_analysis_of_headline_classification [label=guven_2022 fixedsize=true width=2 height=2]
# 	huang_2020_weakly_supervised_aspect_based_sentiment_analysis_via_joint_aspect_sentiment_topic_embedding [label=huang_2020 fixedsize=true width=2 height=2]
# 	shams_2020_lisa_language_independent_method_for_aspect_based_sentiment_analysis [label=shams_2020 fixedsize=true width=2 height=2]
# 	truica_2021_topic_based_document_level_sentiment_analysis_using_contextual_cues [label=truica_2021 fixedsize=true width=2 height=2]
# 	bansal_2020_aspect_context_aware_sentiment_classification_of_online_consumer_reviews [label=bansal_2020 fixedsize=true width=2 height=2]
# 	shou_2022_predictions_on_usefulness_and_popularity_of_online_reviews_evidence_from_mobile_phones_for_older_adults [label=shou_2022 fixedsize=true width=2 height=2]
# 	farzadnia_2022_identification_of_opinion_trends_using_sentiment_analysis_of_airlines_passengers_reviews [label=farzadnia_2022 fixedsize=true width=2 height=2]
# 	ding_2021_exploring_sources_of_satisfaction_and_dissatisfaction_in_airbnb_accommodation_using_unsupervised_and_supervised_topic_modeling [label=ding_2021 fixedsize=true width=2 height=2]
# 	he_2020_the_voice_of_drug_consumers_online_textual_review_analysis_using_structural_topic_model [label=he_2020 fixedsize=true width=2 height=2]
# 	shadrova_2021_topic_models_do_not_model_topics_epistemological_remarks_and_steps_towards_best_practices [label=shadrova_2021 fixedsize=true width=2 height=2]
# 	chen_2020_a_structural_topic_modeling_based_bibliometric_study_of_sentiment_analysis_literature [label=chen_2020 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	wang_2022_discovery_of_product_features_for_redesign_from_user_implicit_feedback [label=wang_2022 fixedsize=true width=2 height=2]
# 	calli_2022_understanding_airline_passengers_during_covid_19_outbreak_to_improve_service_quality_topic_modeling_approach_to_complaints_with_latent_dirichlet_allocation_algorithm [label=calli_2022 fixedsize=true width=2 height=2]
# 	li_2021_impact_of_the_latent_topics_of_policy_documents_on_the_promotion_of_new_energy_vehicles_empirical_evidence_from_chinese_cities [label=li_2021 fixedsize=true width=2 height=2]
# 	porter_2020_measuring_tech_emergence_a_contest [label=porter_2020 fixedsize=true width=2 height=2]
# 	chowdhury_2021_functional_analysis_of_generalized_linear_models_under_non_linear_constraints_with_applications_to_identifying_highly_cited_papers [label=chowdhury_2021 fixedsize=true width=2 height=2]
# 	korencic_2021_a_topic_coverage_approach_to_evaluation_of_topic_models [label=korencic_2021 fixedsize=true width=2 height=2]
# 	shou_2022_predictions_on_usefulness_and_popularity_of_online_reviews_evidence_from_mobile_phones_for_older_adults [label=shou_2022 fixedsize=true width=2 height=2]
# 	guven_2019_comparison_of_topic_modeling_methods_for_type_detection_of_turkish_news [label=guven_2019 fixedsize=true width=2 height=2]
# 	farzadnia_2022_identification_of_opinion_trends_using_sentiment_analysis_of_airlines_passengers_reviews [label=farzadnia_2022 fixedsize=true width=2 height=2]
# 	calli_2022_understanding_airline_passengers_during_covid_19_outbreak_to_improve_service_quality_topic_modeling_approach_to_complaints_with_latent_dirichlet_allocation_algorithm [label=calli_2022 fixedsize=true width=2 height=2]
# 	yan_2021_examining_consumer_complaints_from_an_on_demand_service_platform [label=yan_2021 fixedsize=true width=2 height=2]
# 	wang_2021_technology_hotspot_tracking_topic_discovery_and_evolution_of_chinas_blockchain_patents_based_on_a_dynamic_lda_model [label=wang_2021 fixedsize=true width=2 height=2]
# 	guven_2022_impact_of_n_stage_latent_dirichlet_allocation_on_analysis_of_headline_classification [label=guven_2022 fixedsize=true width=2 height=2]
# 	ahmed_mateen_2021_an_analysis_on_text_mining_techniques_for_smart_literature_review [label=ahmed_mateen_2021 fixedsize=true width=2 height=2]
# 	yang_2020_service_providers_competence_identification_in_knowledge_intensive_crowdsourcing_context [label=yang_2020 fixedsize=true width=2 height=2]
# 	parlina_2021_exposing_emerging_trends_in_smart_sustainable_city_research_using_deep_autoencoders_based_fuzzy_c_means [label=parlina_2021 fixedsize=true width=2 height=2]
# 	hussain_2022_aspect2labels_a_novelistic_decision_support_system_for_higher_educational_institutions_by_using_multi_layer_topic_modelling_approach [label=hussain_2022 fixedsize=true width=2 height=2]
# 	murshed_2022_short_text_topic_modelling_approaches_in_the_context_of_big_data_taxonomy_survey_and_analysis [label=murshed_2022 fixedsize=true width=2 height=2]
# 	wahid_2021_topic2features_a_novel_framework_to_classify_noisy_and_sparse_textual_data_using_lda_topic_distributions [label=wahid_2021 fixedsize=true width=2 height=2]
# 	zhu_2022_evolution_analysis_of_online_topics_based_on_word_topic_coupling_network [label=zhu_2022 fixedsize=true width=2 height=2]
# 	gozuacik_2021_social_media_based_opinion_retrieval_for_product_analysis_using_multi_task_deep_neural_networks [label=gozuacik_2021 fixedsize=true width=2 height=2]
# 	ahmed_mateen_2021_an_analysis_on_text_mining_techniques_for_smart_literature_review [label=ahmed_mateen_2021 fixedsize=true width=2 height=2]
# 	luo_2021_exploring_chinas_5a_global_geoparks_through_online_tourism_reviews_a_mining_model_based_on_machine_learning_approach [label=luo_2021 fixedsize=true width=2 height=2]
# 	chiarello_2021_value_creation_in_emerging_technologies_through_text_mining_the_case_of_blockchain [label=chiarello_2021 fixedsize=true width=2 height=2]
# 	wood_2022_a_bayesian_topic_model_for_human_evaluated_interpretability [label=wood_2022 fixedsize=true width=2 height=2]
# 	murshed_2022_short_text_topic_modelling_approaches_in_the_context_of_big_data_taxonomy_survey_and_analysis [label=murshed_2022 fixedsize=true width=2 height=2]
# 	porter_2020_measuring_tech_emergence_a_contest [label=porter_2020 fixedsize=true width=2 height=2]
# 	xu_2022_a_methodology_for_identifying_breakthrough_topics_using_structural_entropy [label=xu_2022 fixedsize=true width=2 height=2]
# 	zhang_2021_topic_evolution_disruption_and_resilience_in_early_covid_19_research [label=zhang_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	wu_2021_unraveling_the_capabilities_that_enable_digital_transformation_a_data_driven_methodology_and_the_case_of_artificial_intelligence [label=wu_2021 fixedsize=true width=2 height=2]
# 	chowdhury_2021_functional_analysis_of_generalized_linear_models_under_non_linear_constraints_with_applications_to_identifying_highly_cited_papers [label=chowdhury_2021 fixedsize=true width=2 height=2]
# 	huang_2022_identification_of_topic_evolution_network_analytics_with_piecewise_linear_representation_and_word_embedding [label=huang_2022 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	zhang_2021_ethics_and_privacy_of_artificial_intelligence_understandings_from_bibliometrics [label=zhang_2021 fixedsize=true width=2 height=2]
# 	zhang_2020_framework_of_computational_intelligence_enhanced_knowledge_base_construction_methodology_and_a_case_of_gene_related_cardiovascular_disease [label=zhang_2020 fixedsize=true width=2 height=2]
# 	chiarello_2021_value_creation_in_emerging_technologies_through_text_mining_the_case_of_blockchain [label=chiarello_2021 fixedsize=true width=2 height=2]
# 	xu_2022_a_methodology_for_identifying_breakthrough_topics_using_structural_entropy [label=xu_2022 fixedsize=true width=2 height=2]
# 	zhu_2022_evolution_analysis_of_online_topics_based_on_word_topic_coupling_network [label=zhu_2022 fixedsize=true width=2 height=2]
# 	huang_2022_identification_of_topic_evolution_network_analytics_with_piecewise_linear_representation_and_word_embedding [label=huang_2022 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	liu_2022_innovation_hierarchy_based_patent_representation_model [label=liu_2022 fixedsize=true width=2 height=2]
# 	firdaniza_2021_information_diffusion_model_in_twitter_a_systematic_literature_review [label=firdaniza_2021 fixedsize=true width=2 height=2]
# 	ishfaq_2022_finding_influential_users_in_microblogs_state_of_the_art_methods_and_open_research_challenges [label=ishfaq_2022 fixedsize=true width=2 height=2]
# 	liu_2020_gmm_a_generalized_mechanics_model_for_identifying_the_importance_of_nodes_in_complex_networks [label=liu_2020 fixedsize=true width=2 height=2]
# 	al_yazidi_2020_measuring_reputation_and_influence_in_online_social_networks_a_systematic_literature_review [label=al_yazidi_2020 fixedsize=true width=2 height=2]
# 	altinel_girgin_2022_from_past_to_present_spam_detection_and_identifying_opinion_leaders_in_social_networks [label=altinel_girgin_2022 fixedsize=true width=2 height=2]
# 	firdaniza_2021_information_diffusion_model_in_twitter_a_systematic_literature_review [label=firdaniza_2021 fixedsize=true width=2 height=2]
# 	ishfaq_2022_finding_influential_users_in_microblogs_state_of_the_art_methods_and_open_research_challenges [label=ishfaq_2022 fixedsize=true width=2 height=2]
# 	altinel_girgin_2022_from_past_to_present_spam_detection_and_identifying_opinion_leaders_in_social_networks [label=altinel_girgin_2022 fixedsize=true width=2 height=2]
# 	al_yazidi_2020_measuring_reputation_and_influence_in_online_social_networks_a_systematic_literature_review [label=al_yazidi_2020 fixedsize=true width=2 height=2]
# 	liu_2020_gmm_a_generalized_mechanics_model_for_identifying_the_importance_of_nodes_in_complex_networks [label=liu_2020 fixedsize=true width=2 height=2]
# 	zhang_2021_ethics_and_privacy_of_artificial_intelligence_understandings_from_bibliometrics [label=zhang_2021 fixedsize=true width=2 height=2]
# 	wu_2021_unraveling_the_capabilities_that_enable_digital_transformation_a_data_driven_methodology_and_the_case_of_artificial_intelligence [label=wu_2021 fixedsize=true width=2 height=2]
# 	zhang_2021_topic_evolution_disruption_and_resilience_in_early_covid_19_research [label=zhang_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	zhang_2020_framework_of_computational_intelligence_enhanced_knowledge_base_construction_methodology_and_a_case_of_gene_related_cardiovascular_disease [label=zhang_2020 fixedsize=true width=2 height=2]
# 	parlina_2021_exposing_emerging_trends_in_smart_sustainable_city_research_using_deep_autoencoders_based_fuzzy_c_means [label=parlina_2021 fixedsize=true width=2 height=2]
# 	murshed_2022_short_text_topic_modelling_approaches_in_the_context_of_big_data_taxonomy_survey_and_analysis [label=murshed_2022 fixedsize=true width=2 height=2]
# 	wang_2021_technology_hotspot_tracking_topic_discovery_and_evolution_of_chinas_blockchain_patents_based_on_a_dynamic_lda_model [label=wang_2021 fixedsize=true width=2 height=2]
# 	truica_2021_tlatr_automatic_topic_labeling_using_automatic_domain_specific_term_recognition [label=truica_2021 color=lightgoldenrodyellow style=filled fixedsize=true width=2 height=2]
# 	truica_2021_topic_based_document_level_sentiment_analysis_using_contextual_cues [label=truica_2021 fixedsize=true width=2 height=2]
# 	guven_2019_comparison_of_topic_modeling_methods_for_type_detection_of_turkish_news [label=guven_2019 fixedsize=true width=2 height=2]
# 	shams_2020_lisa_language_independent_method_for_aspect_based_sentiment_analysis [label=shams_2020 fixedsize=true width=2 height=2]
# 	luo_2021_exploring_chinas_5a_global_geoparks_through_online_tourism_reviews_a_mining_model_based_on_machine_learning_approach [label=luo_2021 fixedsize=true width=2 height=2]
# 	shadrova_2021_topic_models_do_not_model_topics_epistemological_remarks_and_steps_towards_best_practices [label=shadrova_2021 fixedsize=true width=2 height=2]
# }

# %%
# Selected BS papers which are cited by more than one paper in the initial selection
# Papers from initial selection are colored skyblue
bs_style = []
bs_counts = {}
glossary = get_glossary()

# Count incoming edges for bs papers
for key in venues:
    for venue in venues[key]:
        with os.scandir(f'../References/Snowballing/Backward snowballing (Outgoing references)/{key}/{venue}') as it:
            for entry in it:
                if entry.name.endswith(".bib") and entry.is_file():
                    source = entry.name.replace('.bib','')
                    with open(entry, 'r') as fp:
                        db = biblib.bib.Parser().parse(fp, log_fp=sys.stderr).get_entries()
                    
                    for ent in db.values():
                        cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])
                        if cite_key in bs_selection: 
                            if(cite_key in bs_counts): bs_counts[cite_key] += 1
                            else: bs_counts[cite_key] = 1

print('digraph G {')
for key in venues:
    for venue in venues[key]:
        with os.scandir(f'../References/Snowballing/Backward snowballing (Outgoing references)/{key}/{venue}') as it:
            for entry in it:
                if entry.name.endswith(".bib") and entry.is_file():
                    source = entry.name.replace('.bib','')
                    with open(entry, 'r') as fp:
                        db = biblib.bib.Parser().parse(fp, log_fp=sys.stderr).get_entries()

                    ent_count = 0
                    for ent in db.values():
                        cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])
                        if (cite_key in bs_counts) and (bs_counts[cite_key] > 1): ent_count +=1
                    if ent_count == 0: continue

                    title = glossary[source]['title']
                    print(f'\t{source} [label="{cite_key_trim_regex.search(source).group()}, {title}" color=skyblue style=filled]')
                    print(f'\t{source} -> {{', end='')

                    for ent in db.values():
                        cite_key = build_cite_key(ent['author'], ent['year'], ent['title'])

                        if (cite_key in bs_counts) and (bs_counts[cite_key] > 1): 
                            title = glossary[cite_key]['title']
                            bs_style.append(f'\t{cite_key} [label="{cite_key_trim_regex.search(cite_key).group()}, {title}"]')
                            print(f'{cite_key}; ', end='')
                    print(f'}}')
for bs_paper_style in bs_style: print(bs_paper_style)
print('}')
# Out:
# digraph G {
# 	hosseiny_marani_2022_one_rating_to_rule_them_all_evidence_of_multidimensionality_in_human_assessment_of_topic_labeling_quality [label="hosseiny_marani_2022, One {Rating} to {Rule} {Them} {All}?: {Evidence} of {Multidimensionality} in {Human} {Assessment} of {Topic} {Labeling} {Quality}" color=skyblue style=filled]
# 	hosseiny_marani_2022_one_rating_to_rule_them_all_evidence_of_multidimensionality_in_human_assessment_of_topic_labeling_quality -> {smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels; }
# 	sorodoc_2017_multimodal_topic_labelling [label="sorodoc_2017, Multimodal {Topic} {Labelling}" color=skyblue style=filled]
# 	sorodoc_2017_multimodal_topic_labelling -> {aletras_2017_evaluating_topic_representations_for_exploring_document_collections; }
# 	doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures [label="doogan_2021, Topic {Model} or {Topic} {Twaddle}? {Re}-evaluating {Semantic} {Interpretability} {Measures}" color=skyblue style=filled]
# 	doogan_2021_topic_model_or_topic_twaddle_re_evaluating_semantic_interpretability_measures -> {maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology; aletras_2017_evaluating_topic_representations_for_exploring_document_collections; }
# 	alokaili_2020_automatic_generation_of_topic_labels [label="alokaili_2020, Automatic {Generation} of {Topic} {Labels}" color=skyblue style=filled]
# 	alokaili_2020_automatic_generation_of_topic_labels -> {smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels; }
# 	sakshi_2023_recent_trends_in_mathematical_expressions_recognition_an_lda_based_analysis [label="sakshi_2023, Recent trends in mathematical expressions recognition: An LDA-based analysis" color=skyblue style=filled]
# 	sakshi_2023_recent_trends_in_mathematical_expressions_recognition_an_lda_based_analysis -> {maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology; }
# 	korfiatis_2019_measuring_service_quality_from_unstructured_data_a_topic_modeling_application_on_airline_passengers_online_reviews [label="korfiatis_2019, Measuring service quality from unstructured data: A topic modeling application on airline passengers' online reviews" color=skyblue style=filled]
# 	korfiatis_2019_measuring_service_quality_from_unstructured_data_a_topic_modeling_application_on_airline_passengers_online_reviews -> {kuhn_2018_using_structural_topic_modeling_to_identify_latent_topics_and_trends_in_aviation_incident_reports; }
# 	ebadi_2020_application_of_machine_learning_techniques_to_assess_the_trends_and_alignment_of_the_funded_research_output [label="ebadi_2020, Application of machine learning techniques to assess the trends and alignment of the funded research output" color=skyblue style=filled]
# 	ebadi_2020_application_of_machine_learning_techniques_to_assess_the_trends_and_alignment_of_the_funded_research_output -> {kuhn_2018_using_structural_topic_modeling_to_identify_latent_topics_and_trends_in_aviation_incident_reports; }
# 	smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels [label="smith_2017, Evaluating Visual Representations for Topic Understanding and Their Effects on Manually Generated Topic Labels"]
# 	aletras_2017_evaluating_topic_representations_for_exploring_document_collections [label="aletras_2017, Evaluating Topic Representations for Exploring Document Collections"]
# 	maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology [label="maier_2018, Applying {LDA} Topic Modeling in Communication Research: Toward a Valid and Reliable Methodology"]
# 	aletras_2017_evaluating_topic_representations_for_exploring_document_collections [label="aletras_2017, Evaluating Topic Representations for Exploring Document Collections"]
# 	smith_2017_evaluating_visual_representations_for_topic_understanding_and_their_effects_on_manually_generated_topic_labels [label="smith_2017, Evaluating Visual Representations for Topic Understanding and Their Effects on Manually Generated Topic Labels"]
# 	maier_2018_applying_lda_topic_modeling_in_communication_research_toward_a_valid_and_reliable_methodology [label="maier_2018, Applying {LDA} Topic Modeling in Communication Research: Toward a Valid and Reliable Methodology"]
# 	kuhn_2018_using_structural_topic_modeling_to_identify_latent_topics_and_trends_in_aviation_incident_reports [label="kuhn_2018, Using structural topic modeling to identify latent topics and trends in aviation incident reports"]
# 	kuhn_2018_using_structural_topic_modeling_to_identify_latent_topics_and_trends_in_aviation_incident_reports [label="kuhn_2018, Using structural topic modeling to identify latent topics and trends in aviation incident reports"]
# }
